# %% [markdown]
# # Sriram et al. (2012) Model Code

# %% [markdown]
# # Table of Contents
# 1. [Imports](#imports)
# 2. [Parameters and Initial Conditions](#params)
# 3. [Put Raw Data into Arrays](#rawdata)
#     1. [Plot Data Sets](#plotdata)
# 4. [Model Function--Includes ODE Solver](#modelfunction)
# 5. [Functions to Determine Delayed ACTH and Cortisol Values](#delays)
# 6. [Cost Function Definition](#cost)
# 7. [Run the Optimization](#run)
# 8. [Save Output to File](#saveoutput)
# 9. [Compute Means and Std Devations of Parameters and Output as Table](#paramtable)
# 10. [Plots](#plots)
# 11. [Figure 3 Reproduction](#fig3)
# 12. [Figure 4 Reproduction](#fig4)
# 13. [Load Parameter Sets, Run Model and Save Hormone Concentration Data](#loadparams)
# 14. [Checking Parameter Sets Generated Externally](#checkexternal)
# 15. [Load Simulated Concentration Data from Files and Plot](#load-and-plot)
# 16. [Dependencies](#dependencies)

# %% [markdown]
# ## Imports <a name="imports"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as sco
from scipy.interpolate import interp1d
import mpld3
from tabulate import tabulate
import matplotlib
import pandas as pd
from HPAmodeling import ODEsolver, costFun, dataImport

# %% [markdown]
# ## Parameters and Initial Conditions <a name="params"></a>

# %%
# it looks, based on the XPP file from the authors, like they start CRH, ACTH, CORT and GR at 0 each and just run
# the solver until they reach some steady state

y0 = [1,28.7,8.6123,2]

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 10.1
k_i = 1.51
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# or we can initialize the parameters that stay the same as the literature values and optimize all parameters and
#     see what happens

V_S3 = 1.58 # reported as 1.58-5
K_m1 = 2
K_P2 = 0.3 # reported as 0.3-1.8
V_S4 = 1.58 # reported as 1.58-5
K_m2 = 2
K_P3 = 0.3 # reported as 0.3-1.8
V_S5 = 1.58 # reported as 1.58-5
K_m3 = 2
K_d1 = 0.173
K_d2 = 0.035
K_d3 = 0.009
n1 = 5
n2 = 4
K_b = 0.01 # no literature value reported
G_tot = 2 # no literature value reported
V_S2 = 0 # reported as 0-1
K1 = 1
K_d5 = 0.01
p_stress = 10

authors_params = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# define the bounds for the parameters to be optimized, k_stress and k_i
bounds = [(5,20), (0.5,3)]

# %%
# here are the bounds used for all of the parameters, assuming we want to optimize more than just k_stress and k_i
bounds = [(5,20), (0.5,3), (3,4), (1,2), (7,11), (0.5,1.5), (0.08,2), (0.5,1.2), (0.001,0.008), (0.03,0.08), (0.002,0.005), (0.001,0.01), (0.1,0.5), (4,6), (4,6), (0.008,0.05), (2,5), (0.01,0.07), (0.2,0.7), (0.04,0.09)]

# %%
# wider bounds for fitting other data sets than original
bounds = [(1,30), (0.1,5), (1,10), (.1,10), (1,31), (0.1,10.5), (0.001,10), (0.1,10), (0.001,0.1), (0.001,0.5), (0.001,0.1), (0.001,0.1), (0.01,5), (1,15), (1,15), (0.001,0.5), (.02,45), (0.0001,7), (0.02,7), (0.004,0.9)]

# %%
# wider bounds WITH p_stress included for Nelson data
bounds = [(1,30), (0.1,5), (1,10), (.1,10), (1,31), (0.1,10.5), (0.001,10), (0.1,10), (0.001,0.1), (0.001,0.5), (0.001,0.1), (0.001,0.1), (0.01,5), (1,15), (1,15), (0.001,0.5), (.02,45), (0.0001,7), (0.02,7), (0.004,0.9), (1,100)]

# %%
# wider bounds WITHOUT p_stress included for Nelson data
bounds = [(1,30), (0.1,5), (1,10), (.1,10), (1,31), (0.1,10.5), (0.001,10), (0.1,10), (0.001,0.1), (0.001,0.5), (0.001,0.1), (0.001,0.1), (0.01,5), (1,15), (1,15), (0.001,0.5), (.02,45), (0.0001,7), (0.02,7), (0.004,0.9)]

# %%
# time interval and step definition, based on XPP model from authors
t_start = -0.01
t_end = 2.35
t_step = 0.01

# %% [markdown]
# ## Put Raw Data Into Arrays <a name="rawdata"></a>

# %%
(yehudaControlCortisol, 
 yehudaControlCortisol_smooth, 
 yehudaPTSDCortisol, 
 yehudaPTSDCortisol_smooth, 
 yehudaDepressedCortisol, 
 yehudaDepressedCortisol_smooth) = dataImport.yehuda()

# %%
(carrollControlCortisol, 
 carrollControlCortisol_rearr, 
 carrollControlCortisol_smooth, 
 carrollControlCortisol_rearr_smooth, 
 carrollControlACTH, 
 carrollControlACTH_rearr, 
 carrollControlACTH_smooth, 
 carrollControlACTH_rearr_smooth, 
 carrollHCDepressedCortisol, 
 carrollHCDepressedCortisol_rearr, 
 carrollHCDepressedCortisol_smooth, 
 carrollHCDepressedCortisol_rearr_smooth, 
 carrollHCDepressedACTH, 
 carrollHCDepressedACTH_rearr, 
 carrollHCDepressedACTH_smooth, 
 carrollHCDepressedACTH_rearr_smooth, 
 carrollLCDepressedCortisol, 
 carrollLCDepressedCortisol_rearr, 
 carrollLCDepressedCortisol_smooth, 
 carrollLCDepressedCortisol_rearr_smooth, 
 carrollLCDepressedACTH, 
 carrollLCDepressedACTH_rearr, 
 carrollLCDepressedACTH_smooth, 
 carrollLCDepressedACTH_rearr_smooth) = dataImport.carroll()

# %%
(golierPTSDCortisol, 
 golierPTSDCortisol_rearr, 
 golierPTSDCortisol_smooth, 
 golierPTSDCortisol_rearr_smooth, 
 golierPTSDACTH, 
 golierPTSDACTH_rearr, 
 golierPTSDACTH_smooth, 
 golierPTSDACTH_rearr_smooth, 
 golierNonPTSDTraumaExposedCortisol, 
 golierNonPTSDTraumaExposedCortisol_rearr, 
 golierNonPTSDTraumaExposedCortisol_smooth, 
 golierNonPTSDTraumaExposedCortisol_rearr_smooth, 
 golierNonPTSDTraumaExposedACTH, 
 golierNonPTSDTraumaExposedACTH_rearr, 
 golierNonPTSDTraumaExposedACTH_smooth, 
 golierNonPTSDTraumaExposedACTH_rearr_smooth, 
 golierNonPTSDNonExposedCortisol, 
 golierNonPTSDNonExposedCortisol_rearr, 
 golierNonPTSDNonExposedCortisol_smooth, 
 golierNonPTSDNonExposedCortisol_rearr_smooth, 
 golierNonPTSDNonExposedACTH, 
 golierNonPTSDNonExposedACTH_rearr, 
 golierNonPTSDNonExposedACTH_smooth, 
 golierNonPTSDNonExposedACTH_rearr_smooth) = dataImport.golier()

# %%
(bremnerAbusedPTSDCortisol, 
 bremnerAbusedPTSDCortisol_rearr, 
 bremnerAbusedPTSDCortisol_smooth, 
 bremnerAbusedPTSDCortisol_rearr_smooth, 
 bremnerNonAbusedPTSDCortisol, 
 bremnerNonAbusedPTSDCortisol_rearr, 
 bremnerNonAbusedPTSDCortisol_smooth, 
 bremnerNonAbusedPTSDCortisol_rearr_smooth, 
 bremnerNonAbusedNonPTSDCortisol, 
 bremnerNonAbusedNonPTSDCortisol_rearr, 
 bremnerNonAbusedNonPTSDCortisol_smooth, 
 bremnerNonAbusedNonPTSDCortisol_rearr_smooth) = dataImport.bremner()

# %%
(nelsonCortisol, 
 nelsonACTH, 
 nelsonAtypicalCortisol, 
 nelsonAtypicalACTH, 
 nelsonMelancholicCortisol, 
 nelsonMelancholicACTH, 
 nelsonNeitherCortisol, 
 nelsonNeitherACTH, 
 nelsonHealthyCortisol, 
 nelsonHealthyACTH, 
 atypical_ids, 
 melancholic_ids, 
 neither_ids, 
 healthy_ids) = dataImport.nelson()

# %% [markdown]
# ### Plot Data Sets <a name="plotdata"></a>

# %%
# convert time scales to hours for the raw data, because the model is in terms of hours
for i in range(len(yehudaControlCortisol)):
    yehudaControlCortisol[i,0] = yehudaControlCortisol[i,0]/60
    yehudaPTSDCortisol[i,0] = yehudaPTSDCortisol[i,0]/60
    yehudaDepressedCortisol[i,0] = yehudaDepressedCortisol[i,0]/60
    yehudaControlCortisol_smooth[i,0] = yehudaControlCortisol_smooth[i,0]/60
    yehudaPTSDCortisol_smooth[i,0] = yehudaPTSDCortisol_smooth[i,0]/60
    yehudaDepressedCortisol_smooth[i,0] = yehudaDepressedCortisol_smooth[i,0]/60

# %%
# make time scale in hours for graphing
j = 0
k = 0
l = 0

timeCarroll = np.zeros(len(carrollControlCortisol[:,0]))
for i in carrollControlCortisol[:,0]:
    timeCarroll[l] = i/60
    l += 1

# %%
for i in range(len(carrollControlCortisol_rearr_smooth)):
    carrollControlACTH[i,0] = timeCarroll[i]
    carrollControlACTH_rearr[i,0] = timeCarroll[i]
    carrollControlACTH_rearr_smooth[i,0] = timeCarroll[i]
    carrollControlACTH_smooth[i,0] = timeCarroll[i]
    
    carrollControlCortisol[i,0] = timeCarroll[i]
    carrollControlCortisol_rearr[i,0] = timeCarroll[i]
    carrollControlCortisol_rearr_smooth[i,0] = timeCarroll[i]
    carrollControlCortisol_smooth[i,0] = timeCarroll[i]
    
    carrollHCDepressedACTH[i,0] = timeCarroll[i]
    carrollHCDepressedACTH_rearr[i,0] = timeCarroll[i]
    carrollHCDepressedACTH_rearr_smooth[i,0] = timeCarroll[i]
    carrollHCDepressedACTH_smooth[i,0] = timeCarroll[i]
    
    carrollLCDepressedACTH[i,0] = timeCarroll[i]
    carrollLCDepressedACTH_rearr[i,0] = timeCarroll[i]
    carrollLCDepressedACTH_rearr_smooth[i,0] = timeCarroll[i]
    carrollLCDepressedACTH_smooth[i,0] = timeCarroll[i]
    
    carrollHCDepressedCortisol[i,0] = timeCarroll[i]
    carrollHCDepressedCortisol_rearr[i,0] = timeCarroll[i]
    carrollHCDepressedCortisol_rearr_smooth[i,0] = timeCarroll[i]
    carrollHCDepressedCortisol_smooth[i,0] = timeCarroll[i]
    
    carrollLCDepressedCortisol[i,0] = timeCarroll[i]
    carrollLCDepressedCortisol_rearr[i,0] = timeCarroll[i]
    carrollLCDepressedCortisol_rearr_smooth[i,0] = timeCarroll[i]
    carrollLCDepressedCortisol_smooth[i,0] = timeCarroll[i]

# %%
# convert the Nelson data time scale to hours, also
for i in range(len(nelsonCortisol)):
    nelsonCortisol[i,0] = nelsonCortisol[i,0]/60
    nelsonACTH[i,0] = nelsonACTH[i,0]/60

# %%
font = {'size'   : 18}
matplotlib.rc('font', **font)

fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (20,20))

ax1.plot(yehudaControlCortisol[:,0], yehudaControlCortisol[:,1], label = "Control Group Cortisol")
ax1.plot(yehudaControlCortisol_smooth[:,0], yehudaControlCortisol_smooth[:,1], label = "Control Group Cortisol - Smoothed")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax1.legend(loc="lower right", shadow = True, fancybox = True)

ax2.plot(yehudaPTSDCortisol[:,0], yehudaPTSDCortisol[:,1], label = "PTSD Group Cortisol")
ax2.plot(yehudaPTSDCortisol_smooth[:,0], yehudaPTSDCortisol_smooth[:,1], label = "PTSD Group Cortisol - Smoothed")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax2.legend(loc="lower right", shadow = True, fancybox = True)

ax3.plot(yehudaDepressedCortisol[:,0], yehudaDepressedCortisol[:,1], label = "Depression Group Cortisol")
ax3.plot(yehudaDepressedCortisol_smooth[:,0], yehudaDepressedCortisol_smooth[:,1], label = "Depression Group Cortisol - Smoothed")
ax3.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax3.legend(loc="lower right", shadow = True, fancybox = True)

# %%
#mpld3.enable_notebook()
# %matplotlib inline

font = {'size'   : 20}
matplotlib.rc('font', **font)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows = 4, figsize = (25,25))

ax1.plot(carrollControlCortisol_rearr[:,0], carrollControlCortisol_rearr[:,1], 'b', label = "Control")
ax1.plot(carrollHCDepressedCortisol_rearr[:,0], carrollHCDepressedCortisol_rearr[:,1], 'r', label = "High Cortisol Depressed")
ax1.plot(carrollControlCortisol_rearr_smooth[:,0], carrollControlCortisol_rearr_smooth[:,1], label = "Control - Smoothed")
ax1.plot(carrollHCDepressedCortisol_rearr_smooth[:,0], carrollHCDepressedCortisol_rearr_smooth[:,1], label = "High Cortisol Depressed - Smoothed")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax1.legend(loc="upper right", shadow = True, fancybox = True)

ax2.plot(carrollControlCortisol_rearr[:,0], carrollControlCortisol_rearr[:,1], 'b', label = "Control")
ax2.plot(carrollLCDepressedCortisol_rearr[:,0], carrollLCDepressedCortisol_rearr[:,1], 'g', label = "Low Cortisol Depressed")
ax2.plot(carrollControlCortisol_rearr_smooth[:,0], carrollControlCortisol_rearr_smooth[:,1], label = "Control - Smoothed")
ax2.plot(carrollLCDepressedCortisol_rearr_smooth[:,0], carrollLCDepressedCortisol_rearr_smooth[:,1], label = "Low Cortisol Depressed - Smoothed")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax2.legend(loc="upper right", shadow = True, fancybox = True)

ax3.plot(carrollControlACTH_rearr[:,0], carrollControlACTH_rearr[:,1], 'b', label = "Control")
ax3.plot(carrollHCDepressedACTH_rearr[:,0], carrollHCDepressedACTH_rearr[:,1], 'r', label = "High Cortisol Depressed")
ax3.plot(carrollControlACTH_rearr_smooth[:,0], carrollControlACTH_rearr_smooth[:,1], label = "Control - Smoothed")
ax3.plot(carrollHCDepressedACTH_rearr_smooth[:,0], carrollHCDepressedACTH_rearr_smooth[:,1], label = "High Cortisol Depressed - Smoothed")
ax3.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax3.legend(loc="upper right", shadow = True, fancybox = True)

ax4.plot(carrollControlACTH_rearr[:,0], carrollControlACTH_rearr[:,1], 'b', label = "Control")
ax4.plot(carrollLCDepressedACTH_rearr[:,0], carrollLCDepressedACTH_rearr[:,1], 'g', label = "Low Cortisol Depressed")
ax4.plot(carrollControlACTH_rearr_smooth[:,0], carrollControlACTH_rearr_smooth[:,1], label = "Control - Smoothed")
ax4.plot(carrollLCDepressedACTH_rearr_smooth[:,0], carrollLCDepressedACTH_rearr_smooth[:,1], label = "Low Cortisol Depressed - Smoothed")
ax4.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax4.legend(loc="upper right", shadow = True, fancybox = True)

# %%
# %matplotlib inline

fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(nrows = 6, figsize = (15,20))

ax1.plot(golierPTSDCortisol_rearr_smooth[:,0], golierPTSDCortisol_rearr_smooth[:,1], label = "Trauma Exposed PTSD Cortisol - Smoothed")
ax1.plot(golierPTSDCortisol_rearr[:,0], golierPTSDCortisol_rearr[:,1], label = "Trauma Exposed PTSD Cortisol")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (mg/dL)")
ax1.legend(loc="lower right", shadow = True, fancybox = True)

ax2.plot(golierNonPTSDTraumaExposedCortisol_rearr_smooth[:,0], golierNonPTSDTraumaExposedCortisol_rearr_smooth[:,1], label = "Trauma Exposed Non-PTSD Cortisol - Smoothed")
ax2.plot(golierNonPTSDTraumaExposedCortisol_rearr[:,0], golierNonPTSDTraumaExposedCortisol_rearr[:,1], label = "Trauma Exposed Non-PTSD Cortisol")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (mg/dL)")
ax2.legend(loc="lower right", shadow = True, fancybox = True)

ax3.plot(golierNonPTSDNonExposedCortisol_rearr_smooth[:,0], golierNonPTSDNonExposedCortisol_rearr_smooth[:,1], label = "Non-Exposed Non-PTSD Cortisol - Smoothed")
ax3.plot(golierNonPTSDNonExposedCortisol_rearr[:,0], golierNonPTSDNonExposedCortisol_rearr[:,1], label = "Non-Exposed Non-PTSD Cortisol")
ax3.set(xlabel="Time (hours)", ylabel="Cortisol (mg/dL)")
ax3.legend(loc="lower right", shadow = True, fancybox = True)

ax4.plot(golierPTSDACTH_rearr_smooth[:,0], golierPTSDACTH_rearr_smooth[:,1], label = "Trauma Exposed PTSD ACTH - Smoothed")
ax4.plot(golierPTSDACTH_rearr[:,0], golierPTSDACTH_rearr[:,1], label = "Trauma Exposed PTSD ACTH")
ax4.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax4.legend(loc="lower right", shadow = True, fancybox = True)

ax5.plot(golierNonPTSDTraumaExposedACTH_rearr_smooth[:,0], golierNonPTSDTraumaExposedACTH_rearr_smooth[:,1], label = "Trauma Exposed Non-PTSD ACTH - Smoothed")
ax5.plot(golierNonPTSDTraumaExposedACTH_rearr[:,0], golierNonPTSDTraumaExposedACTH_rearr[:,1], label = "Trauma Exposed Non-PTSD ACTH")
ax5.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax5.legend(loc="lower right", shadow = True, fancybox = True)

ax6.plot(golierNonPTSDNonExposedACTH_rearr_smooth[:,0], golierNonPTSDNonExposedACTH_rearr_smooth[:,1], label = "Non-Exposed Non-PTSD ACTH - Smoothed")
ax6.plot(golierNonPTSDNonExposedACTH_rearr[:,0], golierNonPTSDNonExposedACTH_rearr[:,1], label = "Non-Exposed Non-PTSD ACTH")
ax6.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax6.legend(loc="lower right", shadow = True, fancybox = True)

# %%
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (15,15))

ax1.plot(bremnerAbusedPTSDCortisol_rearr_smooth[:,0], bremnerAbusedPTSDCortisol_rearr_smooth[:,1], label = "Abused PTSD Cortisol - Smoothed")
ax1.plot(bremnerAbusedPTSDCortisol_rearr[:,0], bremnerAbusedPTSDCortisol_rearr[:,1], label = "Abused PTSD Cortisol")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (microg/dL)")
ax1.legend(loc="lower right", shadow = True, fancybox = True)

ax2.plot(bremnerNonAbusedPTSDCortisol_rearr_smooth[:,0], bremnerNonAbusedPTSDCortisol_rearr_smooth[:,1], label = "Non-Abused PTSD Cortisol - Smoothed")
ax2.plot(bremnerNonAbusedPTSDCortisol_rearr[:,0], bremnerNonAbusedPTSDCortisol_rearr[:,1], label = "Non-Abused PTSD Cortisol")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (microg/dL)")
ax2.legend(loc="lower right", shadow = True, fancybox = True)

ax3.plot(bremnerNonAbusedNonPTSDCortisol_rearr_smooth[:,0], bremnerNonAbusedNonPTSDCortisol_rearr_smooth[:,1], label = "Non-Abused Non-PTSD Cortisol - Smoothed")
ax3.plot(bremnerNonAbusedNonPTSDCortisol_rearr[:,0], bremnerNonAbusedNonPTSDCortisol_rearr[:,1], label = "Non-Abused Non-PTSD Cortisol")
ax3.set(xlabel="Time (hours)", ylabel="Cortisol (microg/dL)")
ax3.legend(loc="lower left", shadow = True, fancybox = True)

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (15, 15))

ax1.plot(nelsonACTH[:,0], nelsonACTH[:,3])
ax2.plot(nelsonCortisol[:,0], nelsonCortisol[:,3])

# %%
# graph the Nelson data (only showing one patient at a time currently)
fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (15, 15))

#ax1.plot(nelsonACTH[:,0], nelsonACTH[:,1])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,0])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,1])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,2])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,3])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,4])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,5])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,6])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,7])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,8])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,9])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,10])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,11])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,12])
ax1.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,13])

#ax2.plot(nelsonCortisol[:,0], nelsonCortisol[:,1])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,0])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,1])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,2])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,3])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,4])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,5])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,6])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,7])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,8])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,9])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,10])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,11])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,12])
ax2.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,13])

# %%
# graph the Nelson data (only showing one patient at a time currently)
fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (15, 15))

#ax1.plot(nelsonACTH[:,0], nelsonACTH[:,1])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,0])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,1])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,2])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,3])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,4])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,5])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,6])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,7])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,8])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,9])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,10])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,11])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,12])
ax1.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,13])

#ax2.plot(nelsonCortisol[:,0], nelsonCortisol[:,1])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,0])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,1])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,2])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,3])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,4])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,5])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,6])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,7])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,8])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,9])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,10])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,11])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,12])
ax2.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,13])

# %%
nelsonHealthyCortisol_mean = np.zeros(len(nelsonHealthyCortisol[:,0]))
nelsonHealthyACTH_mean = np.zeros(len(nelsonHealthyACTH[:,0]))
nelsonDepressedCortisol_mean = np.zeros(len(nelsonMelancholicCortisol[:,0]))
nelsonDepressedACTH_mean = np.zeros(len(nelsonMelancholicACTH[:,0]))

for i in range(len(nelsonHealthyCortisol[:,0])):
    nelsonHealthyCortisol_mean += np.sum(nelsonHealthyCortisol[i,:])
    nelsonDepressedCortisol_mean += np.sum(nelsonMelancholicCortisol[i,:])
    nelsonDepressedCortisol_mean += np.sum(nelsonAtypicalCortisol[i,:])
    nelsonDepressedCortisol_mean += np.sum(nelsonNeitherCortisol[i,:])
    
    nelsonHealthyACTH_mean += np.sum(nelsonHealthyACTH[i,:])
    nelsonDepressedACTH_mean += np.sum(nelsonMelancholicACTH[i,:])
    nelsonDepressedACTH_mean += np.sum(nelsonAtypicalACTH[i,:])
    nelsonDepressedACTH_mean += np.sum(nelsonNeitherACTH[i,:])
    
nelsonHealthyCortisol_mean = nelsonHealthyCortisol_mean/

# %%
print(nelsonHealthyCortisol_mean, nelsonDepressedCortisol_mean, nelsonHealthyACTH_mean, nelsonDepressedACTH_mean)
# Out:
# [1754.6300375 1754.6300375 1754.6300375 1754.6300375 1754.6300375
#  1754.6300375 1754.6300375 1754.6300375 1754.6300375 1754.6300375
#  1754.6300375] [3811.7241875 3811.7241875 3811.7241875 3811.7241875 3811.7241875
#  3811.7241875 3811.7241875 3811.7241875 3811.7241875 3811.7241875
#  3811.7241875] [4383.2979875 4383.2979875 4383.2979875 4383.2979875 4383.2979875
#  4383.2979875 4383.2979875 4383.2979875 4383.2979875 4383.2979875
#  4383.2979875] [11690.26140625 11690.26140625 11690.26140625 11690.26140625
#  11690.26140625 11690.26140625 11690.26140625 11690.26140625
#  11690.26140625 11690.26140625 11690.26140625]

# %%
# %matplotlib inline

fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (15,15))

ax1.plot()

# %% [markdown]
# ## Model Function--Includes ODE Solver <a name="modelfunction"></a>

# %%
def model(params, ics):
    def ode_system(t, y):
        dy = np.zeros(4)
        # parameters to be optimized including p_stress
        [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress] = params
        
        # parameters to be optimized not including p_stress
        #[k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5] = params
        
        # Change whether we use the stress_input function to add a time-dependent stressor by changing which equation
        #  for dy[0] is not commented
        dy[0] = stress_input(t)*k_stress*(k_i**n2/(k_i**n2 + y[3]**n2)) - V_S3*(y[0]/(K_m1 + y[0])) - K_d1*y[0]
        #dy[0] = k_stress*(k_i**n2/(k_i**n2 + y[3]**n2)) - V_S3*(y[0]/(K_m1 + y[0])) - K_d1*y[0]
        dy[1] = K_P2*y[0]*(k_i**n2/(k_i**n2 + y[3]**n2)) - V_S4*(y[1]/(K_m2 + y[1])) - K_d2*y[1]
        dy[2] = K_P3*y[1] - V_S5*(y[2]/(K_m3 + y[2])) - K_d3*y[2]
        dy[3] = K_b*y[2]*(G_tot - y[3]) + V_S2*(y[3]**n1/(K1**n1 + y[3]**n1)) - K_d5*y[3]

        return dy
    
    def stress_input(t):
        #if (0.5 <= t <= 0.51):
        if (0.5 <= t <= 0.83):
            return p_stress
        else:
            return 1
    
    timeSeries = ODEsolver.solve(ode_system, ics, t_start, t_step, t_end, ode_steps=1000, ode_atol = 1e-8, ode_rtol = 1e-8)
    return timeSeries

# %% [markdown]
# ## Cost Function Definition <a name="cost"></a>

# %%
def cost_fun(params):
    simData = model(params, y0)
    
    return costFun.cost(params, nelsonACTH[:,0], nelsonMelancholicACTH[:,12], nelsonCortisol[:,0], nelsonMelancholicCortisol[:,12], simData)

# %% [markdown]
# ## Run the Optimization <a name="run"></a>

# %%
# it looks, based on the XPP file from the authors, like they start CRH, ACTH, CORT and GR at 0 each and just run
# the solver until they reach some steady state

y0 = [1, nelsonMelancholicACTH[0,12], nelsonMelancholicCortisol[0,12], 2]
print(y0)
# Out:
# [1, 26.9, 6.7, 2]

# %%
# number of times to run the optimization
n = 5

# define an array to hold the population of parameter vectors
opt_pars = np.zeros((n, len(bounds)+1))

# initialize arrays to save simulation cortisol and ACTH data from each optimization
sims_cort = np.zeros((237, n))
sims_acth = np.zeros((237, n))
sims_crh = np.zeros((237, n))
sims_gr = np.zeros((237, n))

# %%
# %%time

# loop n times, running the optimization each time
for i in range(0,n):
    
    print(f"Optimization Run #{i+1}")
    
    # call the differential evolution optimization function on the cost function
    res = sco.differential_evolution(cost_fun, bounds, maxiter = 300, disp = True, popsize = 1)
    
    # alternatively, we can run the SHGO algorithm with the sampling_method = "sobol" flag to do global
    #     optimization with reporting all local minima, as well
    #res = sco.shgo(cost_fun, bounds, callback=callback_fun(*shgo_iter_steps), options = {"f_min": 0.1, "maxiter": None, "minimize_every_iter": True, "local_iter": False, "disp": True}, iters = 3)
    #res = sco.basinhopping(cost_fun, x0, niter = 1000)
    #res = sco.dual_annealing(cost_fun, bounds)
    
    # plug the optimized parameters into the solver
    optimizedSimData = model(res.x, y0)
    # save CRH, cortisol and ACTH data into sims arrays
    sims_gr[:,i] = optimizedSimData[:,4]
    sims_cort[:,i] = optimizedSimData[:,3]
    sims_acth[:,i] = optimizedSimData[:,2]
    sims_crh[:,i] = optimizedSimData[:,1]
    
    # save the cost function values and optimized parameters for each iteration into the array opt_pars
    opt_pars[i,0] = res.fun
    opt_pars[i,1:] = res.x
# Out:
# Optimization Run #1
# differential_evolution step 1: f(x)= 2.58064
# differential_evolution step 2: f(x)= 2.47093
# differential_evolution step 3: f(x)= 2.47093
# differential_evolution step 4: f(x)= 2.47093
# differential_evolution step 5: f(x)= 2.01973
# differential_evolution step 6: f(x)= 2.01973
# differential_evolution step 7: f(x)= 2.01973
# differential_evolution step 8: f(x)= 2.01973
# differential_evolution step 9: f(x)= 2.01973
# differential_evolution step 10: f(x)= 1.77268
# differential_evolution step 11: f(x)= 1.77268
# differential_evolution step 12: f(x)= 1.77268
# differential_evolution step 13: f(x)= 1.70709
# differential_evolution step 14: f(x)= 1.59325
# differential_evolution step 15: f(x)= 1.59325
# differential_evolution step 16: f(x)= 1.58687
# differential_evolution step 17: f(x)= 1.50097
# differential_evolution step 18: f(x)= 1.34008
# differential_evolution step 19: f(x)= 1.16086
# differential_evolution step 20: f(x)= 1.16086
# differential_evolution step 21: f(x)= 1.16086
# differential_evolution step 22: f(x)= 1.16086
# differential_evolution step 23: f(x)= 1.16086
# differential_evolution step 24: f(x)= 1.16086
# differential_evolution step 25: f(x)= 1.16086
# differential_evolution step 26: f(x)= 1.16086
# differential_evolution step 27: f(x)= 1.16086
# differential_evolution step 28: f(x)= 1.16086
# differential_evolution step 29: f(x)= 1.09183
# differential_evolution step 30: f(x)= 1.09183
# differential_evolution step 31: f(x)= 1.09183
# differential_evolution step 32: f(x)= 1.09183
# differential_evolution step 33: f(x)= 1.04785
# differential_evolution step 34: f(x)= 1.04785
# differential_evolution step 35: f(x)= 1.04785
# differential_evolution step 36: f(x)= 1.04785
# differential_evolution step 37: f(x)= 1.04785
# differential_evolution step 38: f(x)= 1.04785
# differential_evolution step 39: f(x)= 1.04785
# differential_evolution step 40: f(x)= 1.04785
# differential_evolution step 41: f(x)= 1.04785
# differential_evolution step 42: f(x)= 1.04785
# differential_evolution step 43: f(x)= 1.04785
# differential_evolution step 44: f(x)= 1.04785
# differential_evolution step 45: f(x)= 1.04785
# differential_evolution step 46: f(x)= 1.04785
# differential_evolution step 47: f(x)= 1.04785
# differential_evolution step 48: f(x)= 1.04785
# differential_evolution step 49: f(x)= 1.04785
# differential_evolution step 50: f(x)= 1.04785
# differential_evolution step 51: f(x)= 1.04785
# differential_evolution step 52: f(x)= 1.04785
# differential_evolution step 53: f(x)= 1.04785
# differential_evolution step 54: f(x)= 1.04785
# differential_evolution step 55: f(x)= 1.04785
# differential_evolution step 56: f(x)= 1.04785
# differential_evolution step 57: f(x)= 1.04785
# differential_evolution step 58: f(x)= 1.04785
# differential_evolution step 59: f(x)= 1.04785
# differential_evolution step 60: f(x)= 1.04612
# differential_evolution step 61: f(x)= 1.04612
# differential_evolution step 62: f(x)= 1.04612
# differential_evolution step 63: f(x)= 1.04612
# differential_evolution step 64: f(x)= 1.04612
# differential_evolution step 65: f(x)= 1.04612
# differential_evolution step 66: f(x)= 1.04049
# differential_evolution step 67: f(x)= 1.00434
# differential_evolution step 68: f(x)= 1.00434
# differential_evolution step 69: f(x)= 0.987809
# differential_evolution step 70: f(x)= 0.987809
# differential_evolution step 71: f(x)= 0.987809
# differential_evolution step 72: f(x)= 0.987809
# differential_evolution step 73: f(x)= 0.974302
# differential_evolution step 74: f(x)= 0.974302
# differential_evolution step 75: f(x)= 0.974302
# differential_evolution step 76: f(x)= 0.974302
# differential_evolution step 77: f(x)= 0.974302
# differential_evolution step 78: f(x)= 0.974302
# differential_evolution step 79: f(x)= 0.974302
# differential_evolution step 80: f(x)= 0.974302
# differential_evolution step 81: f(x)= 0.974302
# differential_evolution step 82: f(x)= 0.974302
# differential_evolution step 83: f(x)= 0.974302
# differential_evolution step 84: f(x)= 0.974302
# differential_evolution step 85: f(x)= 0.974302
# differential_evolution step 86: f(x)= 0.974302
# differential_evolution step 87: f(x)= 0.974278
# differential_evolution step 88: f(x)= 0.953548
# differential_evolution step 89: f(x)= 0.953548
# differential_evolution step 90: f(x)= 0.953548
# differential_evolution step 91: f(x)= 0.953548
# differential_evolution step 92: f(x)= 0.953548
# differential_evolution step 93: f(x)= 0.950936
# differential_evolution step 94: f(x)= 0.936754
# differential_evolution step 95: f(x)= 0.936754
# differential_evolution step 96: f(x)= 0.936754
# differential_evolution step 97: f(x)= 0.936754
# differential_evolution step 98: f(x)= 0.936754
# differential_evolution step 99: f(x)= 0.936754
# differential_evolution step 100: f(x)= 0.930792
# differential_evolution step 101: f(x)= 0.930792
# differential_evolution step 102: f(x)= 0.930792
# differential_evolution step 103: f(x)= 0.930792
# differential_evolution step 104: f(x)= 0.928837
# differential_evolution step 105: f(x)= 0.928837
# differential_evolution step 106: f(x)= 0.928837
# differential_evolution step 107: f(x)= 0.928837
# differential_evolution step 108: f(x)= 0.928837
# differential_evolution step 109: f(x)= 0.928837
# differential_evolution step 110: f(x)= 0.928837
# differential_evolution step 111: f(x)= 0.928837
# differential_evolution step 112: f(x)= 0.928837
# differential_evolution step 113: f(x)= 0.928837
# differential_evolution step 114: f(x)= 0.928837
# differential_evolution step 115: f(x)= 0.928837
# differential_evolution step 116: f(x)= 0.928837
# differential_evolution step 117: f(x)= 0.927727
# differential_evolution step 118: f(x)= 0.927727
# differential_evolution step 119: f(x)= 0.927727
# differential_evolution step 120: f(x)= 0.927727
# differential_evolution step 121: f(x)= 0.924631
# differential_evolution step 122: f(x)= 0.924631
# differential_evolution step 123: f(x)= 0.924631
# Optimization Run #2
# differential_evolution step 1: f(x)= 1.88285
# differential_evolution step 2: f(x)= 1.88285
# differential_evolution step 3: f(x)= 1.88285
# differential_evolution step 4: f(x)= 1.88285
# differential_evolution step 5: f(x)= 1.76792
# differential_evolution step 6: f(x)= 1.76792
# differential_evolution step 7: f(x)= 1.76792
# differential_evolution step 8: f(x)= 1.76792
# differential_evolution step 9: f(x)= 1.76792
# differential_evolution step 10: f(x)= 1.76792
# differential_evolution step 11: f(x)= 1.76792
# differential_evolution step 12: f(x)= 1.73928
# differential_evolution step 13: f(x)= 1.67778
# differential_evolution step 14: f(x)= 1.67778
# differential_evolution step 15: f(x)= 1.67046
# differential_evolution step 16: f(x)= 1.67046
# differential_evolution step 17: f(x)= 1.62171
# differential_evolution step 18: f(x)= 1.62171
# differential_evolution step 19: f(x)= 1.62171
# differential_evolution step 20: f(x)= 1.62171
# differential_evolution step 21: f(x)= 1.40952
# differential_evolution step 22: f(x)= 1.40952
# differential_evolution step 23: f(x)= 1.40665
# differential_evolution step 24: f(x)= 1.40665
# differential_evolution step 25: f(x)= 1.25077
# differential_evolution step 26: f(x)= 1.25077
# differential_evolution step 27: f(x)= 1.25077
# differential_evolution step 28: f(x)= 1.25077
# differential_evolution step 29: f(x)= 1.25077
# differential_evolution step 30: f(x)= 1.25077
# differential_evolution step 31: f(x)= 1.25077
# differential_evolution step 32: f(x)= 1.25077
# differential_evolution step 33: f(x)= 1.25077
# differential_evolution step 34: f(x)= 1.25077
# differential_evolution step 35: f(x)= 1.25077
# differential_evolution step 36: f(x)= 1.25077
# differential_evolution step 37: f(x)= 1.25077
# differential_evolution step 38: f(x)= 1.23225
# differential_evolution step 39: f(x)= 1.23225
# differential_evolution step 40: f(x)= 1.2135
# differential_evolution step 41: f(x)= 1.2135
# differential_evolution step 42: f(x)= 1.16676
# differential_evolution step 43: f(x)= 1.16676
# differential_evolution step 44: f(x)= 1.16676
# differential_evolution step 45: f(x)= 1.16676
# differential_evolution step 46: f(x)= 1.16676
# differential_evolution step 47: f(x)= 1.16676
# differential_evolution step 48: f(x)= 1.16058
# differential_evolution step 49: f(x)= 1.1434
# differential_evolution step 50: f(x)= 1.1434
# differential_evolution step 51: f(x)= 1.1434
# differential_evolution step 52: f(x)= 1.1434
# differential_evolution step 53: f(x)= 1.1434
# differential_evolution step 54: f(x)= 1.1434
# differential_evolution step 55: f(x)= 1.12103
# differential_evolution step 56: f(x)= 1.10713
# differential_evolution step 57: f(x)= 1.10713
# differential_evolution step 58: f(x)= 1.09699
# differential_evolution step 59: f(x)= 1.09699
# differential_evolution step 60: f(x)= 1.0901
# differential_evolution step 61: f(x)= 1.0901
# differential_evolution step 62: f(x)= 1.087
# differential_evolution step 63: f(x)= 1.06106
# differential_evolution step 64: f(x)= 1.06106
# differential_evolution step 65: f(x)= 1.05971
# differential_evolution step 66: f(x)= 1.05928
# differential_evolution step 67: f(x)= 1.05928
# differential_evolution step 68: f(x)= 1.04963
# differential_evolution step 69: f(x)= 1.04963
# differential_evolution step 70: f(x)= 1.01339
# differential_evolution step 71: f(x)= 1.01339
# differential_evolution step 72: f(x)= 1.01339
# differential_evolution step 73: f(x)= 1.01339
# differential_evolution step 74: f(x)= 1.01339
# differential_evolution step 75: f(x)= 1.01339
# differential_evolution step 76: f(x)= 1.01339
# differential_evolution step 77: f(x)= 1.01339
# differential_evolution step 78: f(x)= 1.01339
# differential_evolution step 79: f(x)= 1.01339
# differential_evolution step 80: f(x)= 1.01339
# differential_evolution step 81: f(x)= 1.01339
# differential_evolution step 82: f(x)= 1.01339
# differential_evolution step 83: f(x)= 1.00306
# differential_evolution step 84: f(x)= 0.99609
# differential_evolution step 85: f(x)= 0.980453
# differential_evolution step 86: f(x)= 0.980453
# differential_evolution step 87: f(x)= 0.977503
# differential_evolution step 88: f(x)= 0.977503
# differential_evolution step 89: f(x)= 0.977503
# differential_evolution step 90: f(x)= 0.977503
# differential_evolution step 91: f(x)= 0.977503
# differential_evolution step 92: f(x)= 0.977503
# differential_evolution step 93: f(x)= 0.977503
# differential_evolution step 94: f(x)= 0.977503
# differential_evolution step 95: f(x)= 0.977503
# differential_evolution step 96: f(x)= 0.977503
# differential_evolution step 97: f(x)= 0.977503
# differential_evolution step 98: f(x)= 0.977503
# differential_evolution step 99: f(x)= 0.977503
# differential_evolution step 100: f(x)= 0.977503
# differential_evolution step 101: f(x)= 0.977503
# differential_evolution step 102: f(x)= 0.972583
# differential_evolution step 103: f(x)= 0.972583
# differential_evolution step 104: f(x)= 0.972583
# differential_evolution step 105: f(x)= 0.96771
# differential_evolution step 106: f(x)= 0.965458
# differential_evolution step 107: f(x)= 0.965458
# differential_evolution step 108: f(x)= 0.965458
# differential_evolution step 109: f(x)= 0.965458
# differential_evolution step 110: f(x)= 0.965458
# differential_evolution step 111: f(x)= 0.965458
# differential_evolution step 112: f(x)= 0.965458
# differential_evolution step 113: f(x)= 0.965458
# differential_evolution step 114: f(x)= 0.965458
# differential_evolution step 115: f(x)= 0.965458
# differential_evolution step 116: f(x)= 0.965458
# differential_evolution step 117: f(x)= 0.965458
# differential_evolution step 118: f(x)= 0.965458
# differential_evolution step 119: f(x)= 0.965458
# differential_evolution step 120: f(x)= 0.965458
# differential_evolution step 121: f(x)= 0.965458
# differential_evolution step 122: f(x)= 0.965458
# differential_evolution step 123: f(x)= 0.965458
# differential_evolution step 124: f(x)= 0.965458
# Optimization Run #3
# differential_evolution step 1: f(x)= 2.29917
# differential_evolution step 2: f(x)= 2.15963
# differential_evolution step 3: f(x)= 2.15963
# differential_evolution step 4: f(x)= 1.73775
# differential_evolution step 5: f(x)= 1.73775
# differential_evolution step 6: f(x)= 1.73775
# differential_evolution step 7: f(x)= 1.73775
# differential_evolution step 8: f(x)= 1.6101
# differential_evolution step 9: f(x)= 1.6101
# differential_evolution step 10: f(x)= 1.6101
# differential_evolution step 11: f(x)= 1.6101
# differential_evolution step 12: f(x)= 1.6101
# differential_evolution step 13: f(x)= 1.6101
# differential_evolution step 14: f(x)= 1.6101
# differential_evolution step 15: f(x)= 1.60186
# differential_evolution step 16: f(x)= 1.58445
# differential_evolution step 17: f(x)= 1.58445
# differential_evolution step 18: f(x)= 1.47568
# differential_evolution step 19: f(x)= 1.47568
# differential_evolution step 20: f(x)= 1.47568
# differential_evolution step 21: f(x)= 1.43683
# differential_evolution step 22: f(x)= 1.43683
# differential_evolution step 23: f(x)= 1.43683
# differential_evolution step 24: f(x)= 1.43683
# differential_evolution step 25: f(x)= 1.43683
# differential_evolution step 26: f(x)= 1.31917
# differential_evolution step 27: f(x)= 1.30424
# differential_evolution step 28: f(x)= 1.30424
# differential_evolution step 29: f(x)= 1.30424
# differential_evolution step 30: f(x)= 1.30424
# differential_evolution step 31: f(x)= 1.17377
# differential_evolution step 32: f(x)= 1.17377
# differential_evolution step 33: f(x)= 1.17377
# differential_evolution step 34: f(x)= 1.17377
# differential_evolution step 35: f(x)= 1.17377
# differential_evolution step 36: f(x)= 1.12516
# differential_evolution step 37: f(x)= 1.12516
# differential_evolution step 38: f(x)= 1.12516
# differential_evolution step 39: f(x)= 1.12516
# differential_evolution step 40: f(x)= 1.12516
# differential_evolution step 41: f(x)= 1.12516
# differential_evolution step 42: f(x)= 1.12516
# differential_evolution step 43: f(x)= 1.12516
# differential_evolution step 44: f(x)= 1.12516
# differential_evolution step 45: f(x)= 1.11125
# differential_evolution step 46: f(x)= 1.11125
# differential_evolution step 47: f(x)= 1.09891
# differential_evolution step 48: f(x)= 1.07249
# differential_evolution step 49: f(x)= 1.07249
# differential_evolution step 50: f(x)= 1.07249
# differential_evolution step 51: f(x)= 1.07249
# differential_evolution step 52: f(x)= 1.07249
# differential_evolution step 53: f(x)= 1.07249
# differential_evolution step 54: f(x)= 1.07249
# differential_evolution step 55: f(x)= 1.07249
# differential_evolution step 56: f(x)= 1.06935
# differential_evolution step 57: f(x)= 1.06239
# differential_evolution step 58: f(x)= 1.06239
# differential_evolution step 59: f(x)= 1.0493
# differential_evolution step 60: f(x)= 1.04598
# differential_evolution step 61: f(x)= 1.02103
# differential_evolution step 62: f(x)= 1.00866
# differential_evolution step 63: f(x)= 0.972483
# differential_evolution step 64: f(x)= 0.972483
# differential_evolution step 65: f(x)= 0.972483
# differential_evolution step 66: f(x)= 0.972483
# differential_evolution step 67: f(x)= 0.972483
# differential_evolution step 68: f(x)= 0.972483
# differential_evolution step 69: f(x)= 0.972483
# differential_evolution step 70: f(x)= 0.972483
# differential_evolution step 71: f(x)= 0.972483
# differential_evolution step 72: f(x)= 0.972483
# differential_evolution step 73: f(x)= 0.972483
# differential_evolution step 74: f(x)= 0.971515
# differential_evolution step 75: f(x)= 0.953956
# differential_evolution step 76: f(x)= 0.950894
# differential_evolution step 77: f(x)= 0.944465
# differential_evolution step 78: f(x)= 0.944465
# differential_evolution step 79: f(x)= 0.938303
# differential_evolution step 80: f(x)= 0.938303
# differential_evolution step 81: f(x)= 0.938303
# differential_evolution step 82: f(x)= 0.930563
# differential_evolution step 83: f(x)= 0.923142
# differential_evolution step 84: f(x)= 0.923142
# differential_evolution step 85: f(x)= 0.923142
# differential_evolution step 86: f(x)= 0.923142
# differential_evolution step 87: f(x)= 0.923142
# differential_evolution step 88: f(x)= 0.923142
# differential_evolution step 89: f(x)= 0.918778
# differential_evolution step 90: f(x)= 0.918778
# differential_evolution step 91: f(x)= 0.918778
# differential_evolution step 92: f(x)= 0.918778
# differential_evolution step 93: f(x)= 0.918778
# differential_evolution step 94: f(x)= 0.918778
# differential_evolution step 95: f(x)= 0.918778
# differential_evolution step 96: f(x)= 0.91614
# differential_evolution step 97: f(x)= 0.91614
# differential_evolution step 98: f(x)= 0.91614
# differential_evolution step 99: f(x)= 0.91614
# differential_evolution step 100: f(x)= 0.91614
# differential_evolution step 101: f(x)= 0.91614
# differential_evolution step 102: f(x)= 0.913754
# differential_evolution step 103: f(x)= 0.907843
# differential_evolution step 104: f(x)= 0.894412
# differential_evolution step 105: f(x)= 0.894412
# differential_evolution step 106: f(x)= 0.894412
# differential_evolution step 107: f(x)= 0.894412
# differential_evolution step 108: f(x)= 0.894412
# differential_evolution step 109: f(x)= 0.894412
# differential_evolution step 110: f(x)= 0.894412
# differential_evolution step 111: f(x)= 0.894412
# differential_evolution step 112: f(x)= 0.894412
# differential_evolution step 113: f(x)= 0.894412
# differential_evolution step 114: f(x)= 0.894412
# differential_evolution step 115: f(x)= 0.894412
# differential_evolution step 116: f(x)= 0.894412
# differential_evolution step 117: f(x)= 0.894412
# differential_evolution step 118: f(x)= 0.894412
# differential_evolution step 119: f(x)= 0.894412
# differential_evolution step 120: f(x)= 0.894412
# differential_evolution step 121: f(x)= 0.894412
# differential_evolution step 122: f(x)= 0.886834
# differential_evolution step 123: f(x)= 0.886399
# differential_evolution step 124: f(x)= 0.886399
# differential_evolution step 125: f(x)= 0.886399
# differential_evolution step 126: f(x)= 0.883822
# differential_evolution step 127: f(x)= 0.883822
# differential_evolution step 128: f(x)= 0.883822
# differential_evolution step 129: f(x)= 0.882823
# differential_evolution step 130: f(x)= 0.882823
# differential_evolution step 131: f(x)= 0.8806
# differential_evolution step 132: f(x)= 0.8806
# differential_evolution step 133: f(x)= 0.8806
# differential_evolution step 134: f(x)= 0.8806
# differential_evolution step 135: f(x)= 0.8806
# differential_evolution step 136: f(x)= 0.8806
# differential_evolution step 137: f(x)= 0.8806
# differential_evolution step 138: f(x)= 0.8806
# differential_evolution step 139: f(x)= 0.8806
# differential_evolution step 140: f(x)= 0.8806
# differential_evolution step 141: f(x)= 0.8806
# differential_evolution step 142: f(x)= 0.8806
# differential_evolution step 143: f(x)= 0.8806
# differential_evolution step 144: f(x)= 0.8806
# differential_evolution step 145: f(x)= 0.8806
# differential_evolution step 146: f(x)= 0.8806
# differential_evolution step 147: f(x)= 0.8806
# differential_evolution step 148: f(x)= 0.877535
# differential_evolution step 149: f(x)= 0.877535
# differential_evolution step 150: f(x)= 0.877535
# Optimization Run #4
# differential_evolution step 1: f(x)= 2.30475
# differential_evolution step 2: f(x)= 2.20877
# differential_evolution step 3: f(x)= 2.15387
# differential_evolution step 4: f(x)= 2.15387
# differential_evolution step 5: f(x)= 2.02551
# differential_evolution step 6: f(x)= 2.02551
# differential_evolution step 7: f(x)= 1.82041
# differential_evolution step 8: f(x)= 1.79114
# differential_evolution step 9: f(x)= 1.79114
# differential_evolution step 10: f(x)= 1.7347
# differential_evolution step 11: f(x)= 1.58141
# differential_evolution step 12: f(x)= 1.58141
# differential_evolution step 13: f(x)= 1.58141
# differential_evolution step 14: f(x)= 1.58141
# differential_evolution step 15: f(x)= 1.45856
# differential_evolution step 16: f(x)= 1.45856
# differential_evolution step 17: f(x)= 1.45856
# differential_evolution step 18: f(x)= 1.45856
# differential_evolution step 19: f(x)= 1.45856
# differential_evolution step 20: f(x)= 1.45856
# differential_evolution step 21: f(x)= 1.45856
# differential_evolution step 22: f(x)= 1.45856
# differential_evolution step 23: f(x)= 1.45856
# differential_evolution step 24: f(x)= 1.45856
# differential_evolution step 25: f(x)= 1.45856
# differential_evolution step 26: f(x)= 1.45856
# differential_evolution step 27: f(x)= 1.45856
# differential_evolution step 28: f(x)= 1.45856
# differential_evolution step 29: f(x)= 1.45856
# differential_evolution step 30: f(x)= 1.4446
# differential_evolution step 31: f(x)= 1.4446
# differential_evolution step 32: f(x)= 1.4446
# differential_evolution step 33: f(x)= 1.4446
# differential_evolution step 34: f(x)= 1.4446
# differential_evolution step 35: f(x)= 1.4446
# differential_evolution step 36: f(x)= 1.4446
# differential_evolution step 37: f(x)= 1.42949
# differential_evolution step 38: f(x)= 1.42949
# differential_evolution step 39: f(x)= 1.42949
# differential_evolution step 40: f(x)= 1.42949
# differential_evolution step 41: f(x)= 1.42645
# differential_evolution step 42: f(x)= 1.42645
# differential_evolution step 43: f(x)= 1.42645
# differential_evolution step 44: f(x)= 1.42645
# differential_evolution step 45: f(x)= 1.42645
# differential_evolution step 46: f(x)= 1.42645
# differential_evolution step 47: f(x)= 1.37027
# differential_evolution step 48: f(x)= 1.37027
# differential_evolution step 49: f(x)= 1.32482
# differential_evolution step 50: f(x)= 1.31343
# differential_evolution step 51: f(x)= 1.31343
# differential_evolution step 52: f(x)= 1.29728
# differential_evolution step 53: f(x)= 1.29728
# differential_evolution step 54: f(x)= 1.29728
# differential_evolution step 55: f(x)= 1.29728
# differential_evolution step 56: f(x)= 1.28467
# differential_evolution step 57: f(x)= 1.25486
# differential_evolution step 58: f(x)= 1.25486
# differential_evolution step 59: f(x)= 1.22749
# differential_evolution step 60: f(x)= 1.20013
# differential_evolution step 61: f(x)= 1.20013
# differential_evolution step 62: f(x)= 1.14936
# differential_evolution step 63: f(x)= 1.14936
# differential_evolution step 64: f(x)= 1.14936
# differential_evolution step 65: f(x)= 1.08548
# differential_evolution step 66: f(x)= 1.08548
# differential_evolution step 67: f(x)= 1.08548
# differential_evolution step 68: f(x)= 1.08548
# differential_evolution step 69: f(x)= 1.0779
# differential_evolution step 70: f(x)= 1.0779
# differential_evolution step 71: f(x)= 1.0779
# differential_evolution step 72: f(x)= 1.0779
# differential_evolution step 73: f(x)= 1.05742
# differential_evolution step 74: f(x)= 1.05742
# differential_evolution step 75: f(x)= 1.05742
# differential_evolution step 76: f(x)= 1.05742
# differential_evolution step 77: f(x)= 1.05742
# differential_evolution step 78: f(x)= 1.05461
# differential_evolution step 79: f(x)= 1.05461
# differential_evolution step 80: f(x)= 1.0398
# differential_evolution step 81: f(x)= 1.0398
# differential_evolution step 82: f(x)= 1.03132
# differential_evolution step 83: f(x)= 1.03132
# differential_evolution step 84: f(x)= 1.02633
# differential_evolution step 85: f(x)= 1.0108
# differential_evolution step 86: f(x)= 1.0108
# differential_evolution step 87: f(x)= 1.0108
# differential_evolution step 88: f(x)= 1.0108
# differential_evolution step 89: f(x)= 1.0108
# differential_evolution step 90: f(x)= 1.0108
# differential_evolution step 91: f(x)= 1.0108
# differential_evolution step 92: f(x)= 0.988389
# differential_evolution step 93: f(x)= 0.988389
# differential_evolution step 94: f(x)= 0.988389
# differential_evolution step 95: f(x)= 0.988389
# differential_evolution step 96: f(x)= 0.970587
# differential_evolution step 97: f(x)= 0.970587
# differential_evolution step 98: f(x)= 0.970587
# differential_evolution step 99: f(x)= 0.970587
# differential_evolution step 100: f(x)= 0.970587
# differential_evolution step 101: f(x)= 0.970587
# differential_evolution step 102: f(x)= 0.970587
# differential_evolution step 103: f(x)= 0.970587
# differential_evolution step 104: f(x)= 0.970587
# differential_evolution step 105: f(x)= 0.970587
# differential_evolution step 106: f(x)= 0.946488
# differential_evolution step 107: f(x)= 0.946488
# differential_evolution step 108: f(x)= 0.946488
# differential_evolution step 109: f(x)= 0.946488
# differential_evolution step 110: f(x)= 0.946488
# differential_evolution step 111: f(x)= 0.946488
# differential_evolution step 112: f(x)= 0.946488
# differential_evolution step 113: f(x)= 0.946488
# differential_evolution step 114: f(x)= 0.938766
# differential_evolution step 115: f(x)= 0.938766
# differential_evolution step 116: f(x)= 0.925249
# differential_evolution step 117: f(x)= 0.925249
# differential_evolution step 118: f(x)= 0.925249
# differential_evolution step 119: f(x)= 0.925249
# differential_evolution step 120: f(x)= 0.925249
# differential_evolution step 121: f(x)= 0.925249
# differential_evolution step 122: f(x)= 0.925249
# differential_evolution step 123: f(x)= 0.925249
# differential_evolution step 124: f(x)= 0.925249
# differential_evolution step 125: f(x)= 0.925249
# differential_evolution step 126: f(x)= 0.925249
# differential_evolution step 127: f(x)= 0.92036
# differential_evolution step 128: f(x)= 0.92036
# differential_evolution step 129: f(x)= 0.92036
# differential_evolution step 130: f(x)= 0.92036
# differential_evolution step 131: f(x)= 0.916876
# differential_evolution step 132: f(x)= 0.916433
# differential_evolution step 133: f(x)= 0.916433
# differential_evolution step 134: f(x)= 0.916433
# differential_evolution step 135: f(x)= 0.916433
# differential_evolution step 136: f(x)= 0.910769
# differential_evolution step 137: f(x)= 0.910769
# differential_evolution step 138: f(x)= 0.910769
# differential_evolution step 139: f(x)= 0.910769
# differential_evolution step 140: f(x)= 0.910769
# differential_evolution step 141: f(x)= 0.910403
# differential_evolution step 142: f(x)= 0.910403
# differential_evolution step 143: f(x)= 0.908766
# differential_evolution step 144: f(x)= 0.906582
# differential_evolution step 145: f(x)= 0.905013
# differential_evolution step 146: f(x)= 0.886789
# differential_evolution step 147: f(x)= 0.885365
# differential_evolution step 148: f(x)= 0.881035
# differential_evolution step 149: f(x)= 0.881035
# differential_evolution step 150: f(x)= 0.881035
# differential_evolution step 151: f(x)= 0.881035
# differential_evolution step 152: f(x)= 0.881035
# differential_evolution step 153: f(x)= 0.881035
# differential_evolution step 154: f(x)= 0.881035
# differential_evolution step 155: f(x)= 0.881035
# differential_evolution step 156: f(x)= 0.881035
# differential_evolution step 157: f(x)= 0.881035
# differential_evolution step 158: f(x)= 0.881035
# differential_evolution step 159: f(x)= 0.881035
# differential_evolution step 160: f(x)= 0.881035
# differential_evolution step 161: f(x)= 0.881035
# differential_evolution step 162: f(x)= 0.881035
# differential_evolution step 163: f(x)= 0.881035
# differential_evolution step 164: f(x)= 0.881035
# differential_evolution step 165: f(x)= 0.881035
# differential_evolution step 166: f(x)= 0.881035
# differential_evolution step 167: f(x)= 0.881035
# differential_evolution step 168: f(x)= 0.881035
# differential_evolution step 169: f(x)= 0.881035
# differential_evolution step 170: f(x)= 0.881035
# differential_evolution step 171: f(x)= 0.879819
# differential_evolution step 172: f(x)= 0.879819
# differential_evolution step 173: f(x)= 0.879627
# differential_evolution step 174: f(x)= 0.879627
# differential_evolution step 175: f(x)= 0.879627
# differential_evolution step 176: f(x)= 0.879627
# differential_evolution step 177: f(x)= 0.877307
# differential_evolution step 178: f(x)= 0.877307
# differential_evolution step 179: f(x)= 0.877307
# differential_evolution step 180: f(x)= 0.877086
# differential_evolution step 181: f(x)= 0.877086
# differential_evolution step 182: f(x)= 0.875446
# differential_evolution step 183: f(x)= 0.875446
# differential_evolution step 184: f(x)= 0.875446
# differential_evolution step 185: f(x)= 0.875446
# Optimization Run #5
# differential_evolution step 1: f(x)= 2.16589
# differential_evolution step 2: f(x)= 2.16589
# differential_evolution step 3: f(x)= 2.16589
# differential_evolution step 4: f(x)= 2.16589
# differential_evolution step 5: f(x)= 1.8589
# differential_evolution step 6: f(x)= 1.8589
# differential_evolution step 7: f(x)= 1.8589
# differential_evolution step 8: f(x)= 1.8589
# differential_evolution step 9: f(x)= 1.8589
# differential_evolution step 10: f(x)= 1.8589
# differential_evolution step 11: f(x)= 1.82396
# differential_evolution step 12: f(x)= 1.64039
# differential_evolution step 13: f(x)= 1.64039
# differential_evolution step 14: f(x)= 1.64039
# differential_evolution step 15: f(x)= 1.58283
# differential_evolution step 16: f(x)= 1.57938
# differential_evolution step 17: f(x)= 1.57938
# differential_evolution step 18: f(x)= 1.57938
# differential_evolution step 19: f(x)= 1.57938
# differential_evolution step 20: f(x)= 1.41614
# differential_evolution step 21: f(x)= 1.41614
# differential_evolution step 22: f(x)= 1.40852
# differential_evolution step 23: f(x)= 1.40852
# differential_evolution step 24: f(x)= 1.40852
# differential_evolution step 25: f(x)= 1.40852
# differential_evolution step 26: f(x)= 1.40852
# differential_evolution step 27: f(x)= 1.3506
# differential_evolution step 28: f(x)= 1.33778
# differential_evolution step 29: f(x)= 1.33778
# differential_evolution step 30: f(x)= 1.30982
# differential_evolution step 31: f(x)= 1.30982
# differential_evolution step 32: f(x)= 1.2549
# differential_evolution step 33: f(x)= 1.2549
# differential_evolution step 34: f(x)= 1.2549
# differential_evolution step 35: f(x)= 1.2549
# differential_evolution step 36: f(x)= 1.2549
# differential_evolution step 37: f(x)= 1.2549
# differential_evolution step 38: f(x)= 1.2549
# differential_evolution step 39: f(x)= 1.2549
# differential_evolution step 40: f(x)= 1.2549
# differential_evolution step 41: f(x)= 1.2549
# differential_evolution step 42: f(x)= 1.2549
# differential_evolution step 43: f(x)= 1.25402
# differential_evolution step 44: f(x)= 1.14619
# differential_evolution step 45: f(x)= 1.14619
# differential_evolution step 46: f(x)= 1.14619
# differential_evolution step 47: f(x)= 1.14619
# differential_evolution step 48: f(x)= 1.14619
# differential_evolution step 49: f(x)= 1.13166
# differential_evolution step 50: f(x)= 1.13166
# differential_evolution step 51: f(x)= 1.13166
# differential_evolution step 52: f(x)= 1.13166
# differential_evolution step 53: f(x)= 1.13166
# differential_evolution step 54: f(x)= 1.13166
# differential_evolution step 55: f(x)= 1.13166
# differential_evolution step 56: f(x)= 1.13166
# differential_evolution step 57: f(x)= 1.13166
# differential_evolution step 58: f(x)= 1.13166
# differential_evolution step 59: f(x)= 1.13166
# differential_evolution step 60: f(x)= 1.10152
# differential_evolution step 61: f(x)= 1.10152
# differential_evolution step 62: f(x)= 1.10152
# differential_evolution step 63: f(x)= 1.06791
# differential_evolution step 64: f(x)= 1.06791
# differential_evolution step 65: f(x)= 1.06791
# differential_evolution step 66: f(x)= 1.06791
# differential_evolution step 67: f(x)= 1.06791
# differential_evolution step 68: f(x)= 1.06046
# differential_evolution step 69: f(x)= 1.03888
# differential_evolution step 70: f(x)= 1.03888
# differential_evolution step 71: f(x)= 1.03872
# differential_evolution step 72: f(x)= 1.03872
# differential_evolution step 73: f(x)= 1.03872
# differential_evolution step 74: f(x)= 1.03872
# differential_evolution step 75: f(x)= 1.03872
# differential_evolution step 76: f(x)= 1.03872
# differential_evolution step 77: f(x)= 1.02963
# differential_evolution step 78: f(x)= 1.02963
# differential_evolution step 79: f(x)= 1.02963
# differential_evolution step 80: f(x)= 1.02963
# differential_evolution step 81: f(x)= 1.02361
# differential_evolution step 82: f(x)= 1.02361
# differential_evolution step 83: f(x)= 1.02361
# differential_evolution step 84: f(x)= 1.02361
# differential_evolution step 85: f(x)= 1.02151
# differential_evolution step 86: f(x)= 1.02151
# differential_evolution step 87: f(x)= 1.02151
# differential_evolution step 88: f(x)= 1.02151
# differential_evolution step 89: f(x)= 0.998478
# differential_evolution step 90: f(x)= 0.998478
# differential_evolution step 91: f(x)= 0.998478
# differential_evolution step 92: f(x)= 0.993553
# differential_evolution step 93: f(x)= 0.993553
# differential_evolution step 94: f(x)= 0.986633
# differential_evolution step 95: f(x)= 0.967157
# differential_evolution step 96: f(x)= 0.967157
# differential_evolution step 97: f(x)= 0.967157
# differential_evolution step 98: f(x)= 0.957307
# differential_evolution step 99: f(x)= 0.950114
# differential_evolution step 100: f(x)= 0.950114
# differential_evolution step 101: f(x)= 0.950114
# differential_evolution step 102: f(x)= 0.950114
# differential_evolution step 103: f(x)= 0.950114
# differential_evolution step 104: f(x)= 0.950114
# differential_evolution step 105: f(x)= 0.950114
# differential_evolution step 106: f(x)= 0.950114
# differential_evolution step 107: f(x)= 0.93997
# differential_evolution step 108: f(x)= 0.93997
# differential_evolution step 109: f(x)= 0.93997
# differential_evolution step 110: f(x)= 0.9361
# differential_evolution step 111: f(x)= 0.9361
# differential_evolution step 112: f(x)= 0.928167
# differential_evolution step 113: f(x)= 0.928167
# differential_evolution step 114: f(x)= 0.928167
# differential_evolution step 115: f(x)= 0.928167
# differential_evolution step 116: f(x)= 0.928167
# differential_evolution step 117: f(x)= 0.928167
# differential_evolution step 118: f(x)= 0.906846
# differential_evolution step 119: f(x)= 0.906846
# differential_evolution step 120: f(x)= 0.906846
# differential_evolution step 121: f(x)= 0.906846
# differential_evolution step 122: f(x)= 0.906846
# differential_evolution step 123: f(x)= 0.906846
# differential_evolution step 124: f(x)= 0.906846
# differential_evolution step 125: f(x)= 0.906846
# differential_evolution step 126: f(x)= 0.906846
# differential_evolution step 127: f(x)= 0.906846
# differential_evolution step 128: f(x)= 0.906846
# differential_evolution step 129: f(x)= 0.906846
# differential_evolution step 130: f(x)= 0.906846
# differential_evolution step 131: f(x)= 0.906846
# differential_evolution step 132: f(x)= 0.906846
# differential_evolution step 133: f(x)= 0.906846
# differential_evolution step 134: f(x)= 0.906846
# differential_evolution step 135: f(x)= 0.906846
# differential_evolution step 136: f(x)= 0.906846
# differential_evolution step 137: f(x)= 0.906846
# differential_evolution step 138: f(x)= 0.906846
# differential_evolution step 139: f(x)= 0.906846
# differential_evolution step 140: f(x)= 0.906846
# differential_evolution step 141: f(x)= 0.906846
# differential_evolution step 142: f(x)= 0.904057
# differential_evolution step 143: f(x)= 0.904057
# differential_evolution step 144: f(x)= 0.904057
# differential_evolution step 145: f(x)= 0.903806
# differential_evolution step 146: f(x)= 0.903806
# differential_evolution step 147: f(x)= 0.894385
# differential_evolution step 148: f(x)= 0.890598
# differential_evolution step 149: f(x)= 0.890598
# differential_evolution step 150: f(x)= 0.890598
# differential_evolution step 151: f(x)= 0.881966
# differential_evolution step 152: f(x)= 0.881966
# differential_evolution step 153: f(x)= 0.881966
# differential_evolution step 154: f(x)= 0.881966
# differential_evolution step 155: f(x)= 0.881966
# differential_evolution step 156: f(x)= 0.881966
# differential_evolution step 157: f(x)= 0.881032
# differential_evolution step 158: f(x)= 0.881032
# differential_evolution step 159: f(x)= 0.881032
# differential_evolution step 160: f(x)= 0.881032
# differential_evolution step 161: f(x)= 0.877318
# differential_evolution step 162: f(x)= 0.877318
# differential_evolution step 163: f(x)= 0.877318
# CPU times: user 1min 56s, sys: 1.92 s, total: 1min 58s
# Wall time: 1min 58s

# %% [markdown]
# ## Save Output to File <a name="saveoutput"></a>

# %%
df_t = pd.DataFrame(optimizedSimData[:,0])
df_gr = pd.DataFrame(sims_gr)
df_cort = pd.DataFrame(sims_cort)
df_acth = pd.DataFrame(sims_acth)
df_crh = pd.DataFrame(sims_crh)

df_t.to_excel(excel_writer = 'sriramModel-nelson-melancholic-patientID_60-timeSteps-5-iterations-p_stress.xlsx')
df_gr.to_excel(excel_writer = 'sriramModel-nelson-melancholic-patientID_60-sims-gr-5-iterations-p_stress.xlsx')
df_cort.to_excel(excel_writer = 'sriramModel-nelson-melancholic-patientID_60-sims-cort-5-iterations-p_stress.xlsx')
df_acth.to_excel(excel_writer = 'sriramModel-nelson-melancholic-patientID_60-sims-acth-5-iterations-p_stress.xlsx')
df_crh.to_excel(excel_writer = 'sriramModel-nelson-melancholic-patientID_60-sims-crh-5-iterations-p_stress.xlsx')

# %%
np.savetxt('sriramModel-nelson-melancholic-patientID_60-opt-pars-5-iterations-p_stress.txt', opt_pars)
np.savetxt('sriramModel-nelson-melancholic-patientID_60-timeSteps-5-iterations-p_stress.txt', optimizedSimData[:,0])
np.savetxt('sriramModel-nelson-melancholic-patientID_60-sims-gr-5-iterations-p_stress.txt', sims_gr)
np.savetxt('sriramModel-nelson-melancholic-patientID_60-sims-crh-5-iterations-p_stress.txt', sims_crh)
np.savetxt('sriramModel-nelson-melancholic-patientID_60-sims-acth-5-iterations-p_stress.txt', sims_acth)
np.savetxt('sriramModel-nelson-melancholic-patientID_60-sims-cort-5-iterations-p_stress.txt', sims_cort)
np.savetxt('sriramModel-nelson-melancholic-patientID_60-initial-conditions-5-iterations-p_stress.txt', y0)
np.savetxt('sriramModel-nelson-melancholic-patientID_60-bounds-5-iterations-p_stress.txt', bounds)

# %% [markdown]
# ## Compute Means and Std Devations of Parameters and Output as Table <a name="paramtable"></a>

# %%
k_stress_mean = np.mean(opt_pars[:,1])
k_stress_std = np.std(opt_pars[:,1])
k_i_mean = np.mean(opt_pars[:,2])
k_i_std = np.std(opt_pars[:,2])
V_S3_mean = np.mean(opt_pars[:,3])
V_S3_std = np.std(opt_pars[:,3])
K_m1_mean = np.mean(opt_pars[:,4])
K_m1_std = np.std(opt_pars[:,4])
K_P2_mean = np.mean(opt_pars[:,5])
K_P2_std = np.std(opt_pars[:,5])
V_S4_mean = np.mean(opt_pars[:,6])
V_S4_std = np.std(opt_pars[:,6])
K_m2_mean = np.mean(opt_pars[:,7])
K_m2_std = np.std(opt_pars[:,7])
K_P3_mean = np.mean(opt_pars[:,8])
K_P3_std = np.std(opt_pars[:,8])
V_S5_mean = np.mean(opt_pars[:,9])
V_S5_std = np.std(opt_pars[:,9])
K_m3_mean = np.mean(opt_pars[:,10])
K_m3_std = np.std(opt_pars[:,10])
K_d1_mean = np.mean(opt_pars[:,11])
K_d1_std = np.std(opt_pars[:,11])
K_d2_mean = np.mean(opt_pars[:,12])
K_d2_std = np.std(opt_pars[:,12])
K_d3_mean = np.mean(opt_pars[:,13])
K_d3_std = np.std(opt_pars[:,13])
n1_mean = np.mean(opt_pars[:,14])
n1_std = np.std(opt_pars[:,14])
n2_mean = np.mean(opt_pars[:,15])
n2_std = np.std(opt_pars[:,15])
K_b_mean = np.mean(opt_pars[:,16])
K_b_std = np.std(opt_pars[:,16])
G_tot_mean = np.mean(opt_pars[:,17])
G_tot_std = np.std(opt_pars[:,17])
V_S2_mean = np.mean(opt_pars[:,18])
V_S2_std = np.std(opt_pars[:,18])
K1_mean = np.mean(opt_pars[:,19])
K1_std = np.std(opt_pars[:,19])
K_d5_mean = np.mean(opt_pars[:,20])
K_d5_std = np.std(opt_pars[:,20])
#p_stress_mean = np.mean(opt_pars[:,21])
#p_stress_std = np.std(opt_pars[:,21])

# %%
#print(tabulate([["k_stress", "%f +- %f" % (k_stress_mean, k_stress_std)], ["k_i", "%f +- %f" % (k_i_mean, k_i_std)], ["V_S3", "%f +- %f" % (V_S3_mean, V_S3_std)], ["K_m1", "%f +- %f" % (K_m1_mean, K_m1_std)], ["K_P2", "%f +- %f" % (K_P2_mean, K_P2_std)], ["V_S4", "%f +- %f" % (V_S4_mean, V_S4_std)], ["K_m2", "%f +- %f" % (K_m2_mean, K_m2_std)], ["K_P3", "%f +- %f" % (K_P3_mean, K_P3_std)], ["V_S5", "%f +- %f" % (V_S5_mean, V_S5_std)], ["K_m3", "%f +- %f" % (K_m3_mean, K_m3_std)], ["K_d1", "%f +- %f" % (K_d1_mean, K_d1_std)], ["K_d2", "%f +- %f" % (K_d2_mean, K_d2_std)], ["K_d3", "%f +- %f" % (K_d3_mean, K_d3_std)], ["n1", "%f +- %f" % (n1_mean, n1_std)], ["n2", "%f +- %f" % (n2_mean, n2_std)], ["K_b", "%f +- %f" % (K_b_mean, K_b_std)], ["G_tot", "%f +- %f" % (G_tot_mean, G_tot_std)], ["V_S2", "%f +- %f" % (V_S2_mean, V_S2_std)], ["K1", "%f +- %f" % (K1_mean, K1_std)], ["K_d5", "%f +- %f" % (K_d5_mean, K_d5_std)], ["p_stress", "%f +- %f" % (p_stress_mean, p_stress_std)]], headers = ["Parameter", "Mean +- Standard Deviation"]))
print(tabulate([["k_stress", "%f +- %f" % (k_stress_mean, k_stress_std)], ["k_i", "%f +- %f" % (k_i_mean, k_i_std)], ["V_S3", "%f +- %f" % (V_S3_mean, V_S3_std)], ["K_m1", "%f +- %f" % (K_m1_mean, K_m1_std)], ["K_P2", "%f +- %f" % (K_P2_mean, K_P2_std)], ["V_S4", "%f +- %f" % (V_S4_mean, V_S4_std)], ["K_m2", "%f +- %f" % (K_m2_mean, K_m2_std)], ["K_P3", "%f +- %f" % (K_P3_mean, K_P3_std)], ["V_S5", "%f +- %f" % (V_S5_mean, V_S5_std)], ["K_m3", "%f +- %f" % (K_m3_mean, K_m3_std)], ["K_d1", "%f +- %f" % (K_d1_mean, K_d1_std)], ["K_d2", "%f +- %f" % (K_d2_mean, K_d2_std)], ["K_d3", "%f +- %f" % (K_d3_mean, K_d3_std)], ["n1", "%f +- %f" % (n1_mean, n1_std)], ["n2", "%f +- %f" % (n2_mean, n2_std)], ["K_b", "%f +- %f" % (K_b_mean, K_b_std)], ["G_tot", "%f +- %f" % (G_tot_mean, G_tot_std)], ["V_S2", "%f +- %f" % (V_S2_mean, V_S2_std)], ["K1", "%f +- %f" % (K1_mean, K1_std)], ["K_d5", "%f +- %f" % (K_d5_mean, K_d5_std)]], headers = ["Parameter", "Mean +- Standard Deviation"]))
# Out:
# Parameter    Mean +- Standard Deviation
# -----------  ----------------------------
# k_stress     13.247636 +- 7.968169
# k_i          4.613209 +- 0.193066
# V_S3         4.736703 +- 1.563491
# K_m1         5.221136 +- 1.976948
# K_P2         12.405898 +- 5.077322
# V_S4         10.436700 +- 0.069413
# K_m2         0.150279 +- 0.108139
# K_P3         1.845525 +- 0.242625
# V_S5         0.054775 +- 0.016630
# K_m3         0.203894 +- 0.058057
# K_d1         0.047767 +- 0.019335
# K_d2         0.099883 +- 0.000234
# K_d3         4.252588 +- 0.575155
# n1           11.013569 +- 2.236910
# n2           14.306485 +- 0.529685
# K_b          0.069123 +- 0.029608
# G_tot        10.552569 +- 4.912254
# V_S2         5.854484 +- 1.324208
# K1           4.391350 +- 0.544687
# K_d5         0.203365 +- 0.100740

# %%
np.savetxt('sriramModel-nelson-melancholic-patientID_60-param-means-stds-5-iterations-p_stress.txt', [k_stress_mean, k_stress_std, k_i_mean, k_i_std, V_S3_mean, V_S3_std, K_m1_mean, K_m1_std, K_P2_mean, K_P2_std, V_S4_mean, V_S4_std, K_m2_mean, K_m2_std, K_P3_mean, K_P3_std, V_S5_mean, V_S5_std, K_m3_mean, K_m3_std, K_d1_mean, K_d1_std, K_d2_mean, K_d2_std, K_d3_mean, K_d3_std, n1_mean, n1_std, n2_mean, n2_std, K_b_mean, K_b_std, G_tot_mean, G_tot_std, V_S2_mean, V_S2_std, K1_mean, K1_std, K_d5_mean, K_d5_std])
#np.savetxt('sriramModel-nelson-atypical-patientID_1-param-means-stds-5-iterations-p-stress.txt', [k_stress_mean, k_stress_std, k_i_mean, k_i_std, V_S3_mean, V_S3_std, K_m1_mean, K_m1_std, K_P2_mean, K_P2_std, V_S4_mean, V_S4_std, K_m2_mean, K_m2_std, K_P3_mean, K_P3_std, V_S5_mean, V_S5_std, K_m3_mean, K_m3_std, K_d1_mean, K_d1_std, K_d2_mean, K_d2_std, K_d3_mean, K_d3_std, n1_mean, n1_std, n2_mean, n2_std, K_b_mean, K_b_std, G_tot_mean, G_tot_std, V_S2_mean, V_S2_std, K1_mean, K1_std, K_d5_mean, K_d5_std, p_stress_mean, p_stress_std])

# %% [markdown]
# ## Plots <a name="plots"></a>

# %%
# %matplotlib inline
# plot of raw data with simulation data for cortisol, then just simulation data for crh and acth

matplotlib.rc('font', **{'size'   : 28})

fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(24,40))

#ax1.plot(optimizedSimData[:,0], sims_crh, label = "Mean Simulated CRH")
# for more than 1 iteration, uncomment below
ax1.plot(optimizedSimData[:,0], np.mean(sims_crh, axis = 1), label = "Mean Simulated CRH", color = "blue")
ax1.fill_between(optimizedSimData[:,0], np.mean(sims_crh, axis = 1) - np.std(sims_crh, axis = 1), np.mean(sims_crh, axis = 1) + np.std(sims_crh, axis = 1), alpha = 0.3, label = "Simulated CRH Standard Deviation")
ax1.legend(loc = "upper left", shadow = True, fancybox = True)
ax1.set(xlabel = "Time (h)", ylabel = "CRH (micrograms/dL)", title = "CRH Concentration")

#ax2.plot(optimizedSimData[:,0], sims_acth, label = "Mean")
ax2.plot(nelsonACTH[:,0], nelsonMelancholicACTH[:,12], label = "Nelson Melancholic MDD ACTH Data - Patient ID 60", color = "orange")
# for more than 1 iteration, uncomment below0.650146
ax2.plot(optimizedSimData[:,0], np.mean(sims_acth, axis = 1), label = "Mean Simulated ACTH", color = "blue")
ax2.fill_between(optimizedSimData[:,0], np.mean(sims_acth, axis = 1) - np.std(sims_acth, axis = 1), np.mean(sims_acth, axis = 1) + np.std(sims_acth, axis = 1), alpha = 0.3, label = "Simulated ACTH Standard Deviation")
ax2.legend(loc = "upper right", shadow = True, fancybox = True)
ax2.set(xlabel = "Time (h)", ylabel = "ACTH (pg/mL)", title = "ACTH Concentration")

#ax3.plot(optimizedSimData[:,0], sims_cort, label = "Simulation Mean")
ax3.plot(nelsonCortisol[:,0], nelsonMelancholicCortisol[:,12], label = "Nelson Melancholic MDD Cortisol Data - Patient ID 60", color = "orange")
# for more than 1 iteration, uncomment below
ax3.plot(optimizedSimData[:,0], np.mean(sims_cort, axis = 1), label = "Mean Simulated Cortisol", color = "blue")
ax3.fill_between(optimizedSimData[:,0], np.mean(sims_cort, axis = 1) - np.std(sims_cort, axis = 1), np.mean(sims_cort, axis = 1) + np.std(sims_cort, axis = 1), alpha = 0.3, label = "Simulated Cortisol Standard Deviation")
ax3.legend(loc = "lower right", shadow = True, fancybox = True)
ax3.set(xlabel = "Time (h)", ylabel = "Cortisol (micrograms/dL)", title = "Cortisol Concentration")

#ax4.plot(optimizedSimData[:,0], sims_gr, label = "Mean")
# for more than 1 iteration, uncomment below
ax4.plot(optimizedSimData[:,0], np.mean(sims_gr, axis = 1), label = "Mean Simulated GR")
ax4.fill_between(optimizedSimData[:,0], np.mean(sims_gr, axis = 1) - np.std(sims_gr, axis = 1), np.mean(sims_gr, axis = 1) + np.std(sims_gr, axis = 1), alpha = 0.5, label = "Simulated GR Standard Deviation")
ax4.legend(loc = "upper left", shadow = True, fancybox = True)
ax4.set(xlabel = "Time (h)", ylabel = "GR (micrograms)", title = "GR Concentration")

txt = "cost = [0.875446, 0.965458]"
plt.figtext(0.1, 0.09, txt, wrap = True, horizontalalignment = 'center', fontsize = 30)
#plt.savefig("sriramModel-nelson-atypical-patientID_1-5-iterations-all-params-normalizedCost.png", dpi = 300)
# include p_stress in filename to indicate that we used stress_input function
plt.savefig("sriramModel-nelson-melancholic-patientID_60-5-iterations-all-params-normalizedCost-p_stress.png", dpi = 300)

# %% [markdown]
# ## Figure 3 Reproduction <a name="fig3"></a>

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 10.1
k_i = 1.51
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params_control = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 13.7
k_i = 1.6
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params_depressed = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 17.5
k_i = 1.17
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params_ptsd = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
y0_control = [1, 5, 5, 2]
y0_depressed = [1, 5, 5, 2]
y0_ptsd = [1, 5, 5, 2]

t_start = -0.01
t_end = 300.01
t_step = 0.01

# %%
# %%time

no_opt_control = model(authors_params_control, y0_control)
no_opt_depressed = model(authors_params_depressed, y0_depressed)
no_opt_ptsd = model(authors_params_ptsd, y0_ptsd)

sims_gr_control = no_opt_control[:,4]
sims_cort_control = no_opt_control[:,3]
sims_acth_control = no_opt_control[:,2]
sims_crh_control = no_opt_control[:,1]

sims_gr_depressed = no_opt_depressed[:,4]
sims_cort_depressed = no_opt_depressed[:,3]
sims_acth_depressed = no_opt_depressed[:,2]
sims_crh_depressed = no_opt_depressed[:,1]

sims_gr_ptsd = no_opt_ptsd[:,4]
sims_cort_ptsd = no_opt_ptsd[:,3]
sims_acth_ptsd = no_opt_ptsd[:,2]
sims_crh_ptsd = no_opt_ptsd[:,1]
# Out:
# CPU times: user 844 ms, sys: 25.8 ms, total: 870 ms
# Wall time: 868 ms

# %%
# %matplotlib inline
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (15,20))

ax1.plot(np.arange(0, 70, 0.01), sims_cort_control[-7800:-800], label = "CORT sim - Control")
ax1.set(ylabel = "CORT (micrograms/dL)", xlabel = "Time (h)", title = "CORT sim - Control")
#ax1.legend(loc = "upper right", shadow = True, fancybox = True)

ax2.plot(np.arange(0, 70, 0.01), sims_cort_depressed[-8800:-1800], label = "CORT sim - Depression")
ax2.set(ylabel = "CORT (micrograms/dL)", xlabel = "Time (h)", title = "CORT sim - Depression")
#ax2.legend(loc = "upper right", shadow = True, fancybox = True)

ax3.plot(np.arange(0, 70, 0.01), sims_cort_ptsd[-9100:-2100], label = "CORT sim - PTSD")
ax3.set(ylabel = "CORT (micrograms/dL)", xlabel = "Time (h)", title = "CORT sim - PTSD")
#ax3.legend(loc = "upper right", shadow = True, fancybox = True)

plt.savefig("sriramModel-figure3-reproduction.png", dpi=300)

# %% [markdown]
# ## Figure 4 Reproduction <a name="fig4"></a>

# %%
# create Fig 4 of free glucocorticoid receptor level
t_end = 240.01

normal = model(authors_params_control, y0)
PTSD = model(authors_params_ptsd, y0)
depressed = model(authors_params_depressed, y0)

G_normal = G_tot - normal[:,4]
G_PTSD = G_tot - PTSD[:,4]
G_depressed = G_tot - depressed[:,4]

plt.plot(normal[-12000:,0], G_normal[-12000:], label='Normal')
plt.plot(PTSD[-12000:,0], G_PTSD[-12000:], label='PTSD')
plt.plot(depressed[-12000:,0], G_depressed[-12000:], label='Depressed')
plt.ylim(0,2.5)
plt.xlabel('t (hours)')
plt.ylabel('G')
plt.title("Figure 4 Reproduction")
plt.legend(loc = "upper right", shadow = True, fancybox = True)
plt.savefig("sriramModel-figure4-reproduction.png", dpi=300)

# %% [markdown]
# ## Load Parameter Sets, Run Model and Save Hormone Concentration Data <a name="loadparams"></a>

# %%
loaded_params = np.genfromtxt("sriram-opt-pars-carrollControl-rearr-1-all-params-expanded-bounds.txt")
y0 = np.genfromtxt("sriram-y0-carrollControl-rearr-1-all-params-expanded-bounds.txt")
bounds = np.genfromtxt("sriram-bounds-carrollControl-rearr-1-all-params-expanded-bounds.txt")

# %%
# if loading only a single iteration
loaded_params = loaded_params[1:]

# if loading multiple iterations
#loaded_params = loaded_params[1:,:]

# %%
# plug the optimized parameters into the solver
optimizedSimData = model(loaded_params, y0)
    
# save CRH, cortisol and ACTH data into sims arrays
sims_gr = optimizedSimData[:,4]
sims_cort = optimizedSimData[:,3]
sims_acth = optimizedSimData[:,2]
sims_crh = optimizedSimData[:,1]

# %% [markdown]
# ### Checking Parameter Sets Generated Externally <a name="checkexternal"></a>

# %%
cort_data = np.zeros((2403,len(loaded_params)))
for i in range(len(loaded_params)):
    cort_data[:,i] = np.transpose(np.hstack((i+1,model(loaded_params[i,1:], y0)[:,3])))

# %%
time_data = np.zeros((2403,len(loaded_params)))
for i in range(len(loaded_params)):
    time_data[:,i] = np.transpose(np.hstack((i+1,model(loaded_params[i,1:], y0)[:,0])))

# %%
np.savetxt("sriram-cort-data-yehudaControl-1000-all-params.txt", cort_data)

# %%
np.savetxt("sriram-time-data-yehudaControl-1000-all-params.txt", time_data)

# %%
sim = model(yin_params[next_max,1:], y0)

# %%
sim = model(testing_params, y0)

# %%
print(cost_fun(testing_params))
# Out:
# 921758398.1845118

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (15,15))
ax1.plot(sim[:,0], sim[:,3], label = "Simulation")
ax1.plot(yehudaControlCortisol[:,0], yehudaControlCortisol[:,1], label = "Yehuda Control Group")
ax1.set(xlabel = "Time", ylabel = "Cortisol", title = "Control Group: Raw Data vs Authors' Optimized Parameters")
ax2.plot(sim[:,0], sim[:,1])
ax2.set(xlabel = "Time", ylabel = "CRH", title = "CRH w/ Authors' Control Group Parameters")
ax3.plot(sim[:,0], sim[:,2])
ax3.set(xlabel = "Time", ylabel = "ACTH", title = "ACTH w/ Authors' Control Group Parameters")

plt.savefig("testing-params-kb-0.01.pdf", dpi = 300)

# %% [markdown]
# ## Load Simulated Concentration Data from Files and Plot <a name="load-and-plot"></a>

# %%
sims_t = np.genfromtxt('sriramModel-nelson-atypical-patientID_19-timeSteps-5-iterations.txt')
sims_gr = np.genfromtxt('sriramModel-nelson-atypical-patientID_19-sims-gr-5-iterations.txt')
sims_cort = np.genfromtxt('sriramModel-nelson-atypical-patientID_19-sims-cort-5-iterations.txt')
sims_crh = np.genfromtxt('sriramModel-nelson-atypical-patientID_19-sims-crh-5-iterations.txt')
sims_acth = np.genfromtxt('sriramModel-nelson-atypical-patientID_19-sims-acth-5-iterations.txt')

# %%
# %matplotlib inline
# plot of raw data with simulation data for cortisol, then just simulation data for crh and acth

matplotlib.rc('font', **{'size'   : 28})

fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(24,40))

#ax1.plot(optimizedSimData[:,0], sims_crh, label = "Mean Simulated CRH")
# for more than 1 iteration, uncomment below
ax1.plot(sims_t, np.mean(sims_crh, axis = 1), label = "Mean Simulated CRH", color = "blue")
ax1.fill_between(sims_t, np.mean(sims_crh, axis = 1) - np.std(sims_crh, axis = 1), np.mean(sims_crh, axis = 1) + np.std(sims_crh, axis = 1), alpha = 0.3, label = "Simulated CRH Standard Deviation")
ax1.legend(loc = "upper left", shadow = True, fancybox = True)
ax1.set(xlabel = "Time (h)", ylabel = "CRH (micrograms/dL)", title = "CRH Concentration")

#ax2.plot(optimizedSimData[:,0], sims_acth, label = "Mean")
ax2.plot(nelsonACTH[:,0], nelsonAtypicalACTH[:,5], label = "Nelson Atypical MDD ACTH Data - Patient ID 19", color = "orange")
# for more than 1 iteration, uncomment below
ax2.plot(sims_t, np.mean(sims_acth, axis = 1), label = "Mean Simulated ACTH", color = "blue")
ax2.fill_between(sims_t, np.mean(sims_acth, axis = 1) - np.std(sims_acth, axis = 1), np.mean(sims_acth, axis = 1) + np.std(sims_acth, axis = 1), alpha = 0.3, label = "Simulated ACTH Standard Deviation")
ax2.legend(loc = "upper right", shadow = True, fancybox = True)
ax2.set(xlabel = "Time (h)", ylabel = "ACTH (pg/mL)", title = "ACTH Concentration")

#ax3.plot(optimizedSimData[:,0], sims_cort, label = "Simulation Mean")
ax3.plot(nelsonCortisol[:,0], nelsonAtypicalCortisol[:,5], label = "Nelson Atypical MDD Cortisol Data - Patient ID 19", color = "orange")
# for more than 1 iteration, uncomment below
ax3.plot(sims_t, np.mean(sims_cort, axis = 1), label = "Mean Simulated Cortisol", color = "blue")
ax3.fill_between(sims_t, np.mean(sims_cort, axis = 1) - np.std(sims_cort, axis = 1), np.mean(sims_cort, axis = 1) + np.std(sims_cort, axis = 1), alpha = 0.3, label = "Simulated Cortisol Standard Deviation")
ax3.legend(loc = "lower right", shadow = True, fancybox = True)
ax3.set(xlabel = "Time (h)", ylabel = "Cortisol (micrograms/dL)", title = "Cortisol Concentration")

#ax4.plot(optimizedSimData[:,0], sims_gr, label = "Mean")
# for more than 1 iteration, uncomment below
ax4.plot(sims_t, np.mean(sims_gr, axis = 1), label = "Mean Simulated GR")
ax4.fill_between(sims_t, np.mean(sims_gr, axis = 1) - np.std(sims_gr, axis = 1), np.mean(sims_gr, axis = 1) + np.std(sims_gr, axis = 1), alpha = 0.5, label = "Simulated GR Standard Deviation")
ax4.legend(loc = "upper left", shadow = True, fancybox = True)
ax4.set(xlabel = "Time (h)", ylabel = "GR (micrograms)", title = "GR Concentration")

txt = "cost = [0.759431, 0.84753]"
plt.figtext(0.1, 0.09, txt, wrap = True, horizontalalignment = 'center', fontsize = 30)
#plt.savefig("sriramModel-nelson-atypical-patientID_1-5-iterations-all-params-normalizedCost.png", dpi = 300)
# include p_stress in filename to indicate that we used stress_input function
plt.savefig("sriramModel-nelson-atypical-patientID_19-5-iterations-all-params-normalizedCost.png", dpi = 300)

# %% [markdown]
# ## Dependencies <a name="dependencies"></a>

# %%
# %load_ext watermark

# %%
# %watermark --iversions
# Out:
# distutils : 3.7.7
# scipy     : 1.1.0
# matplotlib: 3.0.1
# platform  : 1.0.8
# sys       : 3.7.7 (default, May  6 2020, 04:59:01)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# pandas    : 0.23.4
# PyDSTool  : 0.91.0
# numpy     : 1.21.5
# mpld3     : 0.3.1.dev1
