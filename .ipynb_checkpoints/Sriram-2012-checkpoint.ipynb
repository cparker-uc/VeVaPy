# %% [markdown]
# # Sriram et al. (2012) Model Code

# %% [markdown]
# # Table of Contents
# 1. [Imports](#imports)
# 2. [Parameters and Initial Conditions](#params)
# 3. [Put Raw Data into Arrays](#rawdata)
#     1. [Smooth Data, if Desired](#smoothdata)
#     2. [Re-run Code to Input Non-Smoothed Data into Array](#rerun)
#     3. [Plot Data Sets](#plotdata)
# 4. [Model Function--Includes ODE Solver](#modelfunction)
# 5. [Functions to Determine Delayed ACTH and Cortisol Values](#delays)
# 6. [Cost Function Definition](#cost)
# 7. [Run the Optimization](#run)
# 8. [Save Output to File](#saveoutput)
# 9. [Compute Means and Std Devations of Parameters and Output as Table](#paramtable)
# 10. [Plots](#plots)
# 11. [Figure 3 Reproduction](#fig3)
# 12. [Figure 4 Reproduction](#fig4)
# 13. [Load Parameter Sets, Run Model and Save Hormone Concentration Data](#loadparams)
# 14. [Checking Parameter Sets Generated Externally](#checkexternal)
# 15. [Dependencies](#dependencies)

# %% [markdown]
# ## Imports <a name="imports"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.integrate as sci
import scipy.optimize as sco
from scipy.interpolate import interp1d
import mpld3
from tabulate import tabulate
import matplotlib
import pandas as pd

# %% [markdown]
# ## Parameters and Initial Conditions <a name="params"></a>

# %%
# it looks, based on the XPP file from the authors, like they start CRH, ACTH, CORT and GR at 0 each and just run
# the solver until they reach some steady state

y0 = [1,28.7,8.6123,2]
icdict = {'CRH':0, 'ACTH':0, 'CORT':0, 'GR':2.28}

# %%
# initialize dictionaries for each of the three groups which include k_stress and k_i (the only parameters 
#     that vary between groups)

pardict_normal = {'k_stress':10.1, 'k_i':1.51, 'V_S3':3.25, 'K_m1':1.74, 'K_P2':8.3, 'V_S4':0.907, 'K_m2':0.112, 'K_P3':0.945, 'V_S5':0.00535, 'K_m3':0.0768, 'K_d1':0.00379, 'K_d2':0.00916, 'K_d3':0.356, 'n1':5.43, 'n2':5.1, 'K_b':0.0202, 'G_tot':3.28, 'V_S2':0.0509, 'K1':0.645, 'K_d5':0.0854}
pardict_depressed = {'k_stress':13.7, 'k_i':1.6, 'V_S3':3.25, 'K_m1':1.74, 'K_P2':8.3, 'V_S4':0.907, 'K_m2':0.112, 'K_P3':0.945, 'V_S5':0.00535, 'K_m3':0.0768, 'K_d1':0.00379, 'K_d2':0.00916, 'K_d3':0.356, 'n1':5.43, 'n2':5.1, 'K_b':0.0202, 'G_tot':3.28, 'V_S2':0.0509, 'K1':0.645, 'K_d5':0.0854}
pardict_PTSD = {'k_stress':17.5, 'k_i':1.17, 'V_S3':3.25, 'K_m1':1.74, 'K_P2':8.3, 'V_S4':0.907, 'K_m2':0.112, 'K_P3':0.945, 'V_S5':0.00535, 'K_m3':0.0768, 'K_d1':0.00379, 'K_d2':0.00916, 'K_d3':0.356, 'n1':5.43, 'n2':5.1, 'K_b':0.0202, 'G_tot':3.28, 'V_S2':0.0509, 'K1':0.645, 'K_d5':0.0854}

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 10.1
k_i = 1.51
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# or we can initialize the parameters that stay the same as the literature values and optimize all parameters and
#     see what happens

V_S3 = 1.58 # reported as 1.58-5
K_m1 = 2
K_P2 = 0.3 # reported as 0.3-1.8
V_S4 = 1.58 # reported as 1.58-5
K_m2 = 2
K_P3 = 0.3 # reported as 0.3-1.8
V_S5 = 1.58 # reported as 1.58-5
K_m3 = 2
K_d1 = 0.173
K_d2 = 0.035
K_d3 = 0.009
n1 = 5
n2 = 4
K_b = 0.01 # no literature value reported
G_tot = 2 # no literature value reported
V_S2 = 0 # reported as 0-1
K1 = 1
K_d5 = 0.01
p_stress = 10

authors_params = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# define the bounds for the parameters to be optimized, k_stress and k_i
bounds = [(5,20), (0.5,3)]

# %%
# here are the bounds used for all of the parameters, assuming we want to optimize more than just k_stress and k_i
bounds = [(5,20), (0.5,3), (3,4), (1,2), (7,11), (0.5,1.5), (0.08,2), (0.5,1.2), (0.001,0.008), (0.03,0.08), (0.002,0.005), (0.001,0.01), (0.1,0.5), (4,6), (4,6), (0.008,0.05), (2,5), (0.01,0.07), (0.2,0.7), (0.04,0.09)]

# %%
# wider bounds for fitting other data sets than original
bounds = [(1,30), (0.1,5), (1,10), (.1,10), (1,31), (0.1,10.5), (0.001,10), (0.1,10), (0.001,0.1), (0.001,0.5), (0.001,0.1), (0.001,0.1), (0.01,5), (1,15), (1,15), (0.001,0.5), (.02,45), (0.0001,7), (0.02,7), (0.004,0.9)]

# %%
# wider bounds with p_stress included for Nelson data
bounds = [(1,30), (0.1,5), (1,10), (.1,10), (1,31), (0.1,10.5), (0.001,10), (0.1,10), (0.001,0.1), (0.001,0.5), (0.001,0.1), (0.001,0.1), (0.01,5), (1,15), (1,15), (0.001,0.5), (.02,45), (0.0001,7), (0.02,7), (0.004,0.9), (1,100)]

# %%
# time interval and step definition, based on XPP model from authors
t_start = -0.01
t_end = 2.35
t_step = 0.01

# %% [markdown]
# ## Put Raw Data Into Arrays <a name="rawdata"></a>

# %%
yehudaControlCortisol = np.genfromtxt("yehuda-control-cortisol.txt")
yehudaPTSDCortisol = np.genfromtxt("yehuda-PTSD-cortisol.txt")
yehudaDepressedCortisol = np.genfromtxt("yehuda-depressed-cortisol.txt")

# %%
# convert time scales to hours for the raw data, because the model is in terms of hours
for i in range(len(yehudaControlCortisol)):
    yehudaControlCortisol[i,0] = yehudaControlCortisol[i,0]/60
    yehudaPTSDCortisol[i,0] = yehudaPTSDCortisol[i,0]/60
    yehudaDepressedCortisol[i,0] = yehudaDepressedCortisol[i,0]/60

# %%
# extract the data from text files into 145x2 arrays
carrollControlCortisol = np.genfromtxt("controlGroupCortisolCarroll.txt", dtype = float)
carrollHCDepressedCortisol = np.genfromtxt("HCDepressedCortisolCarroll.txt", dtype = float)
carrollLCDepressedCortisol = np.genfromtxt("LCDepressedCortisolCarroll.txt", dtype = float)

carrollControlACTH = np.genfromtxt("controlGroupACTHCarroll.txt", dtype = float)
carrollHCDepressedACTH = np.genfromtxt("HCDepressedACTHCarroll.txt", dtype = float)
carrollLCDepressedACTH = np.genfromtxt("LCDepressedACTHCarroll.txt", dtype = float)

# %%
# rearrange Carroll data, so that we can start optimizing at midnight and go until 10AM 34 hours later
carrollControlCortisol_rearr = np.vstack((carrollControlCortisol[60:,:], carrollControlCortisol[0:60,:]))
carrollHCDepressedCortisol_rearr = np.vstack((carrollHCDepressedCortisol[60:,:], carrollHCDepressedCortisol[0:60,:]))
carrollLCDepressedCortisol_rearr = np.vstack((carrollLCDepressedCortisol[60:,:], carrollLCDepressedCortisol[0:60,:]))

carrollControlACTH_rearr = np.vstack((carrollControlACTH[60:,:], carrollControlACTH[0:60,:]))
carrollHCDepressedACTH_rearr = np.vstack((carrollHCDepressedACTH[60:,:], carrollHCDepressedACTH[0:60,:]))
carrollLCDepressedACTH_rearr = np.vstack((carrollLCDepressedACTH[60:,:], carrollLCDepressedACTH[0:60,:]))

# %%
golierPTSDCortisol = np.genfromtxt("golier-PTSD-cortisol.txt", dtype = float)
golierNonPTSDTraumaExposedCortisol = np.genfromtxt("golier-non-PTSD-trauma-exposed-cortisol.txt", dtype = float)
golierNonPTSDNonExposedCortisol = np.genfromtxt("golier-non-exposed-control-cortisol.txt", dtype = float)

golierPTSDACTH = np.genfromtxt("golier-PTSD-ACTH.txt", dtype = float)
golierNonPTSDTraumaExposedACTH = np.genfromtxt("golier-non-PTSD-trauma-exposed-ACTH.txt", dtype = float)
golierNonPTSDNonExposedACTH = np.genfromtxt("golier-non-exposed-control-ACTH.txt", dtype = float)

# %%
golierPTSDCortisol_rearr = np.vstack((golierPTSDCortisol[7:,:], golierPTSDCortisol[0:7,:]))
golierNonPTSDTraumaExposedCortisol_rearr = np.vstack((golierNonPTSDTraumaExposedCortisol[7:,:], golierNonPTSDTraumaExposedCortisol[0:7,:]))
golierNonPTSDNonExposedCortisol_rearr = np.vstack((golierNonPTSDNonExposedCortisol[7:,:], golierNonPTSDNonExposedCortisol[0:7,:]))

golierPTSDACTH_rearr = np.vstack((golierPTSDACTH[3:,:], golierPTSDACTH[0:3,:]))
golierNonPTSDTraumaExposedACTH_rearr = np.vstack((golierNonPTSDTraumaExposedACTH[3:,:], golierNonPTSDTraumaExposedACTH[0:3,:]))
golierNonPTSDNonExposedACTH_rearr = np.vstack((golierNonPTSDNonExposedACTH[3:,:], golierNonPTSDNonExposedACTH[0:3,:]))

# %%
bremnerAbusedPTSDCortisol = np.genfromtxt("bremner-abused-PTSD-cortisol.txt", dtype = float)
bremnerNonAbusedPTSDCortisol = np.genfromtxt("bremner-non-abused-PTSD-cortisol.txt", dtype = float)
bremnerNonAbusedNonPTSDCortisol = np.genfromtxt("bremner-non-abused-non-PTSD-cortisol.txt", dtype = float)

# %%
bremnerAbusedPTSDCortisol_rearr = np.vstack((bremnerAbusedPTSDCortisol[68:,:],bremnerAbusedPTSDCortisol[0:68,:]))
bremnerNonAbusedPTSDCortisol_rearr = np.vstack((bremnerNonAbusedPTSDCortisol[68:,:],bremnerNonAbusedPTSDCortisol[0:68,:]))
bremnerNonAbusedNonPTSDCortisol_rearr = np.vstack((bremnerNonAbusedNonPTSDCortisol[68:,:],bremnerNonAbusedNonPTSDCortisol[0:68,:]))

# %%
# data from Dr Erik Nelson
nelsonACTH_data = np.genfromtxt("tsst_acth_nelson.txt")
nelsonCortisol_data = np.genfromtxt("tsst_cort_nelson.txt")

# %% [markdown]
# ### Smooth Data, If Desired <a name="smoothdata"></a>

# %%
# this function computes the moving average over the neighboring 5 points
def smoothing(a, n=5) :
    idx = int((n-1)/2)
    ret = np.cumsum(a, dtype=float)
    ret[idx+1:-idx] = ret[n:] - ret[:-n]
    ret[idx] = ret[idx+2]
    return ret[idx:-idx] / n

# %%
yehudaControlCortisol_smooth = yehudaControlCortisol
yehudaPTSDCortisol_smooth = yehudaPTSDCortisol
yehudaDepressedCortisol_smooth = yehudaDepressedCortisol

yehudaControlCortisol_smooth[2:-2,1] = smoothing(yehudaControlCortisol[:,1])
yehudaPTSDCortisol_smooth[2:-2,1] = smoothing(yehudaPTSDCortisol[:,1])
yehudaDepressedCortisol_smooth[2:-2,1] = smoothing(yehudaDepressedCortisol[:,1])

# %%
# run smoothing if so desired
# REMEMBER: need to re-extract the data from the files into the non-smooth arrays to make them non-smooth.
#     I'm still not sure why it's smoothing the original data when I only save the values from the smoothing function
#     into the smooth arrays
carrollControlCortisol_smooth = carrollControlCortisol
carrollHCDepressedCortisol_smooth = carrollHCDepressedCortisol
carrollLCDepressedCortisol_smooth = carrollLCDepressedCortisol

carrollControlACTH_smooth = carrollControlACTH
carrollHCDepressedACTH_smooth = carrollHCDepressedACTH
carrollLCDepressedACTH_smooth = carrollLCDepressedACTH

carrollControlCortisol_rearr_smooth = carrollControlCortisol_rearr
carrollHCDepressedCortisol_rearr_smooth = carrollHCDepressedCortisol_rearr
carrollLCDepressedCortisol_rearr_smooth = carrollLCDepressedCortisol_rearr

carrollControlACTH_rearr_smooth = carrollControlACTH_rearr
carrollHCDepressedACTH_rearr_smooth = carrollHCDepressedACTH_rearr
carrollLCDepressedACTH_rearr_smooth = carrollLCDepressedACTH_rearr

carrollControlCortisol_smooth[2:-2,1] = smoothing(carrollControlCortisol[:,1])
carrollHCDepressedCortisol_smooth[2:-2,1] = smoothing(carrollHCDepressedCortisol[:,1])
carrollLCDepressedCortisol_smooth[2:-2,1] = smoothing(carrollLCDepressedCortisol[:,1])

carrollControlACTH_smooth[2:-2,1] = smoothing(carrollControlACTH[:,1])
carrollHCDepressedACTH_smooth[2:-2,1] = smoothing(carrollHCDepressedACTH[:,1])
carrollLCDepressedACTH_smooth[2:-2,1] = smoothing(carrollLCDepressedACTH[:,1])

carrollControlCortisol_rearr_smooth[2:-2,1] = smoothing(carrollControlCortisol_rearr[:,1])
carrollHCDepressedCortisol_rearr_smooth[2:-2,1] = smoothing(carrollHCDepressedCortisol_rearr[:,1])
carrollLCDepressedCortisol_rearr_smooth[2:-2,1] = smoothing(carrollLCDepressedCortisol_rearr[:,1])

carrollControlACTH_rearr_smooth[2:-2,1] = smoothing(carrollControlACTH_rearr[:,1])
carrollHCDepressedACTH_rearr_smooth[2:-2,1] = smoothing(carrollHCDepressedACTH_rearr[:,1])
carrollLCDepressedACTH_rearr_smooth[2:-2,1] = smoothing(carrollLCDepressedACTH_rearr[:,1])

# %%
golierPTSDCortisol_smooth = golierPTSDCortisol
golierNonPTSDTraumaExposedCortisol_smooth = golierNonPTSDTraumaExposedCortisol
golierNonPTSDNonExposedCortisol_smooth = golierNonPTSDNonExposedCortisol
golierPTSDACTH_smooth = golierPTSDACTH
golierNonPTSDTraumaExposedACTH_smooth = golierNonPTSDTraumaExposedACTH
golierNonPTSDNonExposedACTH_smooth = golierNonPTSDNonExposedACTH

golierPTSDCortisol_smooth[2:-2,1] = smoothing(golierPTSDCortisol[:,1])
golierNonPTSDTraumaExposedCortisol_smooth[2:-2,1] = smoothing(golierNonPTSDTraumaExposedCortisol[:,1])
golierNonPTSDNonExposedCortisol_smooth[2:-2,1] = smoothing(golierNonPTSDNonExposedCortisol[:,1])

golierPTSDACTH_smooth[2:-2,1] = smoothing(golierPTSDACTH[:,1])
golierNonPTSDTraumaExposedACTH_smooth[2:-2,1] = smoothing(golierNonPTSDTraumaExposedACTH[:,1])
golierNonPTSDNonExposedACTH_smooth[2:-2,1] = smoothing(golierNonPTSDNonExposedACTH[:,1])

# %%
golierPTSDCortisol_rearr_smooth = golierPTSDCortisol_rearr
golierNonPTSDTraumaExposedCortisol_rearr_smooth = golierNonPTSDTraumaExposedCortisol_rearr
golierNonPTSDNonExposedCortisol_rearr_smooth = golierNonPTSDNonExposedCortisol_rearr
golierPTSDACTH_rearr_smooth = golierPTSDACTH_rearr
golierNonPTSDTraumaExposedACTH_rearr_smooth = golierNonPTSDTraumaExposedACTH_rearr
golierNonPTSDNonExposedACTH_rearr_smooth = golierNonPTSDNonExposedACTH_rearr

golierPTSDCortisol_rearr_smooth[2:-2,1] = smoothing(golierPTSDCortisol_rearr[:,1])
golierNonPTSDTraumaExposedCortisol_rearr_smooth[2:-2,1] = smoothing(golierNonPTSDTraumaExposedCortisol_rearr[:,1])
golierNonPTSDNonExposedCortisol_rearr_smooth[2:-2,1] = smoothing(golierNonPTSDNonExposedCortisol_rearr[:,1])

golierPTSDACTH_rearr_smooth[2:-2,1] = smoothing(golierPTSDACTH_rearr[:,1])
golierNonPTSDTraumaExposedACTH_rearr_smooth[2:-2,1] = smoothing(golierNonPTSDTraumaExposedACTH_rearr[:,1])
golierNonPTSDNonExposedACTH_rearr_smooth[2:-2,1] = smoothing(golierNonPTSDNonExposedACTH_rearr[:,1])

# %%
bremnerAbusedPTSDCortisol_rearr_smooth = bremnerAbusedPTSDCortisol_rearr
bremnerNonAbusedPTSDCortisol_rearr_smooth = bremnerNonAbusedPTSDCortisol_rearr
bremnerNonAbusedNonPTSDCortisol_rearr_smooth = bremnerNonAbusedNonPTSDCortisol_rearr

bremnerAbusedPTSDCortisol_rearr_smooth[2:-2,1] = smoothing(bremnerAbusedPTSDCortisol_rearr[:,1])
bremnerNonAbusedPTSDCortisol_rearr_smooth[2:-2,1] = smoothing(bremnerNonAbusedPTSDCortisol_rearr[:,1])
bremnerNonAbusedNonPTSDCortisol_rearr_smooth[2:-2,1] = smoothing(bremnerNonAbusedNonPTSDCortisol_rearr[:,1])

# %%
bremnerAbusedPTSDCortisol_smooth = bremnerAbusedPTSDCortisol
bremnerNonAbusedPTSDCortisol_smooth = bremnerNonAbusedPTSDCortisol
bremnerNonAbusedNonPTSDCortisol_smooth = bremnerNonAbusedNonPTSDCortisol

bremnerAbusedPTSDCortisol_smooth[2:-2,1] = smoothing(bremnerAbusedPTSDCortisol[:,1])
bremnerNonAbusedPTSDCortisol_smooth[2:-2,1] = smoothing(bremnerNonAbusedPTSDCortisol[:,1])
bremnerNonAbusedNonPTSDCortisol_smooth[2:-2,1] = smoothing(bremnerNonAbusedNonPTSDCortisol[:,1])

# %% [markdown]
# ### Re-run Code to Input Non-Smoothed Data into Array <a name="rerun"></a>

# %%
yehudaControlCortisol = np.genfromtxt("yehuda-control-cortisol.txt")
yehudaPTSDCortisol = np.genfromtxt("yehuda-PTSD-cortisol.txt")
yehudaDepressedCortisol = np.genfromtxt("yehuda-depressed-cortisol.txt")

# %%
# convert time scales to hours for the raw data, because the model is in terms of hours
for i in range(len(yehudaControlCortisol)):
    yehudaControlCortisol[i,0] = yehudaControlCortisol[i,0]/60
    yehudaPTSDCortisol[i,0] = yehudaPTSDCortisol[i,0]/60
    yehudaDepressedCortisol[i,0] = yehudaDepressedCortisol[i,0]/60

# %%
# extract the data from text files into 145x2 arrays
carrollControlCortisol = np.genfromtxt("controlGroupCortisolCarroll.txt", dtype = float)
carrollHCDepressedCortisol = np.genfromtxt("HCDepressedCortisolCarroll.txt", dtype = float)
carrollLCDepressedCortisol = np.genfromtxt("LCDepressedCortisolCarroll.txt", dtype = float)

carrollControlACTH = np.genfromtxt("controlGroupACTHCarroll.txt", dtype = float)
carrollHCDepressedACTH = np.genfromtxt("HCDepressedACTHCarroll.txt", dtype = float)
carrollLCDepressedACTH = np.genfromtxt("LCDepressedACTHCarroll.txt", dtype = float)

# %%
# rearrange Carroll data, so that we can start optimizing at midnight and go until 10AM 34 hours later
carrollControlCortisol_rearr = np.vstack((carrollControlCortisol[60:,:], carrollControlCortisol[0:60,:]))
carrollHCDepressedCortisol_rearr = np.vstack((carrollHCDepressedCortisol[60:,:], carrollHCDepressedCortisol[0:60,:]))
carrollLCDepressedCortisol_rearr = np.vstack((carrollLCDepressedCortisol[60:,:], carrollLCDepressedCortisol[0:60,:]))

carrollControlACTH_rearr = np.vstack((carrollControlACTH[60:,:], carrollControlACTH[0:60,:]))
carrollHCDepressedACTH_rearr = np.vstack((carrollHCDepressedACTH[60:,:], carrollHCDepressedACTH[0:60,:]))
carrollLCDepressedACTH_rearr = np.vstack((carrollLCDepressedACTH[60:,:], carrollLCDepressedACTH[0:60,:]))

# %%
golierPTSDCortisol = np.genfromtxt("golier-PTSD-cortisol.txt", dtype = float)
golierNonPTSDTraumaExposedCortisol = np.genfromtxt("golier-non-PTSD-trauma-exposed-cortisol.txt", dtype = float)
golierNonPTSDNonExposedCortisol = np.genfromtxt("golier-non-exposed-control-cortisol.txt", dtype = float)

golierPTSDACTH = np.genfromtxt("golier-PTSD-ACTH.txt", dtype = float)
golierNonPTSDTraumaExposedACTH = np.genfromtxt("golier-non-PTSD-trauma-exposed-ACTH.txt", dtype = float)
golierNonPTSDNonExposedACTH = np.genfromtxt("golier-non-exposed-control-ACTH.txt", dtype = float)

# %%
golierPTSDCortisol_rearr = np.vstack((golierPTSDCortisol[7:,:], golierPTSDCortisol[0:7,:]))
golierNonPTSDTraumaExposedCortisol_rearr = np.vstack((golierNonPTSDTraumaExposedCortisol[7:,:], golierNonPTSDTraumaExposedCortisol[0:7,:]))
golierNonPTSDNonExposedCortisol_rearr = np.vstack((golierNonPTSDNonExposedCortisol[7:,:], golierNonPTSDNonExposedCortisol[0:7,:]))

golierPTSDACTH_rearr = np.vstack((golierPTSDACTH[3:,:], golierPTSDACTH[0:3,:]))
golierNonPTSDTraumaExposedACTH_rearr = np.vstack((golierNonPTSDTraumaExposedACTH[3:,:], golierNonPTSDTraumaExposedACTH[0:3,:]))
golierNonPTSDNonExposedACTH_rearr = np.vstack((golierNonPTSDNonExposedACTH[3:,:], golierNonPTSDNonExposedACTH[0:3,:]))

# %%
bremnerAbusedPTSDCortisol = np.genfromtxt("bremner-abused-PTSD-cortisol.txt", dtype = float)
bremnerNonAbusedPTSDCortisol = np.genfromtxt("bremner-non-abused-PTSD-cortisol.txt", dtype = float)
bremnerNonAbusedNonPTSDCortisol = np.genfromtxt("bremner-non-abused-non-PTSD-cortisol.txt", dtype = float)

# %%
bremnerAbusedPTSDCortisol_rearr = np.vstack((bremnerAbusedPTSDCortisol[68:,:],bremnerAbusedPTSDCortisol[0:68,:]))
bremnerNonAbusedPTSDCortisol_rearr = np.vstack((bremnerNonAbusedPTSDCortisol[68:,:],bremnerNonAbusedPTSDCortisol[0:68,:]))
bremnerNonAbusedNonPTSDCortisol_rearr = np.vstack((bremnerNonAbusedNonPTSDCortisol[68:,:],bremnerNonAbusedNonPTSDCortisol[0:68,:]))

# %% [markdown]
# ### Plot Data Sets <a name="plotdata"></a>

# %%
# make time scale in hours for graphing
j = 0
k = 0
l = 0

timeCarroll = np.zeros(len(carrollControlCortisol[:,0]))
for i in carrollControlCortisol[:,0]:
    timeCarroll[l] = i/60
    l += 1

# %%
for i in range(len(carrollControlCortisol_rearr_smooth)):
    carrollControlACTH[i,0] = timeCarroll[i]
    carrollControlACTH_rearr[i,0] = timeCarroll[i]
    carrollControlACTH_rearr_smooth[i,0] = timeCarroll[i]
    carrollControlACTH_smooth[i,0] = timeCarroll[i]
    
    carrollControlCortisol[i,0] = timeCarroll[i]
    carrollControlCortisol_rearr[i,0] = timeCarroll[i]
    carrollControlCortisol_rearr_smooth[i,0] = timeCarroll[i]
    carrollControlCortisol_smooth[i,0] = timeCarroll[i]
    
    carrollHCDepressedACTH[i,0] = timeCarroll[i]
    carrollHCDepressedACTH_rearr[i,0] = timeCarroll[i]
    carrollHCDepressedACTH_rearr_smooth[i,0] = timeCarroll[i]
    carrollHCDepressedACTH_smooth[i,0] = timeCarroll[i]
    
    carrollLCDepressedACTH[i,0] = timeCarroll[i]
    carrollLCDepressedACTH_rearr[i,0] = timeCarroll[i]
    carrollLCDepressedACTH_rearr_smooth[i,0] = timeCarroll[i]
    carrollLCDepressedACTH_smooth[i,0] = timeCarroll[i]
    
    carrollHCDepressedCortisol[i,0] = timeCarroll[i]
    carrollHCDepressedCortisol_rearr[i,0] = timeCarroll[i]
    carrollHCDepressedCortisol_rearr_smooth[i,0] = timeCarroll[i]
    carrollHCDepressedCortisol_smooth[i,0] = timeCarroll[i]
    
    carrollLCDepressedCortisol[i,0] = timeCarroll[i]
    carrollLCDepressedCortisol_rearr[i,0] = timeCarroll[i]
    carrollLCDepressedCortisol_rearr_smooth[i,0] = timeCarroll[i]
    carrollLCDepressedCortisol_smooth[i,0] = timeCarroll[i]

# %%
for i in range(len(golierPTSDCortisol[:,0])):
    golierPTSDCortisol_rearr[i,0] = golierPTSDCortisol[i,0]
    golierPTSDCortisol_rearr_smooth[i,0] = golierPTSDCortisol[i,0]
    golierNonPTSDTraumaExposedCortisol_rearr[i,0] = golierNonPTSDTraumaExposedCortisol[i,0]
    golierNonPTSDTraumaExposedCortisol_rearr_smooth[i,0] = golierNonPTSDTraumaExposedCortisol[i,0]
    golierNonPTSDNonExposedCortisol_rearr[i,0] = golierNonPTSDNonExposedCortisol[i,0]
    golierNonPTSDNonExposedCortisol_rearr_smooth[i,0] = golierNonPTSDNonExposedCortisol[i,0]
    
for i in range(len(golierPTSDACTH[:,0])):
    golierPTSDACTH_rearr[i,0] = golierPTSDACTH[i,0]
    golierPTSDACTH_rearr_smooth[i,0] = golierPTSDACTH[i,0]
    golierNonPTSDTraumaExposedACTH_rearr[i,0] = golierNonPTSDTraumaExposedACTH[i,0]
    golierNonPTSDTraumaExposedACTH_rearr_smooth[i,0] = golierNonPTSDTraumaExposedACTH[i,0]
    golierNonPTSDNonExposedACTH_rearr[i,0] = golierNonPTSDNonExposedACTH[i,0]
    golierNonPTSDNonExposedACTH_rearr_smooth[i,0] = golierNonPTSDNonExposedACTH[i,0]

# %%
for i in range(len(bremnerAbusedPTSDCortisol[:,0])):
    bremnerAbusedPTSDCortisol_rearr[i,0] = bremnerAbusedPTSDCortisol[i,0]
    bremnerAbusedPTSDCortisol_rearr_smooth[i,0] = bremnerAbusedPTSDCortisol[i,0]
    bremnerNonAbusedPTSDCortisol_rearr[i,0] = bremnerNonAbusedPTSDCortisol[i,0]
    bremnerNonAbusedPTSDCortisol_rearr_smooth[i,0] = bremnerNonAbusedPTSDCortisol[i,0]
    bremnerNonAbusedNonPTSDCortisol_rearr[i,0] = bremnerNonAbusedNonPTSDCortisol[i,0]
    bremnerNonAbusedNonPTSDCortisol_rearr_smooth[i,0] = bremnerNonAbusedNonPTSDCortisol[i,0]

# %%
font = {'size'   : 18}
matplotlib.rc('font', **font)

fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (20,20))

ax1.plot(yehudaControlCortisol[:,0], yehudaControlCortisol[:,1], label = "Control Group Cortisol")
ax1.plot(yehudaControlCortisol_smooth[:,0], yehudaControlCortisol_smooth[:,1], label = "Control Group Cortisol - Smoothed")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax1.legend(loc="lower right", shadow = True, fancybox = True)

ax2.plot(yehudaPTSDCortisol[:,0], yehudaPTSDCortisol[:,1], label = "PTSD Group Cortisol")
ax2.plot(yehudaPTSDCortisol_smooth[:,0], yehudaPTSDCortisol_smooth[:,1], label = "PTSD Group Cortisol - Smoothed")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax2.legend(loc="lower right", shadow = True, fancybox = True)

ax3.plot(yehudaDepressedCortisol[:,0], yehudaDepressedCortisol[:,1], label = "Depression Group Cortisol")
ax3.plot(yehudaDepressedCortisol_smooth[:,0], yehudaDepressedCortisol_smooth[:,1], label = "Depression Group Cortisol - Smoothed")
ax3.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax3.legend(loc="lower right", shadow = True, fancybox = True)

# %%
#mpld3.enable_notebook()
# %matplotlib inline

font = {'size'   : 20}
matplotlib.rc('font', **font)
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows = 4, figsize = (25,25))

ax1.plot(carrollControlCortisol_rearr[:,0], carrollControlCortisol_rearr[:,1], 'b', label = "Control")
ax1.plot(carrollHCDepressedCortisol_rearr[:,0], carrollHCDepressedCortisol_rearr[:,1], 'r', label = "High Cortisol Depressed")
ax1.plot(carrollControlCortisol_rearr_smooth[:,0], carrollControlCortisol_rearr_smooth[:,1], label = "Control - Smoothed")
ax1.plot(carrollHCDepressedCortisol_rearr_smooth[:,0], carrollHCDepressedCortisol_rearr_smooth[:,1], label = "High Cortisol Depressed - Smoothed")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax1.legend(loc="upper right", shadow = True, fancybox = True)

ax2.plot(carrollControlCortisol_rearr[:,0], carrollControlCortisol_rearr[:,1], 'b', label = "Control")
ax2.plot(carrollLCDepressedCortisol_rearr[:,0], carrollLCDepressedCortisol_rearr[:,1], 'g', label = "Low Cortisol Depressed")
ax2.plot(carrollControlCortisol_rearr_smooth[:,0], carrollControlCortisol_rearr_smooth[:,1], label = "Control - Smoothed")
ax2.plot(carrollLCDepressedCortisol_rearr_smooth[:,0], carrollLCDepressedCortisol_rearr_smooth[:,1], label = "Low Cortisol Depressed - Smoothed")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (micrograms/dL)")
ax2.legend(loc="upper right", shadow = True, fancybox = True)

ax3.plot(carrollControlACTH_rearr[:,0], carrollControlACTH_rearr[:,1], 'b', label = "Control")
ax3.plot(carrollHCDepressedACTH_rearr[:,0], carrollHCDepressedACTH_rearr[:,1], 'r', label = "High Cortisol Depressed")
ax3.plot(carrollControlACTH_rearr_smooth[:,0], carrollControlACTH_rearr_smooth[:,1], label = "Control - Smoothed")
ax3.plot(carrollHCDepressedACTH_rearr_smooth[:,0], carrollHCDepressedACTH_rearr_smooth[:,1], label = "High Cortisol Depressed - Smoothed")
ax3.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax3.legend(loc="upper right", shadow = True, fancybox = True)

ax4.plot(carrollControlACTH_rearr[:,0], carrollControlACTH_rearr[:,1], 'b', label = "Control")
ax4.plot(carrollLCDepressedACTH_rearr[:,0], carrollLCDepressedACTH_rearr[:,1], 'g', label = "Low Cortisol Depressed")
ax4.plot(carrollControlACTH_rearr_smooth[:,0], carrollControlACTH_rearr_smooth[:,1], label = "Control - Smoothed")
ax4.plot(carrollLCDepressedACTH_rearr_smooth[:,0], carrollLCDepressedACTH_rearr_smooth[:,1], label = "Low Cortisol Depressed - Smoothed")
ax4.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax4.legend(loc="upper right", shadow = True, fancybox = True)

# %%
# %matplotlib inline

fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(nrows = 6, figsize = (15,20))

ax1.plot(golierPTSDCortisol_rearr_smooth[:,0], golierPTSDCortisol_rearr_smooth[:,1], label = "Trauma Exposed PTSD Cortisol - Smoothed")
ax1.plot(golierPTSDCortisol_rearr[:,0], golierPTSDCortisol_rearr[:,1], label = "Trauma Exposed PTSD Cortisol")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (mg/dL)")
ax1.legend(loc="lower right", shadow = True, fancybox = True)

ax2.plot(golierNonPTSDTraumaExposedCortisol_rearr_smooth[:,0], golierNonPTSDTraumaExposedCortisol_rearr_smooth[:,1], label = "Trauma Exposed Non-PTSD Cortisol - Smoothed")
ax2.plot(golierNonPTSDTraumaExposedCortisol_rearr[:,0], golierNonPTSDTraumaExposedCortisol_rearr[:,1], label = "Trauma Exposed Non-PTSD Cortisol")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (mg/dL)")
ax2.legend(loc="lower right", shadow = True, fancybox = True)

ax3.plot(golierNonPTSDNonExposedCortisol_rearr_smooth[:,0], golierNonPTSDNonExposedCortisol_rearr_smooth[:,1], label = "Non-Exposed Non-PTSD Cortisol - Smoothed")
ax3.plot(golierNonPTSDNonExposedCortisol_rearr[:,0], golierNonPTSDNonExposedCortisol_rearr[:,1], label = "Non-Exposed Non-PTSD Cortisol")
ax3.set(xlabel="Time (hours)", ylabel="Cortisol (mg/dL)")
ax3.legend(loc="lower right", shadow = True, fancybox = True)

ax4.plot(golierPTSDACTH_rearr_smooth[:,0], golierPTSDACTH_rearr_smooth[:,1], label = "Trauma Exposed PTSD ACTH - Smoothed")
ax4.plot(golierPTSDACTH_rearr[:,0], golierPTSDACTH_rearr[:,1], label = "Trauma Exposed PTSD ACTH")
ax4.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax4.legend(loc="lower right", shadow = True, fancybox = True)

ax5.plot(golierNonPTSDTraumaExposedACTH_rearr_smooth[:,0], golierNonPTSDTraumaExposedACTH_rearr_smooth[:,1], label = "Trauma Exposed Non-PTSD ACTH - Smoothed")
ax5.plot(golierNonPTSDTraumaExposedACTH_rearr[:,0], golierNonPTSDTraumaExposedACTH_rearr[:,1], label = "Trauma Exposed Non-PTSD ACTH")
ax5.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax5.legend(loc="lower right", shadow = True, fancybox = True)

ax6.plot(golierNonPTSDNonExposedACTH_rearr_smooth[:,0], golierNonPTSDNonExposedACTH_rearr_smooth[:,1], label = "Non-Exposed Non-PTSD ACTH - Smoothed")
ax6.plot(golierNonPTSDNonExposedACTH_rearr[:,0], golierNonPTSDNonExposedACTH_rearr[:,1], label = "Non-Exposed Non-PTSD ACTH")
ax6.set(xlabel="Time (hours)", ylabel="ACTH (pg/mL)")
ax6.legend(loc="lower right", shadow = True, fancybox = True)

# %%
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (15,15))

ax1.plot(bremnerAbusedPTSDCortisol_rearr_smooth[:,0], bremnerAbusedPTSDCortisol_rearr_smooth[:,1], label = "Abused PTSD Cortisol - Smoothed")
ax1.plot(bremnerAbusedPTSDCortisol_rearr[:,0], bremnerAbusedPTSDCortisol_rearr[:,1], label = "Abused PTSD Cortisol")
ax1.set(xlabel="Time (hours)", ylabel="Cortisol (microg/dL)")
ax1.legend(loc="lower right", shadow = True, fancybox = True)

ax2.plot(bremnerNonAbusedPTSDCortisol_rearr_smooth[:,0], bremnerNonAbusedPTSDCortisol_rearr_smooth[:,1], label = "Non-Abused PTSD Cortisol - Smoothed")
ax2.plot(bremnerNonAbusedPTSDCortisol_rearr[:,0], bremnerNonAbusedPTSDCortisol_rearr[:,1], label = "Non-Abused PTSD Cortisol")
ax2.set(xlabel="Time (hours)", ylabel="Cortisol (microg/dL)")
ax2.legend(loc="lower right", shadow = True, fancybox = True)

ax3.plot(bremnerNonAbusedNonPTSDCortisol_rearr_smooth[:,0], bremnerNonAbusedNonPTSDCortisol_rearr_smooth[:,1], label = "Non-Abused Non-PTSD Cortisol - Smoothed")
ax3.plot(bremnerNonAbusedNonPTSDCortisol_rearr[:,0], bremnerNonAbusedNonPTSDCortisol_rearr[:,1], label = "Non-Abused Non-PTSD Cortisol")
ax3.set(xlabel="Time (hours)", ylabel="Cortisol (microg/dL)")
ax3.legend(loc="lower left", shadow = True, fancybox = True)

# %%
# arrange and graph the Nelson data
nelsonACTH_mean = np.zeros(11)
nelsonCortisol_mean = np.zeros(11)
nelsonACTH = np.zeros((11,60))
nelsonCortisol = np.zeros((11,60))


for i in range(len(nelsonACTH_data[1,:])-1):
    nelsonACTH_mean[i] = np.mean(nelsonACTH_data[:,i+1])
    nelsonCortisol_mean[i] = np.mean(nelsonCortisol_data[:,i+1])

t_nelson = np.array([0, 15, 30, 40, 50, 65, 80, 95, 110, 125, 140])
t_nelson = t_nelson/60

for i in range(len(t_nelson)):
    nelsonACTH[i,0] = t_nelson[i]
    nelsonACTH[i,1] = nelsonACTH_mean[i]
    
    nelsonCortisol[i,0] = t_nelson[i]
    nelsonCortisol[i,1] = nelsonCortisol_mean[i]
    
for i in range(len(nelsonACTH_data)):
    for j in range(len(t_nelson)):
        nelsonACTH[j,i+2] = nelsonACTH_data[i,j+1]
        nelsonCortisol[j,i+2] = nelsonCortisol_data[i,j+1]
    
    

fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (15, 15))

ax1.plot(nelsonACTH[:,0], nelsonACTH[:,3])
ax2.plot(nelsonCortisol[:,0], nelsonCortisol[:,3])

# %% [markdown]
# ## Model Function--Includes ODE Solver <a name="modelfunction"></a>

# %%
def model(params, ics):
    def ode_system(t, y):
        dy = np.zeros(4)

        [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress] = params
        
        # uncomment this and comment out the other version of dy[0] to add the stress_input function
        #dy[0] = stress_input(t)*k_stress*(k_i**n2/(k_i**n2 + y[3]**n2)) - V_S3*(y[0]/(K_m1 + y[0])) - K_d1*y[0]
        dy[0] = k_stress*(k_i**n2/(k_i**n2 + y[3]**n2)) - V_S3*(y[0]/(K_m1 + y[0])) - K_d1*y[0]
        dy[1] = K_P2*y[0]*(k_i**n2/(k_i**n2 + y[3]**n2)) - V_S4*(y[1]/(K_m2 + y[1])) - K_d2*y[1]
        dy[2] = K_P3*y[1] - V_S5*(y[2]/(K_m3 + y[2])) - K_d3*y[2]
        dy[3] = K_b*y[2]*(G_tot - y[3]) + V_S2*(y[3]**n1/(K1**n1 + y[3]**n1)) - K_d5*y[3]

        return dy
    
    def stress_input(t):
        #if (0.5 <= t <= 0.51):
        if (t >= 0.5):
            return p_stress
        else:
            return 1
    
    # solve the system with scipy.integrate.ode to see if it's any faster
    solver = sci.ode(ode_system)
    solver.set_integrator('vode', method='bdf', atol=3e-12, rtol=1e-12, nsteps = 100000)
    solver.set_initial_value(ics, t_start)
    
    ts = []
    ys = []
    
    while solver.successful() and solver.t < t_end:
        solver.integrate(solver.t + t_step)
        ts.append(solver.t)
        ys.append(solver.y)

    # reshape the output frome ode to an array with the times on the first column
    ts = np.reshape(ts, (len(ts),1))
    ys = np.vstack(ys)
    timeSeries = np.hstack((ts, ys))
    return timeSeries

# %% [markdown]
# ## Cost Function Definition <a name="cost"></a>

# %%
def cost_fun(params):
    # call the solve function
    simData = model(params, y0)
    
    time_ACTH = nelsonACTH[:,0]
    data_ACTH = nelsonACTH[:,41]
    time_CORT = nelsonCortisol[:,0]
    data_CORT = nelsonCortisol[:,41]
        
    # start by computing the mean concentration of the data set to be matched for each
    # hormone to be matched
    mean_ACTH = np.mean(data_ACTH)
    mean_CORT = np.mean(data_CORT)
    
    # normalize the simData arrays by the mean values of data set to be matched
    simNorm_ACTH = simData[:,2]/mean_ACTH
    simNorm_CORT = simData[:,3]/mean_CORT
    
    # normalize the data set to be matched, as well
    dataNorm_ACTH = data_ACTH/mean_ACTH
    dataNorm_CORT = data_CORT/mean_CORT
    
    # here, rick performs a cubic interpolation between time steps
    # I could either do this, or just compute the SSE between the raw data and computed data points without doing
    # the interpolation (as long as every raw data point is hit by the time steps the model computes)
    spline_ACTH = interp1d(simData[:,0], simNorm_ACTH, kind = 'linear')
    spline_CORT = interp1d(simData[:,0], simNorm_CORT, kind = 'linear')
    
    try:
        # compute the actual cost value for the current parameter set by finding SSE between raw data and splines
        # this is where we change the data set we are trying to match, so that it computes the cost based on whatever
        #     data set we put in as the x values into the spline and the y values to subtract
        acthSSE = np.sum((spline_ACTH(time_ACTH) - dataNorm_ACTH)**2)
        cortSSE = np.sum((spline_CORT(time_CORT) - dataNorm_CORT)**2)
        
        # if i run it with acth data, also, can make cost the average of cortisol and ACTH SSEs
        cost = (acthSSE+cortSSE)/2
        # for now though, cost is just the SSE of cortisol data and simulation
        #cost = cortSSE
        
        return cost
    except ValueError:
        print("ODE solver did not make through all data points.")

# %%
# old cost function definition without normalization of values
# I'll keep it here just in case, but I think it was weighting ACTH values much more heavily
# than cortisol values for matching
def cost_fun(params):
    # call the solve function
    simData = model(params, y0)
    
    # this is where Rick makes sure we only have unique values for t, so no time step is repeated
    # I'll include it commented out here, and see if it changes anything later
    #idx = np.unique(simData[:,0], return_index = True)
    #idx = idx[1]
    #simData = simData[idx,:]
    
    # here, rick performs a cubic interpolation between time steps
    # I could either do this, or just compute the SSE between the raw data and computed data points without doing
    # the interpolation (as long as every raw data point is hit by the time steps the model computes)
    spline_ACTH = interp1d(simData[:,0], simData[:,2], kind = 'linear')
    spline_CORT = interp1d(simData[:,0], simData[:,3], kind = 'linear')
    
    try:
        # compute the actual cost value for the current parameter set by finding SSE between raw data and splines
        # this is where we change the data set we are trying to match, so that it computes the cost based on whatever
        #     data set we put in as the x values into the spline and the y values to subtract
        acthSSE = np.sum((spline_ACTH(nelsonACTH[:,0]) - nelsonACTH[:,51])**2)
        cortSSE = np.sum((spline_CORT(nelsonCortisol[:,0]) - nelsonCortisol[:,51])**2)
        
        # if i run it with acth data, also, can make cost the average of cortisol and ACTH SSEs
        cost = (acthSSE+cortSSE)/2
        # for now though, cost is just the SSE of cortisol data and simulation
        #cost = cortSSE
        
        return cost
    except ValueError:
        print("ODE solver did not make through all data points.")

# %% [markdown]
# ## Run the Optimization <a name="run"></a>

# %%
print(nelsonACTH[0,51], nelsonCortisol[0,51])
# Out:
# 11.4 5.3

# %%
# it looks, based on the XPP file from the authors, like they start CRH, ACTH, CORT and GR at 0 each and just run
# the solver until they reach some steady state

y0 = [1, nelsonACTH[0,41], nelsonCortisol[0,41], 2]

# %%
# number of times to run the optimization
n = 5

# define an array to hold the population of parameter vectors
opt_pars = np.zeros((n, len(bounds)+1))

# initialize arrays to save simulation cortisol and ACTH data from each optimization
sims_cort = np.zeros((237, n))
sims_acth = np.zeros((237, n))
sims_crh = np.zeros((237, n))
sims_gr = np.zeros((237, n))

# %%
# %%time

# loop n times, running the optimization each time
for i in range(0,n):
    
    print(f"Optimization Run #{i+1}")
    
    # call the differential evolution optimization function on the cost function
    res = sco.differential_evolution(cost_fun, bounds, maxiter = 999, disp = True, popsize = 1)
    
    # alternatively, we can run the SHGO algorithm with the sampling_method = "sobol" flag to do global
    #     optimization with reporting all local minima, as well
    #res = sco.shgo(cost_fun, bounds, callback=callback_fun(*shgo_iter_steps), options = {"f_min": 0.1, "maxiter": None, "minimize_every_iter": True, "local_iter": False, "disp": True}, iters = 3)
    #res = sco.basinhopping(cost_fun, x0, niter = 1000)
    #res = sco.dual_annealing(cost_fun, bounds)
    
    # plug the optimized parameters into the solver
    optimizedSimData = model(res.x, y0)
    # save CRH, cortisol and ACTH data into sims arrays
    sims_gr[:,i] = optimizedSimData[:,4]
    sims_cort[:,i] = optimizedSimData[:,3]
    sims_acth[:,i] = optimizedSimData[:,2]
    sims_crh[:,i] = optimizedSimData[:,1]
    
    # save the cost function values and optimized parameters for each iteration into the array opt_pars
    opt_pars[i,0] = res.fun
    opt_pars[i,1:] = res.x
# Out:
# Optimization Run #1
# differential_evolution step 1: f(x)= 1.46628
# differential_evolution step 2: f(x)= 1.15396
# differential_evolution step 3: f(x)= 1.01939
# differential_evolution step 4: f(x)= 0.467447
# differential_evolution step 5: f(x)= 0.467447
# differential_evolution step 6: f(x)= 0.467447
# differential_evolution step 7: f(x)= 0.277564
# differential_evolution step 8: f(x)= 0.277564
# differential_evolution step 9: f(x)= 0.277564
# differential_evolution step 10: f(x)= 0.225956
# differential_evolution step 11: f(x)= 0.153745
# differential_evolution step 12: f(x)= 0.153745
# differential_evolution step 13: f(x)= 0.153745
# differential_evolution step 14: f(x)= 0.153745
# differential_evolution step 15: f(x)= 0.153745
# differential_evolution step 16: f(x)= 0.153745
# differential_evolution step 17: f(x)= 0.153745
# differential_evolution step 18: f(x)= 0.15288
# differential_evolution step 19: f(x)= 0.106
# differential_evolution step 20: f(x)= 0.106
# differential_evolution step 21: f(x)= 0.106
# differential_evolution step 22: f(x)= 0.106
# differential_evolution step 23: f(x)= 0.106
# differential_evolution step 24: f(x)= 0.092545
# differential_evolution step 25: f(x)= 0.092545
# differential_evolution step 26: f(x)= 0.092545
# differential_evolution step 27: f(x)= 0.092545
# differential_evolution step 28: f(x)= 0.092545
# differential_evolution step 29: f(x)= 0.092545
# differential_evolution step 30: f(x)= 0.092545
# differential_evolution step 31: f(x)= 0.092545
# differential_evolution step 32: f(x)= 0.092545
# differential_evolution step 33: f(x)= 0.092545
# differential_evolution step 34: f(x)= 0.092545
# differential_evolution step 35: f(x)= 0.0882998
# differential_evolution step 36: f(x)= 0.0882998
# differential_evolution step 37: f(x)= 0.0882998
# differential_evolution step 38: f(x)= 0.0882998
# differential_evolution step 39: f(x)= 0.0882998
# differential_evolution step 40: f(x)= 0.0882998
# differential_evolution step 41: f(x)= 0.0882998
# differential_evolution step 42: f(x)= 0.0882998
# differential_evolution step 43: f(x)= 0.0882998
# differential_evolution step 44: f(x)= 0.0882998
# differential_evolution step 45: f(x)= 0.0882998
# differential_evolution step 46: f(x)= 0.0882998
# differential_evolution step 47: f(x)= 0.0882998
# differential_evolution step 48: f(x)= 0.0882998
# differential_evolution step 49: f(x)= 0.0882998
# differential_evolution step 50: f(x)= 0.0882998
# differential_evolution step 51: f(x)= 0.0882998
# differential_evolution step 52: f(x)= 0.0882998
# differential_evolution step 53: f(x)= 0.0882998
# differential_evolution step 54: f(x)= 0.0882998
# differential_evolution step 55: f(x)= 0.0882998
# differential_evolution step 56: f(x)= 0.0856019
# differential_evolution step 57: f(x)= 0.0856019
# differential_evolution step 58: f(x)= 0.0798661
# differential_evolution step 59: f(x)= 0.0798661
# differential_evolution step 60: f(x)= 0.0798661
# differential_evolution step 61: f(x)= 0.0798661
# differential_evolution step 62: f(x)= 0.0798661
# differential_evolution step 63: f(x)= 0.0798661
# differential_evolution step 64: f(x)= 0.0798661
# differential_evolution step 65: f(x)= 0.0798661
# differential_evolution step 66: f(x)= 0.0798661
# differential_evolution step 67: f(x)= 0.0798661
# differential_evolution step 68: f(x)= 0.0798661
# differential_evolution step 69: f(x)= 0.0798661
# differential_evolution step 70: f(x)= 0.0798661
# differential_evolution step 71: f(x)= 0.0792363
# differential_evolution step 72: f(x)= 0.0792363
# differential_evolution step 73: f(x)= 0.0770353
# differential_evolution step 74: f(x)= 0.0770353
# differential_evolution step 75: f(x)= 0.0770353
# differential_evolution step 76: f(x)= 0.0770353
# differential_evolution step 77: f(x)= 0.0770353
# differential_evolution step 78: f(x)= 0.0755094
# differential_evolution step 79: f(x)= 0.0755094
# differential_evolution step 80: f(x)= 0.0755094
# differential_evolution step 81: f(x)= 0.0755094
# differential_evolution step 82: f(x)= 0.0755094
# differential_evolution step 83: f(x)= 0.0755094
# differential_evolution step 84: f(x)= 0.0745213
# differential_evolution step 85: f(x)= 0.0745213
# differential_evolution step 86: f(x)= 0.0723041
# differential_evolution step 87: f(x)= 0.0723041
# differential_evolution step 88: f(x)= 0.0708444
# differential_evolution step 89: f(x)= 0.0708444
# differential_evolution step 90: f(x)= 0.0675847
# differential_evolution step 91: f(x)= 0.0675847
# differential_evolution step 92: f(x)= 0.0675847
# differential_evolution step 93: f(x)= 0.0657746
# differential_evolution step 94: f(x)= 0.0657746
# differential_evolution step 95: f(x)= 0.0657746
# differential_evolution step 96: f(x)= 0.0655253
# differential_evolution step 97: f(x)= 0.0655253
# differential_evolution step 98: f(x)= 0.0655253
# differential_evolution step 99: f(x)= 0.0655253
# differential_evolution step 100: f(x)= 0.0655253
# differential_evolution step 101: f(x)= 0.0655253
# differential_evolution step 102: f(x)= 0.0654152
# differential_evolution step 103: f(x)= 0.0654152
# differential_evolution step 104: f(x)= 0.0654152
# differential_evolution step 105: f(x)= 0.0654152
# differential_evolution step 106: f(x)= 0.0654152
# differential_evolution step 107: f(x)= 0.0654152
# differential_evolution step 108: f(x)= 0.0654152
# differential_evolution step 109: f(x)= 0.0654152
# differential_evolution step 110: f(x)= 0.0654152
# differential_evolution step 111: f(x)= 0.0653127
# differential_evolution step 112: f(x)= 0.0653127
# differential_evolution step 113: f(x)= 0.0651675
# differential_evolution step 114: f(x)= 0.0651675
# differential_evolution step 115: f(x)= 0.0651675
# differential_evolution step 116: f(x)= 0.0651675
# differential_evolution step 117: f(x)= 0.0651675
# differential_evolution step 118: f(x)= 0.0651675
# differential_evolution step 119: f(x)= 0.0651675
# differential_evolution step 120: f(x)= 0.0651675
# differential_evolution step 121: f(x)= 0.0651675
# differential_evolution step 122: f(x)= 0.0651675
# differential_evolution step 123: f(x)= 0.0651675
# differential_evolution step 124: f(x)= 0.0651675
# differential_evolution step 125: f(x)= 0.0651675
# differential_evolution step 126: f(x)= 0.0651675
# differential_evolution step 127: f(x)= 0.0651675
# differential_evolution step 128: f(x)= 0.0651675
# differential_evolution step 129: f(x)= 0.0640726
# differential_evolution step 130: f(x)= 0.0640726
# differential_evolution step 131: f(x)= 0.0640726
# differential_evolution step 132: f(x)= 0.0640468
# differential_evolution step 133: f(x)= 0.0640468
# differential_evolution step 134: f(x)= 0.0640468
# differential_evolution step 135: f(x)= 0.0640468
# differential_evolution step 136: f(x)= 0.0640468
# differential_evolution step 137: f(x)= 0.0640468
# differential_evolution step 138: f(x)= 0.0640468
# differential_evolution step 139: f(x)= 0.0640468
# differential_evolution step 140: f(x)= 0.0640468
# differential_evolution step 141: f(x)= 0.0640468
# differential_evolution step 142: f(x)= 0.0640468
# differential_evolution step 143: f(x)= 0.0640468
# differential_evolution step 144: f(x)= 0.0640468
# differential_evolution step 145: f(x)= 0.0640468
# differential_evolution step 146: f(x)= 0.0640468
# differential_evolution step 147: f(x)= 0.0639487
# differential_evolution step 148: f(x)= 0.0639487
# differential_evolution step 149: f(x)= 0.0629523
# differential_evolution step 150: f(x)= 0.0629523
# differential_evolution step 151: f(x)= 0.0629523
# differential_evolution step 152: f(x)= 0.0629523
# differential_evolution step 153: f(x)= 0.0629523
# differential_evolution step 154: f(x)= 0.0629523
# differential_evolution step 155: f(x)= 0.0629523
# differential_evolution step 156: f(x)= 0.0629523
# differential_evolution step 157: f(x)= 0.0629523
# differential_evolution step 158: f(x)= 0.0629523
# differential_evolution step 159: f(x)= 0.0629523
# differential_evolution step 160: f(x)= 0.0629523
# differential_evolution step 161: f(x)= 0.0629523
# differential_evolution step 162: f(x)= 0.0626036
# differential_evolution step 163: f(x)= 0.0626036
# differential_evolution step 164: f(x)= 0.0626036
# differential_evolution step 165: f(x)= 0.0626036
# differential_evolution step 166: f(x)= 0.0626036
# differential_evolution step 167: f(x)= 0.0626036
# differential_evolution step 168: f(x)= 0.0626036
# differential_evolution step 169: f(x)= 0.0626036
# differential_evolution step 170: f(x)= 0.0626036
# differential_evolution step 171: f(x)= 0.0623585
# differential_evolution step 172: f(x)= 0.0623585
# differential_evolution step 173: f(x)= 0.0623585
# differential_evolution step 174: f(x)= 0.0623585
# differential_evolution step 175: f(x)= 0.0621249
# differential_evolution step 176: f(x)= 0.0621249
# differential_evolution step 177: f(x)= 0.0621249
# differential_evolution step 178: f(x)= 0.0621249
# differential_evolution step 179: f(x)= 0.0621249
# differential_evolution step 180: f(x)= 0.0621249
# differential_evolution step 181: f(x)= 0.0621249
# differential_evolution step 182: f(x)= 0.0621249
# differential_evolution step 183: f(x)= 0.0621249
# differential_evolution step 184: f(x)= 0.0621249
# differential_evolution step 185: f(x)= 0.062075
# differential_evolution step 186: f(x)= 0.062075
# differential_evolution step 187: f(x)= 0.062075
# differential_evolution step 188: f(x)= 0.062075
# differential_evolution step 189: f(x)= 0.062075
# differential_evolution step 190: f(x)= 0.062075
# differential_evolution step 191: f(x)= 0.062075
# differential_evolution step 192: f(x)= 0.062075
# differential_evolution step 193: f(x)= 0.062075
# differential_evolution step 194: f(x)= 0.0619871
# differential_evolution step 195: f(x)= 0.0619871
# differential_evolution step 196: f(x)= 0.0619871
# differential_evolution step 197: f(x)= 0.0619871
# differential_evolution step 198: f(x)= 0.0617002
# differential_evolution step 199: f(x)= 0.0617002
# differential_evolution step 200: f(x)= 0.0615576
# differential_evolution step 201: f(x)= 0.0615576
# differential_evolution step 202: f(x)= 0.0615576
# differential_evolution step 203: f(x)= 0.0615576
# differential_evolution step 204: f(x)= 0.0615576
# differential_evolution step 205: f(x)= 0.0615576
# differential_evolution step 206: f(x)= 0.0615576
# differential_evolution step 207: f(x)= 0.0615576
# differential_evolution step 208: f(x)= 0.0615576
# differential_evolution step 209: f(x)= 0.0615576
# differential_evolution step 210: f(x)= 0.0615576
# differential_evolution step 211: f(x)= 0.0615576
# differential_evolution step 212: f(x)= 0.0615576
# differential_evolution step 213: f(x)= 0.0615576
# differential_evolution step 214: f(x)= 0.0615576
# differential_evolution step 215: f(x)= 0.0615576
# differential_evolution step 216: f(x)= 0.0615576
# differential_evolution step 217: f(x)= 0.0607523
# differential_evolution step 218: f(x)= 0.0607523
# differential_evolution step 219: f(x)= 0.0607523
# differential_evolution step 220: f(x)= 0.0607523
# differential_evolution step 221: f(x)= 0.0607523
# differential_evolution step 222: f(x)= 0.0607523
# differential_evolution step 223: f(x)= 0.0607523
# differential_evolution step 224: f(x)= 0.0607523
# Optimization Run #2
# differential_evolution step 1: f(x)= 1.13875
# differential_evolution step 2: f(x)= 0.804952
# differential_evolution step 3: f(x)= 0.463015
# differential_evolution step 4: f(x)= 0.463015
# differential_evolution step 5: f(x)= 0.458916
# differential_evolution step 6: f(x)= 0.205658
# differential_evolution step 7: f(x)= 0.2
# differential_evolution step 8: f(x)= 0.2
# differential_evolution step 9: f(x)= 0.2
# differential_evolution step 10: f(x)= 0.2
# differential_evolution step 11: f(x)= 0.2
# differential_evolution step 12: f(x)= 0.2
# differential_evolution step 13: f(x)= 0.2
# differential_evolution step 14: f(x)= 0.2
# differential_evolution step 15: f(x)= 0.17265
# differential_evolution step 16: f(x)= 0.17265
# differential_evolution step 17: f(x)= 0.17265
# differential_evolution step 18: f(x)= 0.148161
# differential_evolution step 19: f(x)= 0.148161
# differential_evolution step 20: f(x)= 0.148161
# differential_evolution step 21: f(x)= 0.137994
# differential_evolution step 22: f(x)= 0.137994
# differential_evolution step 23: f(x)= 0.137994
# differential_evolution step 24: f(x)= 0.0742348
# differential_evolution step 25: f(x)= 0.0742348
# differential_evolution step 26: f(x)= 0.0742348
# differential_evolution step 27: f(x)= 0.0742348
# differential_evolution step 28: f(x)= 0.0742348
# differential_evolution step 29: f(x)= 0.0742348
# differential_evolution step 30: f(x)= 0.0742348
# differential_evolution step 31: f(x)= 0.0742348
# differential_evolution step 32: f(x)= 0.0742348
# differential_evolution step 33: f(x)= 0.0742348
# differential_evolution step 34: f(x)= 0.0742348
# differential_evolution step 35: f(x)= 0.0742348
# differential_evolution step 36: f(x)= 0.0742348
# differential_evolution step 37: f(x)= 0.0742348
# differential_evolution step 38: f(x)= 0.0742348
# differential_evolution step 39: f(x)= 0.0742348
# differential_evolution step 40: f(x)= 0.0742348
# differential_evolution step 41: f(x)= 0.0742348
# differential_evolution step 42: f(x)= 0.0742348
# differential_evolution step 43: f(x)= 0.0742348
# differential_evolution step 44: f(x)= 0.0742348
# differential_evolution step 45: f(x)= 0.0742348
# differential_evolution step 46: f(x)= 0.0742348
# differential_evolution step 47: f(x)= 0.0742348
# differential_evolution step 48: f(x)= 0.0742348
# differential_evolution step 49: f(x)= 0.0742348
# differential_evolution step 50: f(x)= 0.0742348
# differential_evolution step 51: f(x)= 0.070254
# differential_evolution step 52: f(x)= 0.070254
# differential_evolution step 53: f(x)= 0.070254
# differential_evolution step 54: f(x)= 0.070254
# differential_evolution step 55: f(x)= 0.070254
# differential_evolution step 56: f(x)= 0.070254
# differential_evolution step 57: f(x)= 0.070254
# differential_evolution step 58: f(x)= 0.070254
# differential_evolution step 59: f(x)= 0.070254
# differential_evolution step 60: f(x)= 0.070254
# differential_evolution step 61: f(x)= 0.070254
# differential_evolution step 62: f(x)= 0.0645166
# differential_evolution step 63: f(x)= 0.0645166
# differential_evolution step 64: f(x)= 0.0645166
# differential_evolution step 65: f(x)= 0.0645166
# differential_evolution step 66: f(x)= 0.0645166
# differential_evolution step 67: f(x)= 0.0645166
# differential_evolution step 68: f(x)= 0.0645166
# differential_evolution step 69: f(x)= 0.0645166
# differential_evolution step 70: f(x)= 0.0645166
# differential_evolution step 71: f(x)= 0.0645166
# differential_evolution step 72: f(x)= 0.0645166
# differential_evolution step 73: f(x)= 0.0645166
# differential_evolution step 74: f(x)= 0.0645166
# differential_evolution step 75: f(x)= 0.0645166
# differential_evolution step 76: f(x)= 0.0645166
# differential_evolution step 77: f(x)= 0.0645166
# differential_evolution step 78: f(x)= 0.0645166
# differential_evolution step 79: f(x)= 0.0645166
# differential_evolution step 80: f(x)= 0.0645166
# differential_evolution step 81: f(x)= 0.0645166
# differential_evolution step 82: f(x)= 0.0645166
# differential_evolution step 83: f(x)= 0.0645166
# differential_evolution step 84: f(x)= 0.0645166
# differential_evolution step 85: f(x)= 0.0645166
# differential_evolution step 86: f(x)= 0.0622267
# differential_evolution step 87: f(x)= 0.0622267
# differential_evolution step 88: f(x)= 0.0622267
# differential_evolution step 89: f(x)= 0.0622267
# differential_evolution step 90: f(x)= 0.0622267
# differential_evolution step 91: f(x)= 0.0622267
# differential_evolution step 92: f(x)= 0.0622267
# differential_evolution step 93: f(x)= 0.0622267
# differential_evolution step 94: f(x)= 0.0622267
# differential_evolution step 95: f(x)= 0.0622267
# differential_evolution step 96: f(x)= 0.0622267
# differential_evolution step 97: f(x)= 0.0622267
# differential_evolution step 98: f(x)= 0.0622267
# differential_evolution step 99: f(x)= 0.0622267
# differential_evolution step 100: f(x)= 0.0621968
# differential_evolution step 101: f(x)= 0.0621968
# differential_evolution step 102: f(x)= 0.0621968
# differential_evolution step 103: f(x)= 0.0621968
# differential_evolution step 104: f(x)= 0.0621968
# differential_evolution step 105: f(x)= 0.0621968
# differential_evolution step 106: f(x)= 0.0621968
# differential_evolution step 107: f(x)= 0.0621968
# differential_evolution step 108: f(x)= 0.0621968
# differential_evolution step 109: f(x)= 0.0616719
# differential_evolution step 110: f(x)= 0.0616719
# differential_evolution step 111: f(x)= 0.0616719
# differential_evolution step 112: f(x)= 0.0616719
# differential_evolution step 113: f(x)= 0.0616719
# differential_evolution step 114: f(x)= 0.0616719
# differential_evolution step 115: f(x)= 0.0616719
# differential_evolution step 116: f(x)= 0.0616719
# differential_evolution step 117: f(x)= 0.0616719
# differential_evolution step 118: f(x)= 0.0616719
# differential_evolution step 119: f(x)= 0.0616719
# differential_evolution step 120: f(x)= 0.0616582
# differential_evolution step 121: f(x)= 0.0616582
# differential_evolution step 122: f(x)= 0.0616582
# differential_evolution step 123: f(x)= 0.0616582
# differential_evolution step 124: f(x)= 0.0616582
# differential_evolution step 125: f(x)= 0.0616582
# differential_evolution step 126: f(x)= 0.0616582
# differential_evolution step 127: f(x)= 0.0616582
# differential_evolution step 128: f(x)= 0.0616582
# differential_evolution step 129: f(x)= 0.0616582
# differential_evolution step 130: f(x)= 0.0616582
# differential_evolution step 131: f(x)= 0.0616582
# differential_evolution step 132: f(x)= 0.0616582
# differential_evolution step 133: f(x)= 0.0616582
# differential_evolution step 134: f(x)= 0.0616582
# differential_evolution step 135: f(x)= 0.0616582
# differential_evolution step 136: f(x)= 0.0616582
# differential_evolution step 137: f(x)= 0.0616582
# differential_evolution step 138: f(x)= 0.0616582
# differential_evolution step 139: f(x)= 0.0616582
# differential_evolution step 140: f(x)= 0.0616582
# differential_evolution step 141: f(x)= 0.0616582
# differential_evolution step 142: f(x)= 0.0616582
# differential_evolution step 143: f(x)= 0.0616582
# differential_evolution step 144: f(x)= 0.0616582
# differential_evolution step 145: f(x)= 0.0616582
# differential_evolution step 146: f(x)= 0.0616582
# differential_evolution step 147: f(x)= 0.0616582
# differential_evolution step 148: f(x)= 0.0616582
# differential_evolution step 149: f(x)= 0.0616582
# differential_evolution step 150: f(x)= 0.0616582
# differential_evolution step 151: f(x)= 0.0616582
# Optimization Run #3
# differential_evolution step 1: f(x)= 1.43136
# differential_evolution step 2: f(x)= 1.12608
# differential_evolution step 3: f(x)= 1.07364
# differential_evolution step 4: f(x)= 1.07364
# differential_evolution step 5: f(x)= 1.07364
# differential_evolution step 6: f(x)= 0.808146
# differential_evolution step 7: f(x)= 0.47273
# differential_evolution step 8: f(x)= 0.414045
# differential_evolution step 9: f(x)= 0.360058
# differential_evolution step 10: f(x)= 0.324627
# differential_evolution step 11: f(x)= 0.319503
# differential_evolution step 12: f(x)= 0.228557
# differential_evolution step 13: f(x)= 0.201116
# differential_evolution step 14: f(x)= 0.201116
# differential_evolution step 15: f(x)= 0.162338
# differential_evolution step 16: f(x)= 0.162338
# differential_evolution step 17: f(x)= 0.141716
# differential_evolution step 18: f(x)= 0.126502
# differential_evolution step 19: f(x)= 0.122385
# differential_evolution step 20: f(x)= 0.0984367
# differential_evolution step 21: f(x)= 0.0984367
# differential_evolution step 22: f(x)= 0.0984367
# differential_evolution step 23: f(x)= 0.0984367
# differential_evolution step 24: f(x)= 0.0759373
# differential_evolution step 25: f(x)= 0.0759373
# differential_evolution step 26: f(x)= 0.0759373
# differential_evolution step 27: f(x)= 0.0759373
# differential_evolution step 28: f(x)= 0.0759373
# differential_evolution step 29: f(x)= 0.0759373
# differential_evolution step 30: f(x)= 0.0759373
# differential_evolution step 31: f(x)= 0.0759373
# differential_evolution step 32: f(x)= 0.0759373
# differential_evolution step 33: f(x)= 0.0759373
# differential_evolution step 34: f(x)= 0.0759373
# differential_evolution step 35: f(x)= 0.0759373
# differential_evolution step 36: f(x)= 0.0732594
# differential_evolution step 37: f(x)= 0.0732594
# differential_evolution step 38: f(x)= 0.0732594
# differential_evolution step 39: f(x)= 0.0732594
# differential_evolution step 40: f(x)= 0.0732594
# differential_evolution step 41: f(x)= 0.0732594
# differential_evolution step 42: f(x)= 0.0732594
# differential_evolution step 43: f(x)= 0.0732594
# differential_evolution step 44: f(x)= 0.0732594
# differential_evolution step 45: f(x)= 0.0732594
# differential_evolution step 46: f(x)= 0.0732594
# differential_evolution step 47: f(x)= 0.0732594
# differential_evolution step 48: f(x)= 0.0732594
# differential_evolution step 49: f(x)= 0.0732594
# differential_evolution step 50: f(x)= 0.0732594
# differential_evolution step 51: f(x)= 0.0732594
# differential_evolution step 52: f(x)= 0.0732594
# differential_evolution step 53: f(x)= 0.0732594
# differential_evolution step 54: f(x)= 0.0732594
# differential_evolution step 55: f(x)= 0.0732594
# differential_evolution step 56: f(x)= 0.0732594
# differential_evolution step 57: f(x)= 0.0725235
# differential_evolution step 58: f(x)= 0.0725235
# differential_evolution step 59: f(x)= 0.0725235
# differential_evolution step 60: f(x)= 0.0725235
# differential_evolution step 61: f(x)= 0.0725235
# differential_evolution step 62: f(x)= 0.0704834
# differential_evolution step 63: f(x)= 0.0704834
# differential_evolution step 64: f(x)= 0.0704834
# differential_evolution step 65: f(x)= 0.0704834
# differential_evolution step 66: f(x)= 0.0704834
# differential_evolution step 67: f(x)= 0.0704834
# differential_evolution step 68: f(x)= 0.0704834
# differential_evolution step 69: f(x)= 0.0704834
# differential_evolution step 70: f(x)= 0.0704834
# differential_evolution step 71: f(x)= 0.0704834
# differential_evolution step 72: f(x)= 0.0704834
# differential_evolution step 73: f(x)= 0.0704834
# differential_evolution step 74: f(x)= 0.0704834
# differential_evolution step 75: f(x)= 0.0704834
# differential_evolution step 76: f(x)= 0.0704834
# differential_evolution step 77: f(x)= 0.0704834
# differential_evolution step 78: f(x)= 0.0704834
# differential_evolution step 79: f(x)= 0.0704834
# differential_evolution step 80: f(x)= 0.0704834
# differential_evolution step 81: f(x)= 0.0704834
# differential_evolution step 82: f(x)= 0.0704834
# differential_evolution step 83: f(x)= 0.0687124
# differential_evolution step 84: f(x)= 0.0687124
# differential_evolution step 85: f(x)= 0.0687124
# differential_evolution step 86: f(x)= 0.0687124
# differential_evolution step 87: f(x)= 0.0687124
# differential_evolution step 88: f(x)= 0.0687124
# differential_evolution step 89: f(x)= 0.0687124
# differential_evolution step 90: f(x)= 0.0687124
# differential_evolution step 91: f(x)= 0.0687124
# differential_evolution step 92: f(x)= 0.0687124
# differential_evolution step 93: f(x)= 0.0679645
# differential_evolution step 94: f(x)= 0.0679645
# differential_evolution step 95: f(x)= 0.0678565
# differential_evolution step 96: f(x)= 0.0678565
# differential_evolution step 97: f(x)= 0.0678565
# differential_evolution step 98: f(x)= 0.0678565
# differential_evolution step 99: f(x)= 0.0678565
# differential_evolution step 100: f(x)= 0.0655187
# differential_evolution step 101: f(x)= 0.0655187
# differential_evolution step 102: f(x)= 0.0655187
# differential_evolution step 103: f(x)= 0.0655187
# differential_evolution step 104: f(x)= 0.0655187
# differential_evolution step 105: f(x)= 0.0650857
# differential_evolution step 106: f(x)= 0.0650857
# differential_evolution step 107: f(x)= 0.0650857
# differential_evolution step 108: f(x)= 0.0650857
# differential_evolution step 109: f(x)= 0.0650857
# differential_evolution step 110: f(x)= 0.0650857
# differential_evolution step 111: f(x)= 0.0650857
# differential_evolution step 112: f(x)= 0.0650857
# differential_evolution step 113: f(x)= 0.0650857
# differential_evolution step 114: f(x)= 0.0650857
# differential_evolution step 115: f(x)= 0.0650857
# differential_evolution step 116: f(x)= 0.0650857
# differential_evolution step 117: f(x)= 0.0650857
# differential_evolution step 118: f(x)= 0.0650857
# differential_evolution step 119: f(x)= 0.0650857
# differential_evolution step 120: f(x)= 0.0650857
# differential_evolution step 121: f(x)= 0.0650857
# differential_evolution step 122: f(x)= 0.0650857
# differential_evolution step 123: f(x)= 0.0650857
# differential_evolution step 124: f(x)= 0.0650857
# differential_evolution step 125: f(x)= 0.0650857
# differential_evolution step 126: f(x)= 0.0650857
# differential_evolution step 127: f(x)= 0.0650857
# differential_evolution step 128: f(x)= 0.0650857
# differential_evolution step 129: f(x)= 0.0650857
# differential_evolution step 130: f(x)= 0.0650857
# Optimization Run #4
# differential_evolution step 1: f(x)= 0.678481
# differential_evolution step 2: f(x)= 0.678481
# differential_evolution step 3: f(x)= 0.539446
# differential_evolution step 4: f(x)= 0.539446
# differential_evolution step 5: f(x)= 0.539446
# differential_evolution step 6: f(x)= 0.539446
# differential_evolution step 7: f(x)= 0.539446
# differential_evolution step 8: f(x)= 0.471293
# differential_evolution step 9: f(x)= 0.311313
# differential_evolution step 10: f(x)= 0.311313
# differential_evolution step 11: f(x)= 0.311313
# differential_evolution step 12: f(x)= 0.311313
# differential_evolution step 13: f(x)= 0.311313
# differential_evolution step 14: f(x)= 0.311313
# differential_evolution step 15: f(x)= 0.185542
# differential_evolution step 16: f(x)= 0.185542
# differential_evolution step 17: f(x)= 0.185542
# differential_evolution step 18: f(x)= 0.181892
# differential_evolution step 19: f(x)= 0.181892
# differential_evolution step 20: f(x)= 0.129989
# differential_evolution step 21: f(x)= 0.129989
# differential_evolution step 22: f(x)= 0.129989
# differential_evolution step 23: f(x)= 0.129989
# differential_evolution step 24: f(x)= 0.129989
# differential_evolution step 25: f(x)= 0.129989
# differential_evolution step 26: f(x)= 0.129989
# differential_evolution step 27: f(x)= 0.129989
# differential_evolution step 28: f(x)= 0.120168
# differential_evolution step 29: f(x)= 0.120168
# differential_evolution step 30: f(x)= 0.110321
# differential_evolution step 31: f(x)= 0.107199
# differential_evolution step 32: f(x)= 0.107199
# differential_evolution step 33: f(x)= 0.107199
# differential_evolution step 34: f(x)= 0.105561
# differential_evolution step 35: f(x)= 0.105561
# differential_evolution step 36: f(x)= 0.105561
# differential_evolution step 37: f(x)= 0.105561
# differential_evolution step 38: f(x)= 0.10243
# differential_evolution step 39: f(x)= 0.0851194
# differential_evolution step 40: f(x)= 0.0851194
# differential_evolution step 41: f(x)= 0.0851194
# differential_evolution step 42: f(x)= 0.0851194
# differential_evolution step 43: f(x)= 0.0851194
# differential_evolution step 44: f(x)= 0.0851194
# differential_evolution step 45: f(x)= 0.0851194
# differential_evolution step 46: f(x)= 0.0851194
# differential_evolution step 47: f(x)= 0.0851194
# differential_evolution step 48: f(x)= 0.0851194
# differential_evolution step 49: f(x)= 0.0851194
# differential_evolution step 50: f(x)= 0.0851194
# differential_evolution step 51: f(x)= 0.0851194
# differential_evolution step 52: f(x)= 0.0851194
# differential_evolution step 53: f(x)= 0.0817881
# differential_evolution step 54: f(x)= 0.0817881
# differential_evolution step 55: f(x)= 0.0762017
# differential_evolution step 56: f(x)= 0.0762017
# differential_evolution step 57: f(x)= 0.0762017
# differential_evolution step 58: f(x)= 0.0762017
# differential_evolution step 59: f(x)= 0.0762017
# differential_evolution step 60: f(x)= 0.0762017
# differential_evolution step 61: f(x)= 0.0762017
# differential_evolution step 62: f(x)= 0.0762017
# differential_evolution step 63: f(x)= 0.0762017
# differential_evolution step 64: f(x)= 0.0762017
# differential_evolution step 65: f(x)= 0.0762017
# differential_evolution step 66: f(x)= 0.0748997
# differential_evolution step 67: f(x)= 0.0748997
# differential_evolution step 68: f(x)= 0.0748997
# differential_evolution step 69: f(x)= 0.0748997
# differential_evolution step 70: f(x)= 0.0748997
# differential_evolution step 71: f(x)= 0.0677942
# differential_evolution step 72: f(x)= 0.0677942
# differential_evolution step 73: f(x)= 0.0677942
# differential_evolution step 74: f(x)= 0.0677942
# differential_evolution step 75: f(x)= 0.0677942
# differential_evolution step 76: f(x)= 0.0677942
# differential_evolution step 77: f(x)= 0.0677942
# differential_evolution step 78: f(x)= 0.0677942
# differential_evolution step 79: f(x)= 0.0677942
# differential_evolution step 80: f(x)= 0.0677942
# differential_evolution step 81: f(x)= 0.0677942
# differential_evolution step 82: f(x)= 0.0677942
# differential_evolution step 83: f(x)= 0.0677942
# differential_evolution step 84: f(x)= 0.0677942
# differential_evolution step 85: f(x)= 0.0677942
# differential_evolution step 86: f(x)= 0.0677942
# differential_evolution step 87: f(x)= 0.0677942
# differential_evolution step 88: f(x)= 0.0677942
# differential_evolution step 89: f(x)= 0.0677942
# differential_evolution step 90: f(x)= 0.0677942
# differential_evolution step 91: f(x)= 0.0677942
# differential_evolution step 92: f(x)= 0.0677942
# differential_evolution step 93: f(x)= 0.0677942
# differential_evolution step 94: f(x)= 0.0677942
# differential_evolution step 95: f(x)= 0.0677942
# differential_evolution step 96: f(x)= 0.0677942
# differential_evolution step 97: f(x)= 0.0677942
# differential_evolution step 98: f(x)= 0.0677942
# differential_evolution step 99: f(x)= 0.0677942
# differential_evolution step 100: f(x)= 0.0677942
# differential_evolution step 101: f(x)= 0.0677942
# differential_evolution step 102: f(x)= 0.0677942
# differential_evolution step 103: f(x)= 0.0677942
# differential_evolution step 104: f(x)= 0.0677942
# differential_evolution step 105: f(x)= 0.0677942
# differential_evolution step 106: f(x)= 0.0677942
# differential_evolution step 107: f(x)= 0.0677942
# differential_evolution step 108: f(x)= 0.0677942
# differential_evolution step 109: f(x)= 0.0677942
# differential_evolution step 110: f(x)= 0.0677942
# differential_evolution step 111: f(x)= 0.0677942
# differential_evolution step 112: f(x)= 0.0677942
# differential_evolution step 113: f(x)= 0.0677942
# differential_evolution step 114: f(x)= 0.0677942
# differential_evolution step 115: f(x)= 0.0666913
# differential_evolution step 116: f(x)= 0.0666913
# differential_evolution step 117: f(x)= 0.0666913
# differential_evolution step 118: f(x)= 0.0666913
# differential_evolution step 119: f(x)= 0.0666913
# differential_evolution step 120: f(x)= 0.0666913
# differential_evolution step 121: f(x)= 0.0666913
# differential_evolution step 122: f(x)= 0.0666913
# differential_evolution step 123: f(x)= 0.0666913
# differential_evolution step 124: f(x)= 0.0666913
# differential_evolution step 125: f(x)= 0.0666913
# differential_evolution step 126: f(x)= 0.0666913
# differential_evolution step 127: f(x)= 0.0666913
# differential_evolution step 128: f(x)= 0.0666913
# differential_evolution step 129: f(x)= 0.0666913
# differential_evolution step 130: f(x)= 0.0666913
# differential_evolution step 131: f(x)= 0.0666913
# differential_evolution step 132: f(x)= 0.0666913
# differential_evolution step 133: f(x)= 0.0666913
# differential_evolution step 134: f(x)= 0.0666913
# differential_evolution step 135: f(x)= 0.0666913
# differential_evolution step 136: f(x)= 0.0666913
# differential_evolution step 137: f(x)= 0.0666913
# differential_evolution step 138: f(x)= 0.0666913
# differential_evolution step 139: f(x)= 0.0666913
# differential_evolution step 140: f(x)= 0.0666913
# differential_evolution step 141: f(x)= 0.0666913
# differential_evolution step 142: f(x)= 0.0666913
# differential_evolution step 143: f(x)= 0.0666913
# differential_evolution step 144: f(x)= 0.0666913
# differential_evolution step 145: f(x)= 0.0666913
# differential_evolution step 146: f(x)= 0.0666913
# differential_evolution step 147: f(x)= 0.0666913
# differential_evolution step 148: f(x)= 0.0666913
# differential_evolution step 149: f(x)= 0.0666913
# differential_evolution step 150: f(x)= 0.0666913
# differential_evolution step 151: f(x)= 0.0666913
# differential_evolution step 152: f(x)= 0.0666913
# differential_evolution step 153: f(x)= 0.0666913
# differential_evolution step 154: f(x)= 0.0666913
# differential_evolution step 155: f(x)= 0.0666913
# differential_evolution step 156: f(x)= 0.0666913
# differential_evolution step 157: f(x)= 0.0661009
# differential_evolution step 158: f(x)= 0.0661009
# differential_evolution step 159: f(x)= 0.0661009
# differential_evolution step 160: f(x)= 0.0661009
# differential_evolution step 161: f(x)= 0.0661009
# differential_evolution step 162: f(x)= 0.0661009
# differential_evolution step 163: f(x)= 0.0661009
# differential_evolution step 164: f(x)= 0.0661009
# differential_evolution step 165: f(x)= 0.0661009
# differential_evolution step 166: f(x)= 0.0655402
# differential_evolution step 167: f(x)= 0.0655402
# differential_evolution step 168: f(x)= 0.0655402
# differential_evolution step 169: f(x)= 0.0655402
# differential_evolution step 170: f(x)= 0.0655402
# differential_evolution step 171: f(x)= 0.0655402
# differential_evolution step 172: f(x)= 0.0655402
# differential_evolution step 173: f(x)= 0.0655402
# differential_evolution step 174: f(x)= 0.0655402
# differential_evolution step 175: f(x)= 0.0655402
# differential_evolution step 176: f(x)= 0.0655402
# differential_evolution step 177: f(x)= 0.0655402
# differential_evolution step 178: f(x)= 0.0655402
# differential_evolution step 179: f(x)= 0.0655402
# differential_evolution step 180: f(x)= 0.0653988
# differential_evolution step 181: f(x)= 0.0648939
# differential_evolution step 182: f(x)= 0.0648939
# differential_evolution step 183: f(x)= 0.0648939
# differential_evolution step 184: f(x)= 0.0648939
# differential_evolution step 185: f(x)= 0.0648939
# differential_evolution step 186: f(x)= 0.0648939
# differential_evolution step 187: f(x)= 0.0648447
# differential_evolution step 188: f(x)= 0.0648447
# differential_evolution step 189: f(x)= 0.0648447
# differential_evolution step 190: f(x)= 0.0648447
# differential_evolution step 191: f(x)= 0.0648447
# differential_evolution step 192: f(x)= 0.0648447
# differential_evolution step 193: f(x)= 0.0648447
# differential_evolution step 194: f(x)= 0.0648447
# differential_evolution step 195: f(x)= 0.0648447
# differential_evolution step 196: f(x)= 0.0648447
# differential_evolution step 197: f(x)= 0.0648447
# differential_evolution step 198: f(x)= 0.0648447
# differential_evolution step 199: f(x)= 0.0648447
# differential_evolution step 200: f(x)= 0.0648447
# differential_evolution step 201: f(x)= 0.0648447
# differential_evolution step 202: f(x)= 0.0647961
# differential_evolution step 203: f(x)= 0.0647961
# differential_evolution step 204: f(x)= 0.0647453
# differential_evolution step 205: f(x)= 0.0647453
# differential_evolution step 206: f(x)= 0.0644084
# differential_evolution step 207: f(x)= 0.0635548
# differential_evolution step 208: f(x)= 0.0635548
# differential_evolution step 209: f(x)= 0.0635548
# differential_evolution step 210: f(x)= 0.0635548
# differential_evolution step 211: f(x)= 0.0635548
# differential_evolution step 212: f(x)= 0.0634684
# differential_evolution step 213: f(x)= 0.0634684
# differential_evolution step 214: f(x)= 0.0634684
# differential_evolution step 215: f(x)= 0.0634684
# differential_evolution step 216: f(x)= 0.0634684
# differential_evolution step 217: f(x)= 0.0634684
# differential_evolution step 218: f(x)= 0.0633883
# differential_evolution step 219: f(x)= 0.0633883
# differential_evolution step 220: f(x)= 0.0633883
# differential_evolution step 221: f(x)= 0.0633883
# differential_evolution step 222: f(x)= 0.0633883
# differential_evolution step 223: f(x)= 0.0633883
# differential_evolution step 224: f(x)= 0.0633883
# differential_evolution step 225: f(x)= 0.0633883
# differential_evolution step 226: f(x)= 0.0633563
# differential_evolution step 227: f(x)= 0.0630803
# differential_evolution step 228: f(x)= 0.0630803
# differential_evolution step 229: f(x)= 0.0630803
# differential_evolution step 230: f(x)= 0.0630803
# differential_evolution step 231: f(x)= 0.0630122
# differential_evolution step 232: f(x)= 0.0630122
# differential_evolution step 233: f(x)= 0.0630122
# differential_evolution step 234: f(x)= 0.0630122
# differential_evolution step 235: f(x)= 0.0630122
# differential_evolution step 236: f(x)= 0.0630122
# differential_evolution step 237: f(x)= 0.0630122
# differential_evolution step 238: f(x)= 0.0628762
# differential_evolution step 239: f(x)= 0.0628762
# differential_evolution step 240: f(x)= 0.0628762
# differential_evolution step 241: f(x)= 0.0628762
# differential_evolution step 242: f(x)= 0.0628762
# differential_evolution step 243: f(x)= 0.0628625
# Optimization Run #5
# differential_evolution step 1: f(x)= 0.572692
# differential_evolution step 2: f(x)= 0.572692
# differential_evolution step 3: f(x)= 0.572692
# differential_evolution step 4: f(x)= 0.572692
# differential_evolution step 5: f(x)= 0.460277
# differential_evolution step 6: f(x)= 0.460277
# differential_evolution step 7: f(x)= 0.460277
# differential_evolution step 8: f(x)= 0.460277
# differential_evolution step 9: f(x)= 0.460277
# differential_evolution step 10: f(x)= 0.460277
# differential_evolution step 11: f(x)= 0.278794
# differential_evolution step 12: f(x)= 0.278794
# differential_evolution step 13: f(x)= 0.278794
# differential_evolution step 14: f(x)= 0.278794
# differential_evolution step 15: f(x)= 0.278794
# differential_evolution step 16: f(x)= 0.15103
# differential_evolution step 17: f(x)= 0.15103
# differential_evolution step 18: f(x)= 0.15103
# differential_evolution step 19: f(x)= 0.15103
# differential_evolution step 20: f(x)= 0.145026
# differential_evolution step 21: f(x)= 0.145026
# differential_evolution step 22: f(x)= 0.145026
# differential_evolution step 23: f(x)= 0.145026
# differential_evolution step 24: f(x)= 0.145026
# differential_evolution step 25: f(x)= 0.145026
# differential_evolution step 26: f(x)= 0.145026
# differential_evolution step 27: f(x)= 0.145026
# differential_evolution step 28: f(x)= 0.105864
# differential_evolution step 29: f(x)= 0.105864
# differential_evolution step 30: f(x)= 0.105864
# differential_evolution step 31: f(x)= 0.105864
# differential_evolution step 32: f(x)= 0.105864
# differential_evolution step 33: f(x)= 0.105864
# differential_evolution step 34: f(x)= 0.105864
# differential_evolution step 35: f(x)= 0.105864
# differential_evolution step 36: f(x)= 0.105864
# differential_evolution step 37: f(x)= 0.105864
# differential_evolution step 38: f(x)= 0.105864
# differential_evolution step 39: f(x)= 0.105864
# differential_evolution step 40: f(x)= 0.105864
# differential_evolution step 41: f(x)= 0.105864
# differential_evolution step 42: f(x)= 0.105864
# differential_evolution step 43: f(x)= 0.105864
# differential_evolution step 44: f(x)= 0.105864
# differential_evolution step 45: f(x)= 0.105864
# differential_evolution step 46: f(x)= 0.105864
# differential_evolution step 47: f(x)= 0.105864
# differential_evolution step 48: f(x)= 0.105864
# differential_evolution step 49: f(x)= 0.105864
# differential_evolution step 50: f(x)= 0.105864
# differential_evolution step 51: f(x)= 0.105864
# differential_evolution step 52: f(x)= 0.105864
# differential_evolution step 53: f(x)= 0.105864
# differential_evolution step 54: f(x)= 0.105864
# differential_evolution step 55: f(x)= 0.105864
# differential_evolution step 56: f(x)= 0.105864
# differential_evolution step 57: f(x)= 0.105864
# differential_evolution step 58: f(x)= 0.105864
# differential_evolution step 59: f(x)= 0.105864
# differential_evolution step 60: f(x)= 0.105864
# differential_evolution step 61: f(x)= 0.105864
# differential_evolution step 62: f(x)= 0.105864
# differential_evolution step 63: f(x)= 0.105864
# differential_evolution step 64: f(x)= 0.105864
# differential_evolution step 65: f(x)= 0.105864
# differential_evolution step 66: f(x)= 0.105864
# differential_evolution step 67: f(x)= 0.105864
# differential_evolution step 68: f(x)= 0.083364
# differential_evolution step 69: f(x)= 0.083364
# differential_evolution step 70: f(x)= 0.083364
# differential_evolution step 71: f(x)= 0.083364
# differential_evolution step 72: f(x)= 0.083364
# differential_evolution step 73: f(x)= 0.083364
# differential_evolution step 74: f(x)= 0.083364
# differential_evolution step 75: f(x)= 0.083364
# differential_evolution step 76: f(x)= 0.083364
# differential_evolution step 77: f(x)= 0.0760652
# differential_evolution step 78: f(x)= 0.0760652
# differential_evolution step 79: f(x)= 0.0760652
# differential_evolution step 80: f(x)= 0.0760652
# differential_evolution step 81: f(x)= 0.0760652
# differential_evolution step 82: f(x)= 0.0760652
# differential_evolution step 83: f(x)= 0.065937
# differential_evolution step 84: f(x)= 0.065937
# differential_evolution step 85: f(x)= 0.065937
# differential_evolution step 86: f(x)= 0.065937
# differential_evolution step 87: f(x)= 0.065937
# differential_evolution step 88: f(x)= 0.065937
# differential_evolution step 89: f(x)= 0.0653205
# differential_evolution step 90: f(x)= 0.0653205
# differential_evolution step 91: f(x)= 0.0653205
# differential_evolution step 92: f(x)= 0.0653205
# differential_evolution step 93: f(x)= 0.0653205
# differential_evolution step 94: f(x)= 0.0653205
# differential_evolution step 95: f(x)= 0.0653205
# differential_evolution step 96: f(x)= 0.0653205
# differential_evolution step 97: f(x)= 0.0653205
# differential_evolution step 98: f(x)= 0.0653205
# differential_evolution step 99: f(x)= 0.0653205
# differential_evolution step 100: f(x)= 0.0653205
# differential_evolution step 101: f(x)= 0.0653205
# differential_evolution step 102: f(x)= 0.0653205
# differential_evolution step 103: f(x)= 0.0653205
# differential_evolution step 104: f(x)= 0.0653205
# differential_evolution step 105: f(x)= 0.0653205
# differential_evolution step 106: f(x)= 0.0653205
# differential_evolution step 107: f(x)= 0.0653205
# differential_evolution step 108: f(x)= 0.0653205
# differential_evolution step 109: f(x)= 0.0653205
# differential_evolution step 110: f(x)= 0.0653205
# differential_evolution step 111: f(x)= 0.0653205
# differential_evolution step 112: f(x)= 0.0653205
# differential_evolution step 113: f(x)= 0.0653205
# differential_evolution step 114: f(x)= 0.0653205
# differential_evolution step 115: f(x)= 0.0653205
# differential_evolution step 116: f(x)= 0.0653205
# differential_evolution step 117: f(x)= 0.0653205
# differential_evolution step 118: f(x)= 0.0653205
# differential_evolution step 119: f(x)= 0.0653205
# differential_evolution step 120: f(x)= 0.0653205
# differential_evolution step 121: f(x)= 0.062684
# differential_evolution step 122: f(x)= 0.062684
# differential_evolution step 123: f(x)= 0.062684
# differential_evolution step 124: f(x)= 0.062684
# differential_evolution step 125: f(x)= 0.062684
# differential_evolution step 126: f(x)= 0.062684
# differential_evolution step 127: f(x)= 0.062684
# differential_evolution step 128: f(x)= 0.062684
# differential_evolution step 129: f(x)= 0.062684
# differential_evolution step 130: f(x)= 0.062684
# differential_evolution step 131: f(x)= 0.062684
# differential_evolution step 132: f(x)= 0.062684
# differential_evolution step 133: f(x)= 0.062684
# differential_evolution step 134: f(x)= 0.0624042
# differential_evolution step 135: f(x)= 0.0622202
# differential_evolution step 136: f(x)= 0.0622202
# differential_evolution step 137: f(x)= 0.0622202
# differential_evolution step 138: f(x)= 0.0622202
# differential_evolution step 139: f(x)= 0.0622202
# differential_evolution step 140: f(x)= 0.0622202
# differential_evolution step 141: f(x)= 0.0617458
# differential_evolution step 142: f(x)= 0.0617458
# differential_evolution step 143: f(x)= 0.0617458
# differential_evolution step 144: f(x)= 0.0617458
# differential_evolution step 145: f(x)= 0.0617458
# differential_evolution step 146: f(x)= 0.0617458
# differential_evolution step 147: f(x)= 0.0617458
# differential_evolution step 148: f(x)= 0.0617458
# differential_evolution step 149: f(x)= 0.0617458
# differential_evolution step 150: f(x)= 0.0617458
# differential_evolution step 151: f(x)= 0.0617458
# differential_evolution step 152: f(x)= 0.0617458
# differential_evolution step 153: f(x)= 0.0617458
# differential_evolution step 154: f(x)= 0.0617458
# differential_evolution step 155: f(x)= 0.0617458
# differential_evolution step 156: f(x)= 0.0603511
# differential_evolution step 157: f(x)= 0.0603511
# differential_evolution step 158: f(x)= 0.0603511
# differential_evolution step 159: f(x)= 0.0603511
# differential_evolution step 160: f(x)= 0.0603511
# differential_evolution step 161: f(x)= 0.0603511
# differential_evolution step 162: f(x)= 0.0603511
# differential_evolution step 163: f(x)= 0.0603511
# differential_evolution step 164: f(x)= 0.0603511
# differential_evolution step 165: f(x)= 0.0603511
# differential_evolution step 166: f(x)= 0.0603511
# differential_evolution step 167: f(x)= 0.0603511
# differential_evolution step 168: f(x)= 0.0603511
# differential_evolution step 169: f(x)= 0.0603511
# differential_evolution step 170: f(x)= 0.0603511
# differential_evolution step 171: f(x)= 0.0603511
# differential_evolution step 172: f(x)= 0.0603511
# differential_evolution step 173: f(x)= 0.0603511
# differential_evolution step 174: f(x)= 0.0603511
# differential_evolution step 175: f(x)= 0.0603511
# differential_evolution step 176: f(x)= 0.0602997
# differential_evolution step 177: f(x)= 0.0602997
# differential_evolution step 178: f(x)= 0.0602997
# differential_evolution step 179: f(x)= 0.0602997
# differential_evolution step 180: f(x)= 0.0602997
# differential_evolution step 181: f(x)= 0.0602997
# differential_evolution step 182: f(x)= 0.0602997
# differential_evolution step 183: f(x)= 0.0602997
# differential_evolution step 184: f(x)= 0.0602997
# differential_evolution step 185: f(x)= 0.0602997
# differential_evolution step 186: f(x)= 0.0602997
# differential_evolution step 187: f(x)= 0.0602997
# differential_evolution step 188: f(x)= 0.0602997
# differential_evolution step 189: f(x)= 0.0602573
# differential_evolution step 190: f(x)= 0.0602573
# differential_evolution step 191: f(x)= 0.0601404
# differential_evolution step 192: f(x)= 0.0601404
# differential_evolution step 193: f(x)= 0.0601404
# differential_evolution step 194: f(x)= 0.0601404
# differential_evolution step 195: f(x)= 0.0601404
# differential_evolution step 196: f(x)= 0.0601404
# differential_evolution step 197: f(x)= 0.0601404
# differential_evolution step 198: f(x)= 0.0601404
# differential_evolution step 199: f(x)= 0.0601404
# differential_evolution step 200: f(x)= 0.0601404
# differential_evolution step 201: f(x)= 0.0601404
# differential_evolution step 202: f(x)= 0.0599037
# differential_evolution step 203: f(x)= 0.0599037
# differential_evolution step 204: f(x)= 0.0599037
# differential_evolution step 205: f(x)= 0.0599037
# differential_evolution step 206: f(x)= 0.0599037
# differential_evolution step 207: f(x)= 0.0599037
# differential_evolution step 208: f(x)= 0.0599037
# differential_evolution step 209: f(x)= 0.0599037
# differential_evolution step 210: f(x)= 0.0598218
# differential_evolution step 211: f(x)= 0.0598218
# differential_evolution step 212: f(x)= 0.0596771
# differential_evolution step 213: f(x)= 0.0596771
# differential_evolution step 214: f(x)= 0.0596771
# differential_evolution step 215: f(x)= 0.0592296
# differential_evolution step 216: f(x)= 0.0592296
# differential_evolution step 217: f(x)= 0.0592296
# differential_evolution step 218: f(x)= 0.0592296
# differential_evolution step 219: f(x)= 0.0592296
# differential_evolution step 220: f(x)= 0.0592296
# differential_evolution step 221: f(x)= 0.0592296
# differential_evolution step 222: f(x)= 0.0592296
# differential_evolution step 223: f(x)= 0.0592296
# differential_evolution step 224: f(x)= 0.0592296
# differential_evolution step 225: f(x)= 0.0592296
# differential_evolution step 226: f(x)= 0.0591516
# differential_evolution step 227: f(x)= 0.0591516
# differential_evolution step 228: f(x)= 0.0591516
# differential_evolution step 229: f(x)= 0.0591516
# differential_evolution step 230: f(x)= 0.0591516
# differential_evolution step 231: f(x)= 0.0591516
# differential_evolution step 232: f(x)= 0.0591516
# differential_evolution step 233: f(x)= 0.0591516
# differential_evolution step 234: f(x)= 0.0591516
# differential_evolution step 235: f(x)= 0.0591516
# differential_evolution step 236: f(x)= 0.0591516
# differential_evolution step 237: f(x)= 0.0591516
# differential_evolution step 238: f(x)= 0.0591516
# differential_evolution step 239: f(x)= 0.058927
# differential_evolution step 240: f(x)= 0.058927
# differential_evolution step 241: f(x)= 0.058927
# differential_evolution step 242: f(x)= 0.058927
# differential_evolution step 243: f(x)= 0.058927
# differential_evolution step 244: f(x)= 0.058927
# differential_evolution step 245: f(x)= 0.058927
# differential_evolution step 246: f(x)= 0.058927
# differential_evolution step 247: f(x)= 0.058927
# differential_evolution step 248: f(x)= 0.058927
# CPU times: user 4min 29s, sys: 3.63 s, total: 4min 33s
# Wall time: 4min 33s

# %% [markdown]
# ## Save Output to File <a name="saveoutput"></a>

# %%
df_t = pd.DataFrame(optimizedSimData[:,0])
df_gr = pd.DataFrame(sims_gr)
df_cort = pd.DataFrame(sims_cort)
df_acth = pd.DataFrame(sims_acth)
df_crh = pd.DataFrame(sims_crh)

df_t.to_excel(excel_writer = 'sriramModel-nelson-patient40-timeSteps-5-iterations.xlsx')
df_gr.to_excel(excel_writer = 'sriramModel-nelson-patient40-sims-gr-5-iterations.xlsx')
df_cort.to_excel(excel_writer = 'sriramModel-nelson-patient40-sims-cort-5-iterations.xlsx')
df_acth.to_excel(excel_writer = 'sriramModel-nelson-patient40-sims-acth-5-iterations.xlsx')
df_crh.to_excel(excel_writer = 'sriramModel-nelson-patient40-sims-crh-5-iterations.xlsx')

# %%
np.savetxt('sriramModel-nelson-patient40-opt-pars-5-iterations.txt', opt_pars)

# %%
np.savetxt('sriramModel-nelson-patient40-timeSteps-5-iterations.txt', optimizedSimData[:,0])

# %%
np.savetxt('sriramModel-nelson-patient40-sims-gr-5-iterations.txt', sims_gr)
np.savetxt('sriramModel-nelson-patient40-sims-crh-5-iterations.txt', sims_crh)
np.savetxt('sriramModel-nelson-patient40-sims-acth-5-iterations.txt', sims_acth)
np.savetxt('sriramModel-nelson-patient40-sims-cort-5-iterations.txt', sims_cort)

# %%
np.savetxt('sriramModel-nelson-patient40-initial-conditions-5-iterations.txt', y0)
np.savetxt('sriramModel-nelson-patient40-bounds-5-iterations.txt', bounds)

# %% [markdown]
# ## Compute Means and Std Devations of Parameters and Output as Table <a name="paramtable"></a>

# %%
k_stress_mean = np.mean(opt_pars[:,1])
k_stress_std = np.std(opt_pars[:,1])
k_i_mean = np.mean(opt_pars[:,2])
k_i_std = np.std(opt_pars[:,2])
V_S3_mean = np.mean(opt_pars[:,3])
V_S3_std = np.std(opt_pars[:,3])
K_m1_mean = np.mean(opt_pars[:,4])
K_m1_std = np.std(opt_pars[:,4])
K_P2_mean = np.mean(opt_pars[:,5])
K_P2_std = np.std(opt_pars[:,5])
V_S4_mean = np.mean(opt_pars[:,6])
V_S4_std = np.std(opt_pars[:,6])
K_m2_mean = np.mean(opt_pars[:,7])
K_m2_std = np.std(opt_pars[:,7])
K_P3_mean = np.mean(opt_pars[:,8])
K_P3_std = np.std(opt_pars[:,8])
V_S5_mean = np.mean(opt_pars[:,9])
V_S5_std = np.std(opt_pars[:,9])
K_m3_mean = np.mean(opt_pars[:,10])
K_m3_std = np.std(opt_pars[:,10])
K_d1_mean = np.mean(opt_pars[:,11])
K_d1_std = np.std(opt_pars[:,11])
K_d2_mean = np.mean(opt_pars[:,12])
K_d2_std = np.std(opt_pars[:,12])
K_d3_mean = np.mean(opt_pars[:,13])
K_d3_std = np.std(opt_pars[:,13])
n1_mean = np.mean(opt_pars[:,14])
n1_std = np.std(opt_pars[:,14])
n2_mean = np.mean(opt_pars[:,15])
n2_std = np.std(opt_pars[:,15])
K_b_mean = np.mean(opt_pars[:,16])
K_b_std = np.std(opt_pars[:,16])
G_tot_mean = np.mean(opt_pars[:,17])
G_tot_std = np.std(opt_pars[:,17])
V_S2_mean = np.mean(opt_pars[:,18])
V_S2_std = np.std(opt_pars[:,18])
K1_mean = np.mean(opt_pars[:,19])
K1_std = np.std(opt_pars[:,19])
K_d5_mean = np.mean(opt_pars[:,20])
K_d5_std = np.std(opt_pars[:,20])
p_stress_mean = np.mean(opt_pars[:,21])
p_stress_std = np.std(opt_pars[:,21])

# %%
print(tabulate([["k_stress", "%f +- %f" % (k_stress_mean, k_stress_std)], ["k_i", "%f +- %f" % (k_i_mean, k_i_std)], ["V_S3", "%f +- %f" % (V_S3_mean, V_S3_std)], ["K_m1", "%f +- %f" % (K_m1_mean, K_m1_std)], ["K_P2", "%f +- %f" % (K_P2_mean, K_P2_std)], ["V_S4", "%f +- %f" % (V_S4_mean, V_S4_std)], ["K_m2", "%f +- %f" % (K_m2_mean, K_m2_std)], ["K_P3", "%f +- %f" % (K_P3_mean, K_P3_std)], ["V_S5", "%f +- %f" % (V_S5_mean, V_S5_std)], ["K_m3", "%f +- %f" % (K_m3_mean, K_m3_std)], ["K_d1", "%f +- %f" % (K_d1_mean, K_d1_std)], ["K_d2", "%f +- %f" % (K_d2_mean, K_d2_std)], ["K_d3", "%f +- %f" % (K_d3_mean, K_d3_std)], ["n1", "%f +- %f" % (n1_mean, n1_std)], ["n2", "%f +- %f" % (n2_mean, n2_std)], ["K_b", "%f +- %f" % (K_b_mean, K_b_std)], ["G_tot", "%f +- %f" % (G_tot_mean, G_tot_std)], ["V_S2", "%f +- %f" % (V_S2_mean, V_S2_std)], ["K1", "%f +- %f" % (K1_mean, K1_std)], ["K_d5", "%f +- %f" % (K_d5_mean, K_d5_std)], ["p_stress", "%f +- %f" % (p_stress_mean, p_stress_std)]], headers = ["Parameter", "Mean +- Standard Deviation"]))
# Out:
# Parameter    Mean +- Standard Deviation
# -----------  ----------------------------
# k_stress     11.339516 +- 5.543385
# k_i          3.697201 +- 0.441584
# V_S3         3.669963 +- 2.423809
# K_m1         6.670356 +- 2.787892
# K_P2         7.374292 +- 5.802101
# V_S4         9.984322 +- 0.429753
# K_m2         1.178635 +- 0.705414
# K_P3         2.947963 +- 0.504427
# V_S5         0.092981 +- 0.014037
# K_m3         0.314758 +- 0.056573
# K_d1         0.001000 +- 0.000000
# K_d2         0.099594 +- 0.000811
# K_d3         4.552416 +- 0.781448
# n1           13.120833 +- 1.584477
# n2           13.209811 +- 3.460702
# K_b          0.009656 +- 0.008607
# G_tot        14.315506 +- 9.245517
# V_S2         6.819368 +- 0.361264
# K1           2.887201 +- 0.280944
# K_d5         0.037617 +- 0.051470
# p_stress     42.938171 +- 19.566751

# %%
np.savetxt('sriramModel-nelson-patient40-param-means-stds-5-iterations.txt', [k_stress_mean, k_stress_std, k_i_mean, k_i_std, V_S3_mean, V_S3_std, K_m1_mean, K_m1_std, K_P2_mean, K_P2_std, V_S4_mean, V_S4_std, K_m2_mean, K_m2_std, K_P3_mean, K_P3_std, V_S5_mean, V_S5_std, K_m3_mean, K_m3_std, K_d1_mean, K_d1_std, K_d2_mean, K_d2_std, K_d3_mean, K_d3_std, n1_mean, n1_std, n2_mean, n2_std, K_b_mean, K_b_std, G_tot_mean, G_tot_std, V_S2_mean, V_S2_std, K1_mean, K1_std, K_d5_mean, K_d5_std])

# %% [markdown]
# ## Plots <a name="plots"></a>

# %%
#sims_gr = np.genfromtxt("sriram-sims-gr-carrollLCDepressed-rearr-1-all-params-expanded-bounds.txt")
#sims_cort = np.genfromtxt("sriram-sims-cort-carrollLCDepressed-rearr-1-all-params-expanded-bounds.txt")
#sims_crh = np.genfromtxt("sriram-sims-crh-carrollLCDepressed-rearr-1-all-params-expanded-bounds.txt")
#cims_acth = np.genfromtxt("sriram-sims-acth-carrollLCDepressed-rearr-1-all-params-expanded-bounds.txt")

# %%
#%matplotlib inline
#fig, (ax1, ax2) = plt.subplots(nrows = 2, figsize = (15, 15))

#ax1.plot(nelsonACTH[:,0], nelsonACTH[:,59], label = "Nelson ACTH Data - Patient 58", color = "orange")
#ax1.plot(optimizedSimData[:,0], np.mean(sims_acth, axis = 1), label = "Simulated ACTH Data", color = "blue")
#ax1.fill_between(optimizedSimData[:,0], np.mean(sims_acth, axis = 1) - np.std(sims_acth, axis = 1), np.mean(sims_acth, axis = 1) + np.std(sims_acth, axis = 1), alpha = 0.3, label = "Simulated ACTH Standard Deviation")
#ax1.legend(loc = "upper left", shadow = True, fancybox = True)
#ax1.set(xlabel = "Time (h)", ylabel = "ACTH (pg/mL)", title = "Nelson ACTH")

#ax2.plot(nelsonCortisol[:,0], nelsonCortisol[:,59], label = "Nelson Cortisol Data - Patient 58", color = "orange")
#ax2.plot(optimizedSimData[:,0], np.mean(sims_cort, axis = 1), label = "Simulated Cortisol Data", color = "blue")
#ax2.fill_between(optimizedSimData[:,0], np.mean(sims_cort, axis = 1) - np.std(sims_cort, axis = 1), np.mean(sims_cort, axis = 1) + np.std(sims_cort, axis = 1), alpha = 0.3, label = "Simulated Cortisol Standard Deviation")
#ax2.legend(loc = "upper left", shadow = True, fancybox = True)
#ax2.set(xlabel = "Time (h)", ylabel = "Cortisol (micrograms/dL)", title = "Nelson Cortisol")


#plt.savefig("sriramModel-nelson-patient24-5-iterations-all-params.png", dpi = 300)

# %%
# %matplotlib inline
# plot of raw data with simulation data for cortisol, then just simulation data for crh and acth

matplotlib.rc('font', **{'size'   : 28})

fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows=4, figsize=(24,40))

#ax1.plot(optimizedSimData[:,0], sims_crh, label = "Mean Simulated CRH")
# for more than 1 iteration, uncomment below
ax1.plot(optimizedSimData[:,0], np.mean(sims_crh, axis = 1), label = "Mean Simulated CRH", color = "blue")
ax1.fill_between(optimizedSimData[:,0], np.mean(sims_crh, axis = 1) - np.std(sims_crh, axis = 1), np.mean(sims_crh, axis = 1) + np.std(sims_crh, axis = 1), alpha = 0.3, label = "Simulated CRH Standard Deviation")
ax1.legend(loc = "upper left", shadow = True, fancybox = True)
ax1.set(xlabel = "Time (h)", ylabel = "CRH (micrograms/dL)", title = "CRH Concentration")

#ax2.plot(optimizedSimData[:,0], sims_acth, label = "Mean")
ax2.plot(nelsonACTH[:,0], nelsonACTH[:,41], label = "Nelson ACTH Data - Patient 40", color = "orange")
# for more than 1 iteration, uncomment below
ax2.plot(optimizedSimData[:,0], np.mean(sims_acth, axis = 1), label = "Mean Simulated ACTH", color = "blue")
ax2.fill_between(optimizedSimData[:,0], np.mean(sims_acth, axis = 1) - np.std(sims_acth, axis = 1), np.mean(sims_acth, axis = 1) + np.std(sims_acth, axis = 1), alpha = 0.3, label = "Simulated ACTH Standard Deviation")
ax2.legend(loc = "upper right", shadow = True, fancybox = True)
ax2.set(xlabel = "Time (h)", ylabel = "ACTH (pg/mL)", title = "ACTH Concentration")

#ax3.plot(optimizedSimData[:,0], sims_cort, label = "Simulation Mean")
ax3.plot(nelsonCortisol[:,0], nelsonCortisol[:,41], label = "Nelson Cortisol Data - Patient 40", color = "orange")
# for more than 1 iteration, uncomment below
ax3.plot(optimizedSimData[:,0], np.mean(sims_cort, axis = 1), label = "Mean Simulated Cortisol", color = "blue")
ax3.fill_between(optimizedSimData[:,0], np.mean(sims_cort, axis = 1) - np.std(sims_cort, axis = 1), np.mean(sims_cort, axis = 1) + np.std(sims_cort, axis = 1), alpha = 0.3, label = "Simulated Cortisol Standard Deviation")
ax3.legend(loc = "lower right", shadow = True, fancybox = True)
ax3.set(xlabel = "Time (h)", ylabel = "Cortisol (micrograms/dL)", title = "Cortisol Concentration")

#ax4.plot(optimizedSimData[:,0], sims_gr, label = "Mean")
# for more than 1 iteration, uncomment below
ax4.plot(optimizedSimData[:,0], np.mean(sims_gr, axis = 1), label = "Mean Simulated GR")
ax4.fill_between(optimizedSimData[:,0], np.mean(sims_gr, axis = 1) - np.std(sims_gr, axis = 1), np.mean(sims_gr, axis = 1) + np.std(sims_gr, axis = 1), alpha = 0.5, label = "Simulated GR Standard Deviation")
ax4.legend(loc = "upper left", shadow = True, fancybox = True)
ax4.set(xlabel = "Time (h)", ylabel = "GR (micrograms)", title = "GR Concentration")

txt = "cost = []"
plt.figtext(0.1, 0.09, txt, wrap = True, horizontalalignment = 'center', fontsize = 30)
#plt.savefig("sriramModel-nelson-patient40-5-iterations-all-params-normalizedCost.png", dpi = 300)
# Out:
# Text(0.1, 0.09, 'cost = []')

# %% [markdown]
# ## Figure 3 Reproduction <a name="fig3"></a>

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 10.1
k_i = 1.51
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params_control = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 13.7
k_i = 1.6
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params_depressed = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
# initialize parameter values that stay the same between all three groups
#     These are the optimized values that the authors got from SensSB toolbox

k_stress = 17.5
k_i = 1.17
V_S3 = 3.25
K_m1 = 1.74
K_P2 = 8.3
V_S4 = 0.907
K_m2 = 0.112
K_P3 = 0.945
V_S5 = 0.00535
K_m3 = 0.0768
K_d1 = 0.00379
K_d2 = 0.00916
K_d3 = 0.356
n1 = 5.43
n2 = 5.1
K_b = 0.0202
G_tot = 3.28
V_S2 = 0.0509
K1 = 0.645
K_d5 = 0.0854
p_stress = 1

authors_params_ptsd = [k_stress, k_i, V_S3, K_m1, K_P2, V_S4, K_m2, K_P3, V_S5, K_m3, K_d1, K_d2, K_d3, n1, n2, K_b, G_tot, V_S2, K1, K_d5, p_stress]

# %%
y0_control = [1, 5, 5, 2]
y0_depressed = [1, 5, 5, 2]
y0_ptsd = [1, 5, 5, 2]

t_start = -0.01
t_end = 300.01
t_step = 0.01

# %%
# %%time

no_opt_control = model(authors_params_control, y0_control)
no_opt_depressed = model(authors_params_depressed, y0_depressed)
no_opt_ptsd = model(authors_params_ptsd, y0_ptsd)

sims_gr_control = no_opt_control[:,4]
sims_cort_control = no_opt_control[:,3]
sims_acth_control = no_opt_control[:,2]
sims_crh_control = no_opt_control[:,1]

sims_gr_depressed = no_opt_depressed[:,4]
sims_cort_depressed = no_opt_depressed[:,3]
sims_acth_depressed = no_opt_depressed[:,2]
sims_crh_depressed = no_opt_depressed[:,1]

sims_gr_ptsd = no_opt_ptsd[:,4]
sims_cort_ptsd = no_opt_ptsd[:,3]
sims_acth_ptsd = no_opt_ptsd[:,2]
sims_crh_ptsd = no_opt_ptsd[:,1]
# Out:
# CPU times: user 968 ms, sys: 25.8 ms, total: 994 ms
# Wall time: 1 s

# %%
# %matplotlib inline
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (15,20))

ax1.plot(np.arange(0, 70, 0.01), sims_cort_control[-7800:-800], label = "CORT sim - Control")
ax1.set(ylabel = "CORT (micrograms/dL)", xlabel = "Time (h)", title = "CORT sim - Control")
#ax1.legend(loc = "upper right", shadow = True, fancybox = True)

ax2.plot(np.arange(0, 70, 0.01), sims_cort_depressed[-8800:-1800], label = "CORT sim - Depression")
ax2.set(ylabel = "CORT (micrograms/dL)", xlabel = "Time (h)", title = "CORT sim - Depression")
#ax2.legend(loc = "upper right", shadow = True, fancybox = True)

ax3.plot(np.arange(0, 70, 0.01), sims_cort_ptsd[-9100:-2100], label = "CORT sim - PTSD")
ax3.set(ylabel = "CORT (micrograms/dL)", xlabel = "Time (h)", title = "CORT sim - PTSD")
#ax3.legend(loc = "upper right", shadow = True, fancybox = True)

plt.savefig("sriramModel-figure3-reproduction.png", dpi=300)

# %% [markdown]
# ## Figure 4 Reproduction <a name="fig4"></a>

# %%
# create Fig 4 of free glucocorticoid receptor level
t_end = 240.01

normal = model(authors_params_control, y0)
PTSD = model(authors_params_ptsd, y0)
depressed = model(authors_params_depressed, y0)

G_normal = G_tot - normal[:,4]
G_PTSD = G_tot - PTSD[:,4]
G_depressed = G_tot - depressed[:,4]

plt.plot(normal[-12000:,0], G_normal[-12000:], label='Normal')
plt.plot(PTSD[-12000:,0], G_PTSD[-12000:], label='PTSD')
plt.plot(depressed[-12000:,0], G_depressed[-12000:], label='Depressed')
plt.ylim(0,2.5)
plt.xlabel('t (hours)')
plt.ylabel('G')
plt.title("Figure 4 Reproduction")
plt.legend(loc = "upper right", shadow = True, fancybox = True)
plt.savefig("sriramModel-figure4-reproduction.png", dpi=300)

# %% [markdown]
# ## Load Parameter Sets, Run Model and Save Hormone Concentration Data <a name="loadparams"></a>

# %%
loaded_params = np.genfromtxt("sriram-opt-pars-carrollControl-rearr-1-all-params-expanded-bounds.txt")
y0 = np.genfromtxt("sriram-y0-carrollControl-rearr-1-all-params-expanded-bounds.txt")
bounds = np.genfromtxt("sriram-bounds-carrollControl-rearr-1-all-params-expanded-bounds.txt")

# %%
# if loading only a single iteration
loaded_params = loaded_params[1:]

# if loading multiple iterations
#loaded_params = loaded_params[1:,:]

# %%
# plug the optimized parameters into the solver
optimizedSimData = model(loaded_params, y0)
    
# save CRH, cortisol and ACTH data into sims arrays
sims_gr = optimizedSimData[:,4]
sims_cort = optimizedSimData[:,3]
sims_acth = optimizedSimData[:,2]
sims_crh = optimizedSimData[:,1]

# %% [markdown]
# ### Checking Parameter Sets Generated Externally <a name="checkexternal"></a>

# %%
cort_data = np.zeros((2403,len(loaded_params)))
for i in range(len(loaded_params)):
    cort_data[:,i] = np.transpose(np.hstack((i+1,model(loaded_params[i,1:], y0)[:,3])))

# %%
time_data = np.zeros((2403,len(loaded_params)))
for i in range(len(loaded_params)):
    time_data[:,i] = np.transpose(np.hstack((i+1,model(loaded_params[i,1:], y0)[:,0])))

# %%
np.savetxt("sriram-cort-data-yehudaControl-1000-all-params.txt", cort_data)

# %%
np.savetxt("sriram-time-data-yehudaControl-1000-all-params.txt", time_data)

# %%
sim = model(yin_params[next_max,1:], y0)

# %%
sim = model(testing_params, y0)

# %%
print(cost_fun(testing_params))
# Out:
# 921758398.1845118

# %%
fig, (ax1, ax2, ax3) = plt.subplots(nrows = 3, figsize = (15,15))
ax1.plot(sim[:,0], sim[:,3], label = "Simulation")
ax1.plot(yehudaControlCortisol[:,0], yehudaControlCortisol[:,1], label = "Yehuda Control Group")
ax1.set(xlabel = "Time", ylabel = "Cortisol", title = "Control Group: Raw Data vs Authors' Optimized Parameters")
ax2.plot(sim[:,0], sim[:,1])
ax2.set(xlabel = "Time", ylabel = "CRH", title = "CRH w/ Authors' Control Group Parameters")
ax3.plot(sim[:,0], sim[:,2])
ax3.set(xlabel = "Time", ylabel = "ACTH", title = "ACTH w/ Authors' Control Group Parameters")

plt.savefig("testing-params-kb-0.01.pdf", dpi = 300)

# %% [markdown]
# ## Dependencies <a name="dependencies"></a>

# %%
# %load_ext watermark

# %%
# %watermark --iversions
# Out:
# distutils : 3.7.7
# scipy     : 1.1.0
# matplotlib: 3.0.1
# platform  : 1.0.8
# sys       : 3.7.7 (default, May  6 2020, 04:59:01)
# [Clang 4.0.1 (tags/RELEASE_401/final)]
# pandas    : 0.23.4
# PyDSTool  : 0.91.0
# numpy     : 1.21.5
# mpld3     : 0.3.1.dev1
